# %% [markdown]
# # Iterative Linear Quadratic Regulator
# ### Inverse pendulum on a cart

# %%
# python libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import time
import control
from scipy.integrate import odeint

# pydrake imports
from pydrake.all import (Variable, SymbolicVectorSystem, DiagramBuilder,
                         LogVectorOutput, Simulator, ConstantVectorSource,
                         MathematicalProgram, Solve, SnoptSolver, PiecewisePolynomial)
import pydrake.symbolic as sym
from scipy.integrate import solve_ivp

# %% [markdown]
# ## Iterative Linear Quadratic Regulator Derivation
#
# In this exercise we will derive the iterative Linear Quadratic Regulator (iLQR) solving the following optimization problem.
#
# $\begin{aligned} \min_{\mathbf{u}[\cdot]} \quad & \ell_f(\mathbf{x}[N]) + \sum_{n=0}^{N-1} \ell(\mathbf{x}[n],\mathbf{u}[n]) \\ \text{subject to} \quad & \mathbf{x}[n+1] = (\mathbf{x}[n], \mathbf{u}[n]), \quad \forall n\in[0, N-1] \\ & \mathbf{x}[0] = \mathbf{x}_0\end{aligned}$
#
# After completing this exercise you will be able to write your own MPC solver from scratch without any proprietary or third-party software (with the exception of auto-differentiation). You will derive all necessary equations yourself.
# While the iLQR algorithm will be capable of solving general model predictive control problems in the form described above, we will apply it to the control of a vehicle.
#
# ### Pendulum on cart control problem
# Before we start the actual derivation of iLQR we will take a look at the pendulum on cart dynamics and cost functions.

# %% [markdown]
# Using the same convention as the book, we describe the state of the cart-pole as the vector $\mathbf{x} = [x, \dot{x}, \theta, \dot{\theta}]^\top$, and we let the force on the cart be the control input $\mathbf{u} = [f_x]$.
#
# Use [equations (16) and (17)](https://underactuated.csail.mit.edu/acrobot.html#cart_pole) from the textbook for the accelerations:
#
# $$\ddot{x} = \frac{1}{m_c + m_p \sin^2\theta}[ f_x+m_p \sin\theta (l \dot\theta^2 + g\cos\theta)]$$
#
# $$\ddot{\theta} = \frac{1}{l(m_c + m_p \sin^2\theta)}[ -f_x \cos\theta - m_p l \dot\theta^2 \cos\theta \sin\theta - (m_c + m_p) g \sin\theta]$$
#
# Complete the state-space model of the cart-pole by implementing the vector $\dot{\mathbf{x}} = [\dot{x}, \ddot{x}, \dot{\theta}, \ddot{\theta}]^\top$ as $\dot{\mathbf{x}} = {\bf f}(\mathbf{x}, \mathbf{u})$. Implement the function ${\bf f}$ below to return $\dot{\mathbf{x}}$.

# %%
# Compute trajectory
dt = 0.1
T = 5
num_time_pts = int(T / dt)
t = np.linspace(0, T, num_time_pts)

x_goal = np.array([0.0, 0.0, np.pi, 0.0])

# %%
n_x = 4
n_y = 4
n_u = 1

m_p = 0.3 #1.0     # pendulum (bob) mass [kg]
m_c = 1.0     # cart mass [kg]
g = 9.81      # gravity [m/s^2]
l = 1.0       # length of a rod [m]
d = 1

# %%
# function that returns the A_lin matrix
def get_A_lin():
    A = np.array([
        [0, 1, 0, 0], 
        [0, -d/m_c, m_p*g/m_c, 0], 
        [0, 0, 0, 1], 
        [0, -d/(m_c*l), -(m_c+m_p)*g/(m_c*l), 0]  
    ])
    return A

# function that returns the B_lin matrix
def get_B_lin():
    B = np.array([
        [0], 
        [1/m_c], 
        [0], 
        [1/(m_c*l)]
    ])
    return B

# %%
# Design LQR controller
Qw = np.array([[500, 0, 0, 0],[0, 1, 0, 0],[0, 0, 500, 0], [0, 0, 0, 1]])
Rw = 1
A = get_A_lin()
B = get_B_lin()
L, S, E = control.lqr(A, B, Qw, Rw)

# %%
def pendcart(x, t):
    # x = [x_c, v_c, theta_p, omega_p] 
    # u = control input
    theta = x[2] 
    s = np.sin(theta)
    c = np.cos(theta)

    theta_dot = x[-1]
    x_dot = x[1]
    
    u = np.dot(-L, (x - x_goal))

    theta_dot_2 = ( (m_p+m_c)*g*s-m_p*l*(theta_dot**2)*s*c-u[0]*c +d*c*x_dot )/( l*(m_c+m_p*(s**2)) )
    x_dot_2 = (u[0]-m_p*g*s*c+m_p*l*(theta_dot**2)*s-d*x_dot)/(m_c+m_p*(s**2)) 
    
    x_d = np.array([
        x_dot,
        x_dot_2,
        theta_dot,
        theta_dot_2 
    ])
    return x_d

# %%
def LQG_pendulum_on_cart_continuous_dynamics(x, u):
    # x = [x_c, v_c, theta_p, omega_p] 
    # u = control input
    m = sym if x.dtype == object else np # Check type for autodiff
    theta = x[2] 
    s = m.sin(theta)
    c = m.cos(theta)

    theta_dot = x[-1]
    x_dot = x[1]

    u = np.dot(-L, (x - x_goal))
    
    theta_dot_2 = ( (m_p+m_c)*g*s-m_p*l*(theta_dot**2)*s*c-u[0]*c +d*c*x_dot )/( l*(m_c+m_p*(s**2)) )
    x_dot_2 = (u[0]-m_p*g*s*c+m_p*l*(theta_dot**2)*s-d*x_dot)/(m_c+m_p*(s**2)) 
    
    x_d = np.array([
        x_dot,
        x_dot_2,
        theta_dot,
        theta_dot_2 
    ])
    return x_d

def LQG_rk4singlestep(x0, u0):
    """
        This function does a single 4th-order Runge-Kutta
    """

    f1 = LQG_pendulum_on_cart_continuous_dynamics(x0, u0)
    f2 = LQG_pendulum_on_cart_continuous_dynamics(x0 + (dt/2) * f1, u0)
    f3 = LQG_pendulum_on_cart_continuous_dynamics(x0 + (dt/2) * f2, u0)
    f4 = LQG_pendulum_on_cart_continuous_dynamics(x0 + dt * f3, u0)
    x_next = x0 + (dt/6) * (f1 + 2 * f2 + 2 * f3 + f4)

    return x_next

# %%
def pendulum_on_cart_continuous_dynamics(x, u):
    # x = [x_c, v_c, theta_p, omega_p] 
    # u = control input
    m = sym if x.dtype == object else np # Check type for autodiff
    theta = x[2] 
    s = m.sin(theta)
    c = m.cos(theta)

    theta_dot = x[-1]
    x_dot = x[1]

    theta_dot_2 = ( (m_p+m_c)*g*s-m_p*l*(theta_dot**2)*s*c-u[0]*c +d*c*x_dot )/( l*(m_c+m_p*(s**2)) )
    x_dot_2 = (u[0]-m_p*g*s*c+m_p*l*(theta_dot**2)*s-d*x_dot)/(m_c+m_p*(s**2)) 
    
    x_d = np.array([
        x_dot,
        x_dot_2,
        theta_dot,
        theta_dot_2 
    ])
    return x_d

# %% [markdown]
# ### Gen normal distribution noise for multivariate state space

# %%
# Set noise mean and covariances for dynamics and measurement
sigma_x = 0.1
sigma_y = 0.1
W = (sigma_x**2)*np.eye(n_x)
V = (sigma_y**2)*np.eye(n_y)

mean_x = np.zeros([n_x])
mean_y = np.zeros([n_x])

# %%
def GenNoiseSequence(T, N_trials):
        
        # Allocate storage for data
        seq_Q = np.empty([N_trials, n_x, T])
        seq_R = np.empty([N_trials, n_y, T])

        for k in range(N_trials):
            for t in range(T):
                q_sample = np.random.multivariate_normal(mean_x, W)
                r_sample = np.random.multivariate_normal(mean_y, V)
                seq_Q[k,:,t] = q_sample
                seq_R[k,:,t] = r_sample

        noise = (seq_Q, seq_R)
        
        return noise 


N_trials = 100
np.random.seed(0)
noise = GenNoiseSequence(num_time_pts, N_trials)

# Get Process/Observation Noise
Q_noise, R_noise = noise

# %%
# n_x = 4
# n_u = 1
# m_p = 0.3 #1.0     # pendulum (bob) mass [kg]
# m_c = 1.0     # cart mass [kg]
# g = 9.81      # gravity [m/s^2]
# l = 1.0       # length of a rod [m]

# def pendulum_on_cart_continuous_dynamics(x, u):
#     # x = [x_c, v_c, theta_p, omega_p] 
#     # u = control input
#     m = sym if x.dtype == object else np # Check type for autodiff
#     theta = x[2]
#     s = m.sin(theta)
#     c = m.cos(theta)

#     theta_dot = x[-1]
#     theta_dot_2 = -(1/( l*(m_c+m_p*(s**2)) ))*( (m_p+m_c)*g*s+m_p*l*(theta_dot**2)*s*c+u[0]*c )
#     x_dot = x[1]
#     x_dot_2 = (u[0]+m_p*g*s*c+m_p*l*(theta_dot**2)*s)/(m_c+m_p*(s**2)) 
#     x_d = np.array([
#         x_dot,
#         x_dot_2,
#         theta_dot,
#         theta_dot_2 
#     ])
#     return x_d

# %%
def rk4singlestep(x0, u0):
    """
        This function does a single 4th-order Runge-Kutta
    """

    f1 = pendulum_on_cart_continuous_dynamics(x0, u0)
    f2 = pendulum_on_cart_continuous_dynamics(x0 + (dt/2) * f1, u0)
    f3 = pendulum_on_cart_continuous_dynamics(x0 + (dt/2) * f2, u0)
    f4 = pendulum_on_cart_continuous_dynamics(x0 + dt * f3, u0)
    x_next = x0 + (dt/6) * (f1 + 2 * f2 + 2 * f3 + f4)

    return x_next

def euler_single_step(fun, dt, t0, x0):

    x_next = x0 + dt * fun(t0, x0)

    return x_next

# %% [markdown]
# ### Euler integrator (Recap)
# Euler method, also known as forward Euler method, is a 1-st order numerical procedure for solving ODEs with a given initial value. Euler method is the most basic explicit method for numerical integration of ODEs and is known as the simplest version of Runge-Kutta method.
#
# <br>
#
# Since Euler method is a 1-st order method, it means also that the local and global error (per step) is proportional to the square of the step size.
#
# <br>

# %%
# def discrete_dynamics(x, u):
#     x_next = x + dt * pendulum_on_cart_continuous_dynamics(x, u)
#     return x_next

# %% [markdown]
# Given an initial state $\mathbf{x}_0$ and a guess of a control trajectory $\mathbf{u}[0:N-1]$ we roll out the state trajectory $x[0:N]$ until the time horizon $N$. Please complete the rollout function.

# %%
def rollout(x0, u_trj):
    x_trj = np.zeros((u_trj.shape[0]+1, x0.shape[0]))
    # Define the rollout here and return the state trajectory x_trj: [N, number of states]
    N = u_trj.shape[0]+1
    x_trj[0] = x0 
    for n in range(N-1):
        # x_trj[n+1] = rk4singlestep(pendulum_on_cart_continuous_dynamics, dt, t[n], x_trj[n], u_trj[n])
        x_trj[n+1] = rk4singlestep(x_trj[n], u_trj[n])
        
    return x_trj

# Debug your implementation with this example code
# N = 10
# x0 = np.array([0, 0, np.pi, 0])
# u_trj = np.zeros((N-1, n_u))
# x_trj = rollout(x0, u_trj)

# %% [markdown]
# We define the stage cost function $\ell$ and final cost function $\ell_f$. The goal of these cost functions is to drive the vehicle along a circle with radius $r$ around the origin with a desired speed.

# %%
def cost_stage(x, u):
    m = sym if x.dtype == object else np # Check type for autodiff
    n_x = x.shape[0]
    Q = np.array([[500, 0, 0, 0],[0, 1, 0, 0],[0, 0, 500, 0], [0, 0, 0, 1]])
    R = 1
    return (x-x_goal).T@Q@(x-x_goal) + R*(u**2)[0] 

def cost_final(x):
    m = sym if x.dtype == object else np # Check type for autodiff
    n_x = x.shape[0]
    Q = np.array([[500, 0, 0, 0],[0, 1, 0, 0],[0, 0, 500, 0], [0, 0, 0, 1]])
    return (x-x_goal).T@Q@(x-x_goal)

# %% [markdown]
# Your next task is to write the total cost function of the state and control trajectory. This is simply the sum of all stages over the control horizon and the objective from general problem formulation above.

# %%
def cost_trj(x_trj, u_trj):
    total = 0.0
    # Sum up all costs
    N = u_trj.shape[0]+1
    for n in range(N-1):
        total += cost_stage(x_trj[n], u_trj[n]) 
    
    total += cost_final(x_trj[-1])

    return total
    
# # Debug your code
# cost_trj(x_trj, u_trj)

# %% [markdown]
# ### Bellman Recursion
#
# Now that we are warmed up, let's derive the actual algorithm. We start with the Bellman equation known from lecture defining optimality in a recursively backwards in time.
#
# $$\begin{aligned} V(\mathbf{x}[n]) = & \min_{\mathbf{u}[n]} \quad \ell(\mathbf{x}[n], \mathbf{u}[n])  + V(\mathbf{x}[n+1]) \\ \end{aligned}$$
#
# You may have noticed that we neglected a couple of constraints of the original problem formulation. The fully equivalent formulation is
#
# $$\begin{aligned} \min_{\mathbf{u}[n]} \quad & Q(\mathbf{x}[n], \mathbf{u}[n]), \quad \forall n\in[0, N-1] \\ \text{subject to} \quad & Q(\mathbf{x}[n], \mathbf{u}[n]) = \ell(\mathbf{x}[n], \mathbf{u}[n])  + V(\mathbf{x}[n+1]) \\ & V(\mathbf{x}[N]) =   \ell_f(\mathbf{x}[N]) \\ & \mathbf{x}[n+1] = {\bf      f}(\mathbf{x}[n], \mathbf{u}[n]), \quad \\ & \mathbf{x}[0] = \mathbf{x}_0 \end{aligned}$$
#
# The definition of a Q-function will become handy during the derivation of the algorithm.
#
# The key idea of iLQR is simple: Approximate the dynamics linearly and the costs quadratically around a nominal trajectory. We will expand all terms of the Q-function accordingly and optimize the resulting quadratic equation for an optimal linear control law in closed form. We will see that by applying the Bellman equation recursively backwards in time, the value function remains a quadratic.
# The linear and quadratic approximations are computed around the nominal state $\bf \bar{x} = \bf x - \delta \bf x$ and the nominal control $\bf \bar{u} = \bf u - \delta \bf u$. After applying the Bellman equation backwards in time from time $N$ to $0$ (the backward pass), we will update the nominal controls $\bf \bar{u}$ and states $\bf \bar{x}$ by applying the computed linear feedback law from the backward pass and rolling out the dynamics from the initial state $\bf x_0$ to the final horizon $N$. Iterating between backwards and forwards pass optimizes the control problem.
#
# ### Q-function Expansion
#
# Let's start by expanding all terms in the Q-function of the Bellman equation. The quadaratic cost function is
#
# $$\begin{aligned} \ell(\mathbf{x}[n], \mathbf{u}[n]) \approx \ell_n + \begin{bmatrix}\ell_{\mathbf{x},n} \\  \ell_{\mathbf{u},n} \end{bmatrix} ^T  \begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n] \end{bmatrix} + \frac{1}{2}\begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n] \end{bmatrix} ^T \begin{bmatrix}\ell_{\mathbf{xx},n} &  \ell_{\mathbf{ux},n}^T\\ \ell_{\mathbf{ux},n} & \ell_{\mathbf{uu},n}\end{bmatrix} \begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n] \end{bmatrix},\end{aligned}$$
#
# and the dynamics function is
#
# $$\begin{aligned} x[n+1]= \mathbf{f}(\mathbf{x}[n], \mathbf{u}[n]) \approx \mathbf{f}_n + \begin{bmatrix}\mathbf{f}_{\mathbf{x},n} & \mathbf{f}_{\mathbf{u},n} \end{bmatrix}  \begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n] \end{bmatrix}. \end{aligned}$$
#
# Here, $\ell = \ell(\bar{\mathbf{x}}, \bar{\mathbf{u}})$ and $\mathbf{f} = \mathbf{f}(\bar{\mathbf{x}}, \bar{\mathbf{u}})$. $\ell_\mathbf{x}, \ell_\mathbf{u}, \mathbf{f}_\mathbf{x}, \mathbf{f}_\mathbf{u}$ are the gradients and Jacobians evaluated at $\bar{\mathbf{x}}$ and $\bar{\mathbf{u}}$. $\ell_\mathbf{xx}, \ell_\mathbf{ux}, \ell_\mathbf{uu}$ are the Hessians at $\bar{\mathbf{x}}$ and $\bar{\mathbf{u}}$. The expansion of the final cost follows analogously.
# The code to evaluate all the derivative terms is:

# %%
class derivatives():
    def __init__(self, discrete_dynamics, cost_stage, cost_final, n_x, n_u):
        self.x_sym = np.array([sym.Variable("x_{}".format(i)) for i in range(n_x)])
        self.u_sym = np.array([sym.Variable("u_{}".format(i)) for i in range(n_u)])
        # self.t_sym = np.array([sym.Variable("t_{}".format(i)) for i in range(N)])
        x = self.x_sym
        u = self.u_sym
        # t = self.t_sym 

        l = cost_stage(x, u)
        self.l_x = sym.Jacobian([l], x).ravel()
        self.l_u = sym.Jacobian([l], u).ravel()
        self.l_xx = sym.Jacobian(self.l_x, x)
        self.l_ux = sym.Jacobian(self.l_u, x)
        self.l_uu = sym.Jacobian(self.l_u, u)
        
        l_final = cost_final(x)
        self.l_final_x = sym.Jacobian([l_final], x).ravel()
        self.l_final_xx = sym.Jacobian(self.l_final_x, x)
        
        f = discrete_dynamics(x, u)
        self.f_x = sym.Jacobian(f, x)
        self.f_u = sym.Jacobian(f, u)
    
    def stage(self, x, u):
        env = {self.x_sym[i]: x[i] for i in range(x.shape[0])}
        env.update({self.u_sym[i]: u[i] for i in range(u.shape[0])})
        
        l_x = sym.Evaluate(self.l_x, env).ravel()
        l_u = sym.Evaluate(self.l_u, env).ravel()
        l_xx = sym.Evaluate(self.l_xx, env)
        l_ux = sym.Evaluate(self.l_ux, env)
        l_uu = sym.Evaluate(self.l_uu, env)
        
        f_x = sym.Evaluate(self.f_x, env)
        f_u = sym.Evaluate(self.f_u, env)

        return l_x, l_u, l_xx, l_ux, l_uu, f_x, f_u
    
    def final(self, x):
        env = {self.x_sym[i]: x[i] for i in range(x.shape[0])}
        
        l_final_x = sym.Evaluate(self.l_final_x, env).ravel()
        l_final_xx = sym.Evaluate(self.l_final_xx, env)
        
        return l_final_x, l_final_xx
        
# derivs = derivatives(discrete_dynamics, cost_stage, cost_final, n_x, n_u)
derivs = derivatives(rk4singlestep, cost_stage, cost_final, n_x, n_u)

# Test the output:
# x = np.array([0, 0, 0, 0, 0])
# u = np.array([0, 0])
# print(derivs.stage(x, u))
# print(derivs.final(x))

# %%
# # function that returns the A_lin matrix
# def get_A_lin():
#     A = np.array([
#         [0, 1, 0, 0], 
#         [0, -d/m_c, m_p*g/m_c, 0], 
#         [0, 0, 0, 1], 
#         [0, -d/(m_c*l), -(m_c+m_p)*g/(m_c*l), 0]  
#     ])
#     return A

# # function that returns the B_lin matrix
# def get_B_lin():
#     B = np.array([
#         [0], 
#         [1/m_c], 
#         [0], 
#         [1/(m_c*l)]
#     ])
#     return B

# %% [markdown]
# Expanding the second term of the Q-function of the Bellman equation, i.e. the value function at the next state $\mathbf{x}[n+1]$, to second order yields
#
# $$\begin{aligned} V(\mathbf{x}[n+1]) \approx V_{n+1} + V_{\mathbf{x},n+1}^\top  \delta \mathbf{x}[n+1] + \frac{1}{2}\delta \mathbf{x}[n+1]^\top V_{\mathbf{xx},n+1} \delta \mathbf{x}[n+1],\end{aligned}$$
#
# where $\delta \mathbf{x}[n+1]$ is given by
#
# $$\begin{aligned} \delta \mathbf{x}[n+1] & = \mathbf{x}[n+1] - \bar{\mathbf{x}}[n+1] \\ & = \mathbf{f}_n + \begin{bmatrix}\mathbf{f}_{\mathbf{x},n} &  \mathbf{f}_{\mathbf{u},n} \end{bmatrix}  \begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n] \end{bmatrix} -  \bar{\mathbf{x}}[n+1] \\ & = \mathbf{f}_n + \begin{bmatrix}\mathbf{f}_{\mathbf{x},n} & \mathbf{f}_{\mathbf{u},n} \end{bmatrix}  \begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n] \end{bmatrix} -  \mathbf{f}(\bar{\mathbf{x}}[n], \bar{\mathbf{u}}[n]) \\ & = \begin{bmatrix}\mathbf{f}_{\mathbf{x},n} &  \mathbf{f}_{\mathbf{u},n} \end{bmatrix}   \begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n] \end{bmatrix}. \end{aligned}$$
#
# We have now expanded all terms of the Bellman equation and can regroup them in the form of
#
# $$\begin{aligned} Q(\mathbf{x}[n], \mathbf{u}[n]) & \approx \ell_n + \begin{bmatrix}\ell_{\mathbf{x},n} \\  \ell_{\mathbf{u},n} \end{bmatrix} ^\top  \begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n] \end{bmatrix} + \frac{1}{2}\begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n] \end{bmatrix} ^\top \begin{bmatrix}\ell_{\mathbf{xx},n} &  \ell_{\mathbf{ux},n}^\top\\  \ell_{\mathbf{ux},n} & \ell_{\mathbf{uu},n}\end{bmatrix} \begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n] \end{bmatrix}, \\ & \quad + V_{n+1} + V_{\mathbf{x},n+1}^\top  \delta \mathbf{x}[n+1] + \frac{1}{2}\delta \mathbf{x}[n+1]^\top V_{\mathbf{xx},n+1} \delta \mathbf{x}[n+1], \\& = Q_n + \begin{bmatrix} Q_{\mathbf{x},n} \\  Q_{\mathbf{u},n} \end{bmatrix} ^\top  \begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n] \end{bmatrix} + \frac{1}{2}\begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n] \end{bmatrix} ^\top \begin{bmatrix} Q_{\mathbf{xx},n} & Q_{\mathbf{ux},n}^T\\  Q_{\mathbf{ux},n} & Q_{\mathbf{uu},n}\end{bmatrix} \begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n] \end{bmatrix}.\end{aligned}$$
#
# Find $Q_{\mathbf{x},n}$, $Q_{\mathbf{u},n}$, $Q_{\mathbf{xx},n}$, $Q_{\mathbf{ux},n}$, $Q_{\mathbf{uu},n}$ in terms of $\ell$ and $\textbf{f}$ and their expansions by collecitng coefficients in $(\cdot)\delta \mathbf{x}[n]$, $(\cdot)\delta \mathbf{u}[n]$, $1/2 \delta \mathbf{x}[n]^\top (\cdot) \delta \mathbf{x}[n]$, and similar. Write your results in the corresponding function below.

# %% [markdown]
# Answer:
# <br>
# $$Q_{\mathbf{x},n} = \ell_{\mathbf{x},n} + \mathbf{f}_{\mathbf{x},n}^\top V_{\mathbf{x},n+1}
# \\ \\
# Q_{\mathbf{u},n} = \ell_{\mathbf{u},n} + \mathbf{f}_{\mathbf{u},n}^\top V_{\mathbf{x},n+1}
# \\ \\
# Q_{\mathbf{xx},n} = \ell_{\mathbf{xx},n} + \mathbf{f}_{\mathbf{x},n}^\top V_{\mathbf{xx},n+1} \mathbf{f}_{\mathbf{x},n}
# \\ \\
# Q_{\mathbf{uu},n} = \ell_{\mathbf{uu},n} + \mathbf{f}_{\mathbf{u},n}^\top V_{\mathbf{xx},n+1} \mathbf{f}_{\mathbf{u},n}
# \\ \\
# Q_{\mathbf{ux},n} = \ell_{\mathbf{ux},n} + \mathbf{f}_{\mathbf{u},n}^\top V_{\mathbf{xx},n+1} \mathbf{f}_{\mathbf{x},n}
# \\ \\
# Q_{\mathbf{ux},n} = Q_{\mathbf{xu},n}^\top
#
# $$

# %%
def Q_terms(l_x, l_u, l_xx, l_ux, l_uu, f_x, f_u, V_x, V_xx):
    # Define the Q-terms here
    Q_x = l_x + f_x.T@V_x 
    Q_u = l_u + f_u.T@V_x 
    Q_xx = l_xx + f_x.T@V_xx@f_x 
    Q_uu = l_uu + f_u.T@V_xx@f_u 
    Q_ux = l_ux + f_u.T@V_xx@f_x 
    
    return Q_x, Q_u, Q_xx, Q_ux, Q_uu

# %%
def Q_fun(F, C, c, V_xx, V_x, x, u):
    # Define the Q-terms here
    Q = C + F.T@V_xx@F
    q = c + F.T@V_x
    
    q_x = q[0:n_x]
    q_u = q[n_x:]

    Q_xx = Q[0:n_x,0:n_x]
    Q_ux = Q[n_x:, 0:n_x]
    Q_uu = Q[n_x:, n_x:]
    
    return Q_xx, Q_ux, Q_uu, q_x, q_u

# %% [markdown]
# ### Q-function Optimization and Optimal Linear Control Law
# Amazing! Now that we have the Q-function in quadratic form, we can optimize for the optimal control gains in closed form.
# The original formulation, i.e. optimizing over $\mathbf{u}[n]$, $$\begin{aligned} \min_{\mathbf{u}[n]} \quad & Q(\mathbf{x}[n], \mathbf{u}[n]),\end{aligned}$$ is equivalent to optimzing over $\delta \mathbf{u}[n]$.
#
# $$\begin{aligned} \delta \mathbf{u}[n]^* = {\arg\!\min}_{\delta \mathbf{u}[n]} \quad Q_n  + \begin{bmatrix} Q_{\mathbf{x},n} \\  Q_{\mathbf{u},n} \end{bmatrix} ^T  \begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n] \end{bmatrix} + \frac{1}{2}\begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n] \end{bmatrix} ^T \begin{bmatrix} Q_{\mathbf{xx},n} &  Q_{\mathbf{ux},n}^T\\  Q_{\mathbf{ux},n} & Q_{\mathbf{uu},n}\end{bmatrix}\begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n] \end{bmatrix} = k + K \delta \mathbf{x}[n]\end{aligned}$$
#
# It turns out that the optimal control is linear in $\delta \mathbf{x}[n]$.
# Solve the quadratic optimization analytically and derive equations for the feedforward gains $k$ and feedback gains $K$. Implement the function below. Hint: You do not need to compute $Q_\mathbf{uu}^{-1}$ by hand.

# %% [markdown]
# The feedforward gains $k$ and $K$ equal:
# <br>
# $K=-Q_{\mathbf{uu},n}^{-1}Q_{\mathbf{ux},n}$;
# <br>
# $k=-Q_{\mathbf{uu},n}^{-1}Q_{\mathbf{u},n}$

# %%
def gains(Q_uu, Q_u, Q_ux):
    Q_uu_inv = np.linalg.inv(Q_uu)
    # Implement the feedforward gain k and feedback gain K.
    k = -Q_uu_inv@Q_u
    K = -Q_uu_inv@Q_ux
    
    return k, K

# %% [markdown]
# ### Value Function Backward Update
# We are almost done! We need to derive the backwards update equation for the value function. We simply plugin the optimal control $\delta \mathbf{u}[n]^* = k + K \delta \mathbf{x}[n]$ back into the Q-function which yields the value function
#
# $$\begin{aligned} V(\mathbf{x}[n]) \approx V_{n} + V_{\mathbf{x},n}^T  \delta \mathbf{x}[n] + \frac{1}{2}\delta \mathbf{x}[n]^T V_{\mathbf{xx},n} \delta \mathbf{x}[n] = Q_n + \begin{bmatrix} Q_{\mathbf{x},n} \\  Q_{\mathbf{u},n} \end{bmatrix}^T  \begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n]^* \end{bmatrix} + \frac{1}{2}\begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n]^* \end{bmatrix}^T \begin{bmatrix} Q_{\mathbf{xx},n} &  Q_{\mathbf{ux},n}^T\\  Q_{\mathbf{ux},n} & Q_{\mathbf{uu},n}\end{bmatrix} \begin{bmatrix} \delta \mathbf{x}[n] \\ \delta \mathbf{u}[n]^* \end{bmatrix}. \end{aligned}$$
#
# Compare terms in $(\cdot) \delta \mathbf{x}[n]$ and $ 1/2 \delta \mathbf{x}[n]^T (\cdot)  \delta \mathbf{x}[n]$, find $V_{\mathbf{x},n}$, and $V_{\mathbf{xx},n}$ and implement the corresponding function below.
#
# IMPORTANT: Do not simplify the expression you obtain for $V_{x}$ and $V_{xx}$ by assuming that $k$ and $K$ have the form computed by the function `gains`.

# %% [markdown]
# The expression of $V_{\mathbf{x},n}$ and $V_{\mathbf{xx},n}$ are:
# <br>
# <br>
# $V_{\mathbf{x},n} = Q_{\mathbf{x},n} + K^\top Q_{\mathbf{u},n} + Q_{\mathbf{ux},n}^\top k + k^\top Q_{\mathbf{uu},n}$
# <br>
# $V_{\mathbf{xx},n} = Q_{\mathbf{xx},n} + Q_{\mathbf{ux},n}^\top K + K^\top Q_{\mathbf{ux},n}  + K^\top Q_{\mathbf{uu},n} K$

# %%
def V_terms(Q_x, Q_u, Q_xx, Q_ux, Q_uu, K, k):
    # Implement V_x and V_xx, hint: use the A.dot(B) function for matrix multiplcation.

    V_x = Q_x + K.T@Q_u + Q_ux.T@k + k.T@Q_uu@K 
    V_xx = Q_xx + Q_ux.T@K + K.T@Q_ux + K.T@Q_uu@K 
    
    return V_x, V_xx

# %% [markdown]
# ### Expected Cost Reduction
# We can also estimate by how much we expect to reduce the cost by applying the optimal controls. Simply subtract the previous nominal Q-value ($\delta \mathbf{x}[n] = 0$ and $\delta \mathbf{u}[n]=0$) from the value function.  The result is implemented below and is a useful aid in checking how accurate the quadratic approximation is during convergence of iLQR and adapting stepsize and regularization.

# %%
def expected_cost_reduction(Q_u, Q_uu, k):
    return -Q_u.T.dot(k) - 0.5 * k.T.dot(Q_uu.dot(k))

# %% [markdown]
# ## Linearization Error
# The linear model we have built above is very accurate accurate in the vicinity of the equilibrium point, but can lead to very bad predictions if our state is far away from the equilibrium.
#
# The following function, for a given state $\mathbf{x}$ and control $\mathbf{u}$, evaluates the linearization error:
# $$e(\mathbf{x}, \mathbf{u}) = \| {\bf f}(\mathbf{x}, \mathbf{u}) - {\bf f_{\text{lin}}}(\mathbf{x}, \mathbf{u}) \|$$

# %% [markdown]
# ### Forward Pass
# We have now all the ingredients to implement the forward pass and the backward pass of iLQR. In the forward pass, at each timestep the new updated control $\mathbf{u}' =  \bar{\mathbf{u}} + k + K (x' - \bar{\mathbf{x}})$ is applied and the dynamis propagated based on the updated control. The nominal control and state trajectory $\bar{\mathbf{u}}, \bar{\mathbf{x}}$ with which we computed $k$ and $K$ are then updated and we receive a new set of state and control trajectories.

# %% [markdown]
# #### Standard LQR
# for $t = 1:T$
# <br>
# &nbsp; &nbsp; $\mathbf{u}_t = \mathbf{K}_t\mathbf{x}_t+\mathbf{k}_t$
# <br>
# &nbsp; &nbsp; $\mathbf{x}_{t+1} = f(\mathbf{x}_t,\mathbf{u}_t)$

# %%
def forward_pass_lqr(x_trj, u_trj):
    x_trj_new = np.zeros(x_trj.shape)
    x_trj_new[0,:] = x_trj[0,:]
    u_trj_new = np.zeros(u_trj.shape)

    # Implement the forward pass here
    for n in range(u_trj.shape[0]):
        u_trj_new[n,:] = np.dot(-K, (x_trj_new[n]-x_goal))[0] #-K.dot(x_trj_new[n]-x_goal)# Apply feedback law
        x_trj_new[n+1,:] = rk4singlestep(x_trj_new[n], u_trj_new[n])
    return x_trj_new, u_trj_new

# %%
# def forward_pass_lqr(x_trj, u_trj, k_trj, K_trj):
#     x_trj_new = np.zeros(x_trj.shape)
#     x_trj_new[0,:] = x_trj[0,:]
#     u_trj_new = np.zeros(u_trj.shape)

#     # Implement the forward pass here
#     for n in range(u_trj.shape[0]):
#         u_trj_new[n,:] = k_trj[n] + K_trj[n].dot(x_trj_new[n]-x_goal)# Apply feedback law
#         x_trj_new[n+1,:] = rk4singlestep(x_trj_new[n], u_trj_new[n])
#     return x_trj_new, u_trj_new

# %% [markdown]
# #### iLQR
# for $t = 1:T$
# <br>
# &nbsp; &nbsp; $\mathbf{u}_t = \hat{\mathbf{u}}_t + \mathbf{k}_t + \mathbf{K}_t(\mathbf{x}_t-\hat{\mathbf{x}}_t)$
# <br>
# &nbsp; &nbsp; $\mathbf{x}_{t+1} = f(\mathbf{x}_t,\mathbf{u}_t)$

# %%
def forward_pass(x_trj, u_trj, k_trj, K_trj):
    x_trj_new = np.zeros(x_trj.shape)
    x_trj_new[0,:] = x_trj[0,:]
    u_trj_new = np.zeros(u_trj.shape)

    # Implement the forward pass here
    for n in range(u_trj.shape[0]):
        u_trj_new[n,:] = u_trj[n] + k_trj[n] + K_trj[n].dot(x_trj_new[n]-x_trj[n])# Apply feedback law
        # u_trj_new[n,:] = u_trj[n] + k_trj[n] + K_trj[n].dot(x_trj_new[n]-x_goal)# Apply feedback law
        # x_trj_new[n+1,:] = discrete_dynamics(x_trj_new[n], u_trj_new[n])# Apply dynamics
        x_trj_new[n+1,:] = rk4singlestep(x_trj_new[n], u_trj_new[n])
    return x_trj_new, u_trj_new

# %% [markdown]
# ### Backward Pass
# The backward pass starts from the terminal boundary condition $V(\mathbf{x}[N]) =   \ell_f(\mathbf{x}[N])$, such that $V_{\mathbf{x},N} = \ell_{\mathbf{x},f}$ and $V_{\mathbf{xx},N} = \ell_{\mathbf{xx},f}$. In the backwards loop terms for the Q-function at $n$ are computed based on the quadratic value function approximation at $n+1$ and the derivatives and hessians of dynamics and cost functions at $n$. To solve for the gains $k$ and $K$ an inversion of the matrix $Q_\mathbf{uu}$ is necessary. To ensure invertability and to improve conditioning we add a diagonal matrix to $Q_\mathbf{uu}$. This is equivalent to adding a quadratic penalty on the distance of the new control trajectory from the control trajectory of the previous iteration. The result is a smaller stepsize and more conservative convergence properties.

# %%
def backward_pass_lqr(x_trj, u_trj, regu):
    k_trj = np.zeros([u_trj.shape[0], u_trj.shape[1]])
    K_trj = np.zeros([u_trj.shape[0], u_trj.shape[1], x_trj.shape[1]])
    expected_cost_redu = 0
    # Set terminal boundary condition here (V_x, V_xx)
    V_xx = np.zeros((n_x, n_x))
    V_x = np.zeros((n_x))

    Cxx = np.array([[50, 0, 0, 0],[0, 1, 0, 0],[0, 0, 50, 0], [0, 0, 0, 1]])
    Cuu = np.array([[1]])
    C = np.vstack((np.hstack((Cxx, np.zeros([n_x, 1]))), np.hstack((np.zeros([1, n_x]), Cuu))))
    c = np.vstack([np.zeros([n_x,1]), np.zeros([n_u,1])]).reshape(-1)

    F = np.hstack((get_A_lin(), get_B_lin()))
    
    for n in range(u_trj.shape[0]-1, -1, -1):
        # First compute derivatives, then the Q-terms 
        
        Q_xx, Q_ux, Q_uu, q_x, q_u = Q_fun(F, C, c, V_xx, V_x, x_trj[n], u_trj[n])
        # We add regularization to ensure that Q_uu is invertible and nicely conditioned
        # i.e., we apply regularization term to the local cost to account for the non-positive-definite second order 
        # Hessian's computed on the cost:
        Q_uu_regu = Q_uu + np.eye(Q_uu.shape[0])*regu
        k, K = gains(Q_uu_regu, q_u, Q_ux)
        k_trj[n,:] = k
        K_trj[n,:,:] = K
        V_x, V_xx = V_terms(q_x, q_u, Q_xx, Q_ux, Q_uu, K, k)
        expected_cost_redu += expected_cost_reduction(q_u, Q_uu, k)
        
    return k_trj, K_trj, expected_cost_redu

# %%
def backward_pass(x_trj, u_trj, regu):
    k_trj = np.zeros([u_trj.shape[0], u_trj.shape[1]])
    K_trj = np.zeros([u_trj.shape[0], u_trj.shape[1], x_trj.shape[1]])
    expected_cost_redu = 0
    # Set terminal boundary condition here (V_x, V_xx)
    try:
        V_x, V_xx = derivs.final(x_trj[-1])
    except:
        print("error ocurred")
    for n in range(u_trj.shape[0]-1, -1, -1):
        # First compute derivatives, then the Q-terms 
        l_x, l_u, l_xx, l_ux, l_uu, f_x, f_u = derivs.stage(x_trj[n], u_trj[n])
        Q_x, Q_u, Q_xx, Q_ux, Q_uu = Q_terms(l_x, l_u, l_xx, l_ux, l_uu, f_x, f_u, V_x, V_xx)
        # We add regularization to ensure that Q_uu is invertible and nicely conditioned
        # i.e., we apply regularization term to the local cost to account for the non-positive-definite second order 
        # Hessian's computed on the cost:
        Q_uu_regu = Q_uu + np.eye(Q_uu.shape[0])*regu
        k, K = gains(Q_uu_regu, Q_u, Q_ux)
        k_trj[n,:] = k
        K_trj[n,:,:] = K
        V_x, V_xx = V_terms(Q_x, Q_u, Q_xx, Q_ux, Q_uu, K, k)
        expected_cost_redu += expected_cost_reduction(Q_u, Q_uu, k)
    return k_trj, K_trj, expected_cost_redu

# %%
# def backward_pass(x_trj, u_trj, regu):
#     k_trj = np.zeros([u_trj.shape[0], u_trj.shape[1]])
#     K_trj = np.zeros([u_trj.shape[0], u_trj.shape[1], x_trj.shape[1]])
#     expected_cost_redu = 0
#     # Set terminal boundary condition here (V_x, V_xx)
#     V_xx = np.zeros((n_x, n_x))
#     V_x = np.zeros((n_x))

#     for n in range(u_trj.shape[0]-1, -1, -1):
#         # First compute derivatives, then the Q-terms 
#         l_x, l_u, l_xx, l_ux, l_uu, f_x, f_u = derivs.stage(x_trj[n], u_trj[n])
#         if n == u_trj.shape[0]-1:
#             l_x, l_xx = derivs.final(x_trj[-1])
        
#         F = np.hstack((f_x, f_u))
#         c = np.vstack((l_x.reshape(n_x,1), l_u.reshape(n_u,1))).reshape(-1)
#         C = np.vstack((np.hstack((l_xx, l_ux.T)), np.hstack((l_ux, l_uu))))
#         # Q_x, Q_u, Q_xx, Q_ux, Q_uu = Q_terms(l_x, l_u, l_xx, l_ux, l_uu, f_x, f_u, V_x, V_xx)
#         Q_xx, Q_ux, Q_uu, q_x, q_u = Q_fun(F, C, c, V_xx, V_x, x_trj[n], u_trj[n])
#         # We add regularization to ensure that Q_uu is invertible and nicely conditioned
#         # i.e., we apply regularization term to the local cost to account for the non-positive-definite second order 
#         # Hessian's computed on the cost:
#         Q_uu_regu = Q_uu + np.eye(Q_uu.shape[0])*regu
#         k, K = gains(Q_uu_regu, q_u, Q_ux)
#         k_trj[n,:] = k
#         K_trj[n,:,:] = K
#         V_x, V_xx = V_terms(q_x, q_u, Q_xx, Q_ux, Q_uu, K, k)
#         expected_cost_redu += expected_cost_reduction(q_u, Q_uu, k)
        
#     return k_trj, K_trj, expected_cost_redu

# %% [markdown]
# ### Observation model

# %%
def h(x):
    H = np.eye(n_x)
    return H@x

# %% [markdown]
# ### Run EKF

# %%
## Run EKF for single time step
def run_EKF(y, u, m1x_posterior, m2x_posterior, Q, R):
    '''
    INPUTS:
    1. y - measurement data at time step k
    2. u - control at time step k

    OUTPUT:
    1. 
    '''
    #############################################
    ################## Predict ##################
    #############################################
    # Predict the 1-st moment of x
    m1x_prior = rk4singlestep(m1x_posterior, u) #F@m1x_posterior + G@u
    # Compute the Jacobians
    _, _, _, _, _, F, G = derivs.stage(m1x_posterior, u)
    H = np.eye(n_y) #sym.Jacobian([h], m1x_prior).ravel()
    # Predict the 2-nd moment of x
    m2x_prior = F@m2x_posterior
    m2x_prior = m2x_prior@F.T + Q

    # Predict the 1-st moment of y
    m1y = H@m1x_prior
    # Predict the 2-nd moment of y
    m2y = H@m2x_prior
    m2y = m2y@H.T + R

    #############################################
    ################## KGain ####################
    #############################################
    KG = m2x_prior@H.T
    KG = KG@np.linalg.inv(m2y)
    #############################################
    ################# Innovation ################
    #############################################
    dy = y - m1y
    #############################################
    ################# Correct ###################
    #############################################
    # Compute the 1-st posterior moment
    m1x_posterior = m1x_prior + KG@dy
    # Compute the 2-nd posterior moment
    m2x_posterior = m2y@KG.T
    m2x_posterior = m2x_prior - KG@m2x_posterior

    return m1x_posterior, m2x_posterior

# %% [markdown]
# ### Main Loop iLQG
#
# The main iLQR loop consists of iteratively applying the forward and backward pass. The regularization is adapted based on whether the new control and state trajectories improved the cost. We lower the regularization if the total cost was reduced and accept the new trajectory pair. If the total cost did not decrease, the trajectory pair is rejected and the regularization is increased. You may want to test the algorithm with deactivated regularization and observe the changed behavior.
# The main loop stops if the maximum number of iterations is reached or the expected reduction is below a certain threshold.
#
# If you have correctly implemented all subparts of the iLQR you should see that the car plans to drive around the circle.

# %%
def run_ilqr(x0, N, max_iter=50, regu_init=100, alg='ilqr'):
    # First forward rollout
    u_trj = np.random.randn(N-1, n_u)*0.0001
    x_trj = rollout(x0, u_trj)
    total_cost = cost_trj(x_trj, u_trj)
    regu = regu_init
    max_regu = 10000
    min_regu = 0.01
    
    # Setup traces
    cost_trace = [total_cost]
    expected_cost_redu_trace = []
    redu_ratio_trace = [1]
    redu_trace = []
    regu_trace = [regu]
    
    # Run main loop
    for it in range(max_iter):
        # Backward and forward pass
        if alg == 'ilqr':
            k_trj, K_trj, expected_cost_redu = backward_pass(x_trj, u_trj, regu)
            x_trj_new, u_trj_new = forward_pass(x_trj, u_trj, k_trj, K_trj)
        else:
            # k_trj, K_trj, expected_cost_redu = backward_pass_lqr(x_trj, u_trj, regu)
            expected_cost_redu=10
            # x_trj_new, u_trj_new = forward_pass_lqr(x_trj, u_trj)
            x_trj_new = odeint(pendcart, x0, t)
            u_trj_new = np.zeros(u_trj.shape)
            for ii in range(N-1):
                u_trj_new[ii,:] = np.dot(-L, (x_trj_new[ii,:] - x_goal))[0]
            # x_trj_new, u_trj_new = forward_pass_lqr(x_trj, u_trj, k_trj, K_trj)

        # Evaluate new trajectory
        total_cost = cost_trj(x_trj_new, u_trj_new)
        cost_redu = cost_trace[-1] - total_cost
        redu_ratio = cost_redu / abs(expected_cost_redu)
        
        # Accept or reject iteration
        if cost_redu > 0:
            # Improvement! Accept new trajectories and lower regularization
            redu_ratio_trace.append(redu_ratio)
            cost_trace.append(total_cost)
            x_trj = x_trj_new
            u_trj = u_trj_new
            regu *= 0.7
        else:
            # Reject new trajectories and increase regularization
            regu *= 2.0
            cost_trace.append(cost_trace[-1])
            redu_ratio_trace.append(0)

        regu = min(max(regu, min_regu), max_regu)
        regu_trace.append(regu)
        redu_trace.append(cost_redu)

        # Early termination if expected improvement is small
        if expected_cost_redu <= 1e-6:
            break


    return x_trj, u_trj, cost_trace, regu_trace, redu_ratio_trace, redu_trace

# %%
import torch.nn as nn
import torch

# %%
# Init state
m1x_0 = np.array([-2.0, 0.0, 0.3*np.pi, 0.0])
m2x_0 = np.zeros([n_x,n_x])

# LQG params
N_trials = 50

# %% [markdown]
# ### Run LQG

# %%
# LOSS
loss_fn_lqr = nn.MSELoss(reduction='mean')
# MSE [Linear]
MSE_EKF_lqr_arr = torch.empty(N_trials)

# Reset control sequence
u_trj_lqr_new = np.empty([N_trials, num_time_pts-1, n_u])
# Reset state
x_trj_lqr_new = np.empty([N_trials, num_time_pts, n_x])
x_hat_trj_lqr_new = np.empty([N_trials, num_time_pts, n_x])
lqr_cost_arr = np.empty([N_trials])
# Run Monte-Carlo LQG 
for i in range(N_trials):
    # Set init state
    x_trj_lqr_new[i, 0, :] = m1x_0
    x_hat_trj_lqr_new[i, 0, :] = m1x_0

    m1x_posterior = m1x_0
    m2x_posterior = m2x_0
    
    # Init noise for current experiment
    q_noise = Q_noise[i]
    r_noise = R_noise[i]

    # Run LQG over full trajectory
    for k in range(0, num_time_pts-1):
        # Run iLQG
        print("iLQG at time-step: " + str(k) + "\nexperiment: " + str(i+1))
        # Update control sequence
        u_trj_lqr_new[i, k,:] = np.dot(-L, (x_hat_trj_lqr_new[i, k, :] - x_goal))[0]
        # State-Space Evolution
        x_trj_lqr_new[i, k+1, :] = LQG_rk4singlestep(x_hat_trj_lqr_new[i, k, :], u_trj_lqr_new[i, k]) + q_noise[:, k]
        # Measurement model
        y = h(x_trj_lqr_new[i, k+1, :]) + r_noise[:, k]
        # State Estimation
        m1x_posterior, m2x_posterior = run_EKF(y, u_trj_lqr_new[i, k], m1x_posterior, m2x_posterior, W, V)
        x_hat_trj_lqr_new[i, k+1, :] = m1x_posterior

    
    MSE_EKF_lqr_arr[i] = loss_fn_lqr(torch.tensor(x_hat_trj_lqr_new[i, :, :]), torch.tensor(x_trj_lqr_new[i, :, :])).item()    
    lqr_cost_arr[i] = cost_trj(x_trj_lqr_new[i, :, :], u_trj_lqr_new[i, :])/N_trials

MSE_EKF_linear_avg = torch.mean(MSE_EKF_lqr_arr)
MSE_EKF_dB_avg = 10 * torch.log10(MSE_EKF_linear_avg)

LQG_cost_dB = 10*np.log10(lqr_cost_arr.mean())

print("EKF - MSE LOSS:", MSE_EKF_dB_avg, "[dB]")
print("LQG cost:", LQG_cost_dB, "[dB]")
print("Finished LQG simulation")
# Out:
# iLQG at time-step: 0
# experiment: 1
# iLQG at time-step: 1
# experiment: 1
# iLQG at time-step: 2
# experiment: 1
# iLQG at time-step: 3
# experiment: 1
# iLQG at time-step: 4
# experiment: 1
# iLQG at time-step: 5
# experiment: 1
# iLQG at time-step: 6
# experiment: 1
# iLQG at time-step: 7
# experiment: 1
# iLQG at time-step: 8
# experiment: 1
# iLQG at time-step: 9
# experiment: 1
# iLQG at time-step: 10
# experiment: 1
# iLQG at time-step: 11
# experiment: 1
# iLQG at time-step: 12
# experiment: 1
# iLQG at time-step: 13
# experiment: 1
# iLQG at time-step: 14
# experiment: 1
# iLQG at time-step: 15
# experiment: 1
# iLQG at time-step: 16
# experiment: 1
# iLQG at time-step: 17
# experiment: 1
# iLQG at time-step: 18
# experiment: 1
# iLQG at time-step: 19
# experiment: 1
# iLQG at time-step: 20
# experiment: 1
# iLQG at time-step: 21
# experiment: 1
# iLQG at time-step: 22
# experiment: 1
# iLQG at time-step: 23
# experiment: 1
# iLQG at time-step: 24
# experiment: 1
# iLQG at time-step: 25
# experiment: 1
# iLQG at time-step: 26
# experiment: 1
# iLQG at time-step: 27
# experiment: 1
# iLQG at time-step: 28
# experiment: 1
# iLQG at time-step: 29
# experiment: 1
# iLQG at time-step: 30
# experiment: 1
# iLQG at time-step: 31
# experiment: 1
# iLQG at time-step: 32
# experiment: 1
# iLQG at time-step: 33
# experiment: 1
# iLQG at time-step: 34
# experiment: 1
# iLQG at time-step: 35
# experiment: 1
# iLQG at time-step: 36
# experiment: 1
# iLQG at time-step: 37
# experiment: 1
# iLQG at time-step: 38
# experiment: 1
# iLQG at time-step: 39
# experiment: 1
# iLQG at time-step: 40
# experiment: 1
# iLQG at time-step: 41
# experiment: 1
# iLQG at time-step: 42
# experiment: 1
# iLQG at time-step: 43
# experiment: 1
# iLQG at time-step: 44
# experiment: 1
# iLQG at time-step: 45
# experiment: 1
# iLQG at time-step: 46
# experiment: 1
# iLQG at time-step: 47
# experiment: 1
# iLQG at time-step: 48
# experiment: 1
# iLQG at time-step: 0
# experiment: 2
# iLQG at time-step: 1
# experiment: 2
# iLQG at time-step: 2
# experiment: 2
# iLQG at time-step: 3
# experiment: 2
# iLQG at time-step: 4
# experiment: 2
# iLQG at time-step: 5
# experiment: 2
# iLQG at time-step: 6
# experiment: 2
# iLQG at time-step: 7
# experiment: 2
# iLQG at time-step: 8
# experiment: 2
# iLQG at time-step: 9
# experiment: 2
# iLQG at time-step: 10
# experiment: 2
# iLQG at time-step: 11
# experiment: 2
# iLQG at time-step: 12
# experiment: 2
# iLQG at time-step: 13
# experiment: 2
# iLQG at time-step: 14
# experiment: 2
# iLQG at time-step: 15
# experiment: 2
# iLQG at time-step: 16
# experiment: 2
# iLQG at time-step: 17
# experiment: 2
# iLQG at time-step: 18
# experiment: 2
# iLQG at time-step: 19
# experiment: 2
# iLQG at time-step: 20
# experiment: 2
# iLQG at time-step: 21
# experiment: 2
# iLQG at time-step: 22
# experiment: 2
# iLQG at time-step: 23
# experiment: 2
# iLQG at time-step: 24
# experiment: 2
# iLQG at time-step: 25
# experiment: 2
# iLQG at time-step: 26
# experiment: 2
# iLQG at time-step: 27
# experiment: 2
# iLQG at time-step: 28
# experiment: 2
# iLQG at time-step: 29
# experiment: 2
# iLQG at time-step: 30
# experiment: 2
# iLQG at time-step: 31
# experiment: 2
# iLQG at time-step: 32
# experiment: 2
# iLQG at time-step: 33
# experiment: 2
# iLQG at time-step: 34
# experiment: 2
# iLQG at time-step: 35
# experiment: 2
# iLQG at time-step: 36
# experiment: 2
# iLQG at time-step: 37
# experiment: 2
# iLQG at time-step: 38
# experiment: 2
# iLQG at time-step: 39
# experiment: 2
# iLQG at time-step: 40
# experiment: 2
# iLQG at time-step: 41
# experiment: 2
# iLQG at time-step: 42
# experiment: 2
# iLQG at time-step: 43
# experiment: 2
# iLQG at time-step: 44
# experiment: 2
# iLQG at time-step: 45
# experiment: 2
# iLQG at time-step: 46
# experiment: 2
# iLQG at time-step: 47
# experiment: 2
# iLQG at time-step: 48
# experiment: 2
# iLQG at time-step: 0
# experiment: 3
# iLQG at time-step: 1
# experiment: 3
# iLQG at time-step: 2
# experiment: 3
# iLQG at time-step: 3
# experiment: 3
# iLQG at time-step: 4
# experiment: 3
# iLQG at time-step: 5
# experiment: 3
# iLQG at time-step: 6
# experiment: 3
# iLQG at time-step: 7
# experiment: 3
# iLQG at time-step: 8
# experiment: 3
# iLQG at time-step: 9
# experiment: 3
# iLQG at time-step: 10
# experiment: 3
# iLQG at time-step: 11
# experiment: 3
# iLQG at time-step: 12
# experiment: 3
# iLQG at time-step: 13
# experiment: 3
# iLQG at time-step: 14
# experiment: 3
# iLQG at time-step: 15
# experiment: 3
# iLQG at time-step: 16
# experiment: 3
# iLQG at time-step: 17
# experiment: 3
# iLQG at time-step: 18
# experiment: 3
# iLQG at time-step: 19
# experiment: 3
# iLQG at time-step: 20
# experiment: 3
# iLQG at time-step: 21
# experiment: 3
# iLQG at time-step: 22
# experiment: 3
# iLQG at time-step: 23
# experiment: 3
# iLQG at time-step: 24
# experiment: 3
# iLQG at time-step: 25
# experiment: 3
# iLQG at time-step: 26
# experiment: 3
# iLQG at time-step: 27
# experiment: 3
# iLQG at time-step: 28
# experiment: 3
# iLQG at time-step: 29
# experiment: 3
# iLQG at time-step: 30
# experiment: 3
# iLQG at time-step: 31
# experiment: 3
# iLQG at time-step: 32
# experiment: 3
# iLQG at time-step: 33
# experiment: 3
# iLQG at time-step: 34
# experiment: 3
# iLQG at time-step: 35
# experiment: 3
# iLQG at time-step: 36
# experiment: 3
# iLQG at time-step: 37
# experiment: 3
# iLQG at time-step: 38
# experiment: 3
# iLQG at time-step: 39
# experiment: 3
# iLQG at time-step: 40
# experiment: 3
# iLQG at time-step: 41
# experiment: 3
# iLQG at time-step: 42
# experiment: 3
# iLQG at time-step: 43
# experiment: 3
# iLQG at time-step: 44
# experiment: 3
# iLQG at time-step: 45
# experiment: 3
# iLQG at time-step: 46
# experiment: 3
# iLQG at time-step: 47
# experiment: 3
# iLQG at time-step: 48
# experiment: 3
# iLQG at time-step: 0
# experiment: 4
# iLQG at time-step: 1
# experiment: 4
# iLQG at time-step: 2
# experiment: 4
# iLQG at time-step: 3
# experiment: 4
# iLQG at time-step: 4
# experiment: 4
# iLQG at time-step: 5
# experiment: 4
# iLQG at time-step: 6
# experiment: 4
# iLQG at time-step: 7
# experiment: 4
# iLQG at time-step: 8
# experiment: 4
# iLQG at time-step: 9
# experiment: 4
# iLQG at time-step: 10
# experiment: 4
# iLQG at time-step: 11
# experiment: 4
# iLQG at time-step: 12
# experiment: 4
# iLQG at time-step: 13
# experiment: 4
# iLQG at time-step: 14
# experiment: 4
# iLQG at time-step: 15
# experiment: 4
# iLQG at time-step: 16
# experiment: 4
# iLQG at time-step: 17
# experiment: 4
# iLQG at time-step: 18
# experiment: 4
# iLQG at time-step: 19
# experiment: 4
# iLQG at time-step: 20
# experiment: 4
# iLQG at time-step: 21
# experiment: 4
# iLQG at time-step: 22
# experiment: 4
# iLQG at time-step: 23
# experiment: 4
# iLQG at time-step: 24
# experiment: 4
# iLQG at time-step: 25
# experiment: 4
# iLQG at time-step: 26
# experiment: 4
# iLQG at time-step: 27
# experiment: 4
# iLQG at time-step: 28
# experiment: 4
# iLQG at time-step: 29
# experiment: 4
# iLQG at time-step: 30
# experiment: 4
# iLQG at time-step: 31
# experiment: 4
# iLQG at time-step: 32
# experiment: 4
# iLQG at time-step: 33
# experiment: 4
# iLQG at time-step: 34
# experiment: 4
# iLQG at time-step: 35
# experiment: 4
# iLQG at time-step: 36
# experiment: 4
# iLQG at time-step: 37
# experiment: 4
# iLQG at time-step: 38
# experiment: 4
# iLQG at time-step: 39
# experiment: 4
# iLQG at time-step: 40
# experiment: 4
# iLQG at time-step: 41
# experiment: 4
# iLQG at time-step: 42
# experiment: 4
# iLQG at time-step: 43
# experiment: 4
# iLQG at time-step: 44
# experiment: 4
# iLQG at time-step: 45
# experiment: 4
# iLQG at time-step: 46
# experiment: 4
# iLQG at time-step: 47
# experiment: 4
# iLQG at time-step: 48
# experiment: 4
# iLQG at time-step: 0
# experiment: 5
# iLQG at time-step: 1
# experiment: 5
# iLQG at time-step: 2
# experiment: 5
# iLQG at time-step: 3
# experiment: 5
# iLQG at time-step: 4
# experiment: 5
# iLQG at time-step: 5
# experiment: 5
# iLQG at time-step: 6
# experiment: 5
# iLQG at time-step: 7
# experiment: 5
# iLQG at time-step: 8
# experiment: 5
# iLQG at time-step: 9
# experiment: 5
# iLQG at time-step: 10
# experiment: 5
# iLQG at time-step: 11
# experiment: 5
# iLQG at time-step: 12
# experiment: 5
# iLQG at time-step: 13
# experiment: 5
# iLQG at time-step: 14
# experiment: 5
# iLQG at time-step: 15
# experiment: 5
# iLQG at time-step: 16
# experiment: 5
# iLQG at time-step: 17
# experiment: 5
# iLQG at time-step: 18
# experiment: 5
# iLQG at time-step: 19
# experiment: 5
# iLQG at time-step: 20
# experiment: 5
# iLQG at time-step: 21
# experiment: 5
# iLQG at time-step: 22
# experiment: 5
# iLQG at time-step: 23
# experiment: 5
# iLQG at time-step: 24
# experiment: 5
# iLQG at time-step: 25
# experiment: 5
# iLQG at time-step: 26
# experiment: 5
# iLQG at time-step: 27
# experiment: 5
# iLQG at time-step: 28
# experiment: 5
# iLQG at time-step: 29
# experiment: 5
# iLQG at time-step: 30
# experiment: 5
# iLQG at time-step: 31
# experiment: 5
# iLQG at time-step: 32
# experiment: 5
# iLQG at time-step: 33
# experiment: 5
# iLQG at time-step: 34
# experiment: 5
# iLQG at time-step: 35
# experiment: 5
# iLQG at time-step: 36
# experiment: 5
# iLQG at time-step: 37
# experiment: 5
# iLQG at time-step: 38
# experiment: 5
# iLQG at time-step: 39
# experiment: 5
# iLQG at time-step: 40
# experiment: 5
# iLQG at time-step: 41
# experiment: 5
# iLQG at time-step: 42
# experiment: 5
# iLQG at time-step: 43
# experiment: 5
# iLQG at time-step: 44
# experiment: 5
# iLQG at time-step: 45
# experiment: 5
# iLQG at time-step: 46
# experiment: 5
# iLQG at time-step: 47
# experiment: 5
# iLQG at time-step: 48
# experiment: 5
# iLQG at time-step: 0
# experiment: 6
# iLQG at time-step: 1
# experiment: 6
# iLQG at time-step: 2
# experiment: 6
# iLQG at time-step: 3
# experiment: 6
# iLQG at time-step: 4
# experiment: 6
# iLQG at time-step: 5
# experiment: 6
# iLQG at time-step: 6
# experiment: 6
# iLQG at time-step: 7
# experiment: 6
# iLQG at time-step: 8
# experiment: 6
# iLQG at time-step: 9
# experiment: 6
# iLQG at time-step: 10
# experiment: 6
# iLQG at time-step: 11
# experiment: 6
# iLQG at time-step: 12
# experiment: 6
# iLQG at time-step: 13
# experiment: 6
# iLQG at time-step: 14
# experiment: 6
# iLQG at time-step: 15
# experiment: 6
# iLQG at time-step: 16
# experiment: 6
# iLQG at time-step: 17
# experiment: 6
# iLQG at time-step: 18
# experiment: 6
# iLQG at time-step: 19
# experiment: 6
# iLQG at time-step: 20
# experiment: 6
# iLQG at time-step: 21
# experiment: 6
# iLQG at time-step: 22
# experiment: 6
# iLQG at time-step: 23
# experiment: 6
# iLQG at time-step: 24
# experiment: 6
# iLQG at time-step: 25
# experiment: 6
# iLQG at time-step: 26
# experiment: 6
# iLQG at time-step: 27
# experiment: 6
# iLQG at time-step: 28
# experiment: 6
# iLQG at time-step: 29
# experiment: 6
# iLQG at time-step: 30
# experiment: 6
# iLQG at time-step: 31
# experiment: 6
# iLQG at time-step: 32
# experiment: 6
# iLQG at time-step: 33
# experiment: 6
# iLQG at time-step: 34
# experiment: 6
# iLQG at time-step: 35
# experiment: 6
# iLQG at time-step: 36
# experiment: 6
# iLQG at time-step: 37
# experiment: 6
# iLQG at time-step: 38
# experiment: 6
# iLQG at time-step: 39
# experiment: 6
# iLQG at time-step: 40
# experiment: 6
# iLQG at time-step: 41
# experiment: 6
# iLQG at time-step: 42
# experiment: 6
# iLQG at time-step: 43
# experiment: 6
# iLQG at time-step: 44
# experiment: 6
# iLQG at time-step: 45
# experiment: 6
# iLQG at time-step: 46
# experiment: 6
# iLQG at time-step: 47
# experiment: 6
# iLQG at time-step: 48
# experiment: 6
# iLQG at time-step: 0
# experiment: 7
# iLQG at time-step: 1
# experiment: 7
# iLQG at time-step: 2
# experiment: 7
# iLQG at time-step: 3
# experiment: 7
# iLQG at time-step: 4
# experiment: 7
# iLQG at time-step: 5
# experiment: 7
# iLQG at time-step: 6
# experiment: 7
# iLQG at time-step: 7
# experiment: 7
# iLQG at time-step: 8
# experiment: 7
# iLQG at time-step: 9
# experiment: 7
# iLQG at time-step: 10
# experiment: 7
# iLQG at time-step: 11
# experiment: 7
# iLQG at time-step: 12
# experiment: 7
# iLQG at time-step: 13
# experiment: 7
# iLQG at time-step: 14
# experiment: 7
# iLQG at time-step: 15
# experiment: 7
# iLQG at time-step: 16
# experiment: 7
# iLQG at time-step: 17
# experiment: 7
# iLQG at time-step: 18
# experiment: 7
# iLQG at time-step: 19
# experiment: 7
# iLQG at time-step: 20
# experiment: 7
# iLQG at time-step: 21
# experiment: 7
# iLQG at time-step: 22
# experiment: 7
# iLQG at time-step: 23
# experiment: 7
# iLQG at time-step: 24
# experiment: 7
# iLQG at time-step: 25
# experiment: 7
# iLQG at time-step: 26
# experiment: 7
# iLQG at time-step: 27
# experiment: 7
# iLQG at time-step: 28
# experiment: 7
# iLQG at time-step: 29
# experiment: 7
# iLQG at time-step: 30
# experiment: 7
# iLQG at time-step: 31
# experiment: 7
# iLQG at time-step: 32
# experiment: 7
# iLQG at time-step: 33
# experiment: 7
# iLQG at time-step: 34
# experiment: 7
# iLQG at time-step: 35
# experiment: 7
# iLQG at time-step: 36
# experiment: 7
# iLQG at time-step: 37
# experiment: 7
# iLQG at time-step: 38
# experiment: 7
# iLQG at time-step: 39
# experiment: 7
# iLQG at time-step: 40
# experiment: 7
# iLQG at time-step: 41
# experiment: 7
# iLQG at time-step: 42
# experiment: 7
# iLQG at time-step: 43
# experiment: 7
# iLQG at time-step: 44
# experiment: 7
# iLQG at time-step: 45
# experiment: 7
# iLQG at time-step: 46
# experiment: 7
# iLQG at time-step: 47
# experiment: 7
# iLQG at time-step: 48
# experiment: 7
# iLQG at time-step: 0
# experiment: 8
# iLQG at time-step: 1
# experiment: 8
# iLQG at time-step: 2
# experiment: 8
# iLQG at time-step: 3
# experiment: 8
# iLQG at time-step: 4
# experiment: 8
# iLQG at time-step: 5
# experiment: 8
# iLQG at time-step: 6
# experiment: 8
# iLQG at time-step: 7
# experiment: 8
# iLQG at time-step: 8
# experiment: 8
# iLQG at time-step: 9
# experiment: 8
# iLQG at time-step: 10
# experiment: 8
# iLQG at time-step: 11
# experiment: 8
# iLQG at time-step: 12
# experiment: 8
# iLQG at time-step: 13
# experiment: 8
# iLQG at time-step: 14
# experiment: 8
# iLQG at time-step: 15
# experiment: 8
# iLQG at time-step: 16
# experiment: 8
# iLQG at time-step: 17
# experiment: 8
# iLQG at time-step: 18
# experiment: 8
# iLQG at time-step: 19
# experiment: 8
# iLQG at time-step: 20
# experiment: 8
# iLQG at time-step: 21
# experiment: 8
# iLQG at time-step: 22
# experiment: 8
# iLQG at time-step: 23
# experiment: 8
# iLQG at time-step: 24
# experiment: 8
# iLQG at time-step: 25
# experiment: 8
# iLQG at time-step: 26
# experiment: 8
# iLQG at time-step: 27
# experiment: 8
# iLQG at time-step: 28
# experiment: 8
# iLQG at time-step: 29
# experiment: 8
# iLQG at time-step: 30
# experiment: 8
# iLQG at time-step: 31
# experiment: 8
# iLQG at time-step: 32
# experiment: 8
# iLQG at time-step: 33
# experiment: 8
# iLQG at time-step: 34
# experiment: 8
# iLQG at time-step: 35
# experiment: 8
# iLQG at time-step: 36
# experiment: 8
# iLQG at time-step: 37
# experiment: 8
# iLQG at time-step: 38
# experiment: 8
# iLQG at time-step: 39
# experiment: 8
# iLQG at time-step: 40
# experiment: 8
# iLQG at time-step: 41
# experiment: 8
# iLQG at time-step: 42
# experiment: 8
# iLQG at time-step: 43
# experiment: 8
# iLQG at time-step: 44
# experiment: 8
# iLQG at time-step: 45
# experiment: 8
# iLQG at time-step: 46
# experiment: 8
# iLQG at time-step: 47
# experiment: 8
# iLQG at time-step: 48
# experiment: 8
# iLQG at time-step: 0
# experiment: 9
# iLQG at time-step: 1
# experiment: 9
# iLQG at time-step: 2
# experiment: 9
# iLQG at time-step: 3
# experiment: 9
# iLQG at time-step: 4
# experiment: 9
# iLQG at time-step: 5
# experiment: 9
# iLQG at time-step: 6
# experiment: 9
# iLQG at time-step: 7
# experiment: 9
# iLQG at time-step: 8
# experiment: 9
# iLQG at time-step: 9
# experiment: 9
# iLQG at time-step: 10
# experiment: 9
# iLQG at time-step: 11
# experiment: 9
# iLQG at time-step: 12
# experiment: 9
# iLQG at time-step: 13
# experiment: 9
# iLQG at time-step: 14
# experiment: 9
# iLQG at time-step: 15
# experiment: 9
# iLQG at time-step: 16
# experiment: 9
# iLQG at time-step: 17
# experiment: 9
# iLQG at time-step: 18
# experiment: 9
# iLQG at time-step: 19
# experiment: 9
# iLQG at time-step: 20
# experiment: 9
# iLQG at time-step: 21
# experiment: 9
# iLQG at time-step: 22
# experiment: 9
# iLQG at time-step: 23
# experiment: 9
# iLQG at time-step: 24
# experiment: 9
# iLQG at time-step: 25
# experiment: 9
# iLQG at time-step: 26
# experiment: 9
# iLQG at time-step: 27
# experiment: 9
# iLQG at time-step: 28
# experiment: 9
# iLQG at time-step: 29
# experiment: 9
# iLQG at time-step: 30
# experiment: 9
# iLQG at time-step: 31
# experiment: 9
# iLQG at time-step: 32
# experiment: 9
# iLQG at time-step: 33
# experiment: 9
# iLQG at time-step: 34
# experiment: 9
# iLQG at time-step: 35
# experiment: 9
# iLQG at time-step: 36
# experiment: 9
# iLQG at time-step: 37
# experiment: 9
# iLQG at time-step: 38
# experiment: 9
# iLQG at time-step: 39
# experiment: 9
# iLQG at time-step: 40
# experiment: 9
# iLQG at time-step: 41
# experiment: 9
# iLQG at time-step: 42
# experiment: 9
# iLQG at time-step: 43
# experiment: 9
# iLQG at time-step: 44
# experiment: 9
# iLQG at time-step: 45
# experiment: 9
# iLQG at time-step: 46
# experiment: 9
# iLQG at time-step: 47
# experiment: 9
# iLQG at time-step: 48
# experiment: 9
# iLQG at time-step: 0
# experiment: 10
# iLQG at time-step: 1
# experiment: 10
# iLQG at time-step: 2
# experiment: 10
# iLQG at time-step: 3
# experiment: 10
# iLQG at time-step: 4
# experiment: 10
# iLQG at time-step: 5
# experiment: 10
# iLQG at time-step: 6
# experiment: 10
# iLQG at time-step: 7
# experiment: 10
# iLQG at time-step: 8
# experiment: 10
# iLQG at time-step: 9
# experiment: 10
# iLQG at time-step: 10
# experiment: 10
# iLQG at time-step: 11
# experiment: 10
# iLQG at time-step: 12
# experiment: 10
# iLQG at time-step: 13
# experiment: 10
# iLQG at time-step: 14
# experiment: 10
# iLQG at time-step: 15
# experiment: 10
# iLQG at time-step: 16
# experiment: 10
# iLQG at time-step: 17
# experiment: 10
# iLQG at time-step: 18
# experiment: 10
# iLQG at time-step: 19
# experiment: 10
# iLQG at time-step: 20
# experiment: 10
# iLQG at time-step: 21
# experiment: 10
# iLQG at time-step: 22
# experiment: 10
# iLQG at time-step: 23
# experiment: 10
# iLQG at time-step: 24
# experiment: 10
# iLQG at time-step: 25
# experiment: 10
# iLQG at time-step: 26
# experiment: 10
# iLQG at time-step: 27
# experiment: 10
# iLQG at time-step: 28
# experiment: 10
# iLQG at time-step: 29
# experiment: 10
# iLQG at time-step: 30
# experiment: 10
# iLQG at time-step: 31
# experiment: 10
# iLQG at time-step: 32
# experiment: 10
# iLQG at time-step: 33
# experiment: 10
# iLQG at time-step: 34
# experiment: 10
# iLQG at time-step: 35
# experiment: 10
# iLQG at time-step: 36
# experiment: 10
# iLQG at time-step: 37
# experiment: 10
# iLQG at time-step: 38
# experiment: 10
# iLQG at time-step: 39
# experiment: 10
# iLQG at time-step: 40
# experiment: 10
# iLQG at time-step: 41
# experiment: 10
# iLQG at time-step: 42
# experiment: 10
# iLQG at time-step: 43
# experiment: 10
# iLQG at time-step: 44
# experiment: 10
# iLQG at time-step: 45
# experiment: 10
# iLQG at time-step: 46
# experiment: 10
# iLQG at time-step: 47
# experiment: 10
# iLQG at time-step: 48
# experiment: 10
# iLQG at time-step: 0
# experiment: 11
# iLQG at time-step: 1
# experiment: 11
# iLQG at time-step: 2
# experiment: 11
# iLQG at time-step: 3
# experiment: 11
# iLQG at time-step: 4
# experiment: 11
# iLQG at time-step: 5
# experiment: 11
# iLQG at time-step: 6
# experiment: 11
# iLQG at time-step: 7
# experiment: 11
# iLQG at time-step: 8
# experiment: 11
# iLQG at time-step: 9
# experiment: 11
# iLQG at time-step: 10
# experiment: 11
# iLQG at time-step: 11
# experiment: 11
# iLQG at time-step: 12
# experiment: 11
# iLQG at time-step: 13
# experiment: 11
# iLQG at time-step: 14
# experiment: 11
# iLQG at time-step: 15
# experiment: 11
# iLQG at time-step: 16
# experiment: 11
# iLQG at time-step: 17
# experiment: 11
# iLQG at time-step: 18
# experiment: 11
# iLQG at time-step: 19
# experiment: 11
# iLQG at time-step: 20
# experiment: 11
# iLQG at time-step: 21
# experiment: 11
# iLQG at time-step: 22
# experiment: 11
# iLQG at time-step: 23
# experiment: 11
# iLQG at time-step: 24
# experiment: 11
# iLQG at time-step: 25
# experiment: 11
# iLQG at time-step: 26
# experiment: 11
# iLQG at time-step: 27
# experiment: 11
# iLQG at time-step: 28
# experiment: 11
# iLQG at time-step: 29
# experiment: 11
# iLQG at time-step: 30
# experiment: 11
# iLQG at time-step: 31
# experiment: 11
# iLQG at time-step: 32
# experiment: 11
# iLQG at time-step: 33
# experiment: 11
# iLQG at time-step: 34
# experiment: 11
# iLQG at time-step: 35
# experiment: 11
# iLQG at time-step: 36
# experiment: 11
# iLQG at time-step: 37
# experiment: 11
# iLQG at time-step: 38
# experiment: 11
# iLQG at time-step: 39
# experiment: 11
# iLQG at time-step: 40
# experiment: 11
# iLQG at time-step: 41
# experiment: 11
# iLQG at time-step: 42
# experiment: 11
# iLQG at time-step: 43
# experiment: 11
# iLQG at time-step: 44
# experiment: 11
# iLQG at time-step: 45
# experiment: 11
# iLQG at time-step: 46
# experiment: 11
# iLQG at time-step: 47
# experiment: 11
# iLQG at time-step: 48
# experiment: 11
# iLQG at time-step: 0
# experiment: 12
# iLQG at time-step: 1
# experiment: 12
# iLQG at time-step: 2
# experiment: 12
# iLQG at time-step: 3
# experiment: 12
# iLQG at time-step: 4
# experiment: 12
# iLQG at time-step: 5
# experiment: 12
# iLQG at time-step: 6
# experiment: 12
# iLQG at time-step: 7
# experiment: 12
# iLQG at time-step: 8
# experiment: 12
# iLQG at time-step: 9
# experiment: 12
# iLQG at time-step: 10
# experiment: 12
# iLQG at time-step: 11
# experiment: 12
# iLQG at time-step: 12
# experiment: 12
# iLQG at time-step: 13
# experiment: 12
# iLQG at time-step: 14
# experiment: 12
# iLQG at time-step: 15
# experiment: 12
# iLQG at time-step: 16
# experiment: 12
# iLQG at time-step: 17
# experiment: 12
# iLQG at time-step: 18
# experiment: 12
# iLQG at time-step: 19
# experiment: 12
# iLQG at time-step: 20
# experiment: 12
# iLQG at time-step: 21
# experiment: 12
# iLQG at time-step: 22
# experiment: 12
# iLQG at time-step: 23
# experiment: 12
# iLQG at time-step: 24
# experiment: 12
# iLQG at time-step: 25
# experiment: 12
# iLQG at time-step: 26
# experiment: 12
# iLQG at time-step: 27
# experiment: 12
# iLQG at time-step: 28
# experiment: 12
# iLQG at time-step: 29
# experiment: 12
# iLQG at time-step: 30
# experiment: 12
# iLQG at time-step: 31
# experiment: 12
# iLQG at time-step: 32
# experiment: 12
# iLQG at time-step: 33
# experiment: 12
# iLQG at time-step: 34
# experiment: 12
# iLQG at time-step: 35
# experiment: 12
# iLQG at time-step: 36
# experiment: 12
# iLQG at time-step: 37
# experiment: 12
# iLQG at time-step: 38
# experiment: 12
# iLQG at time-step: 39
# experiment: 12
# iLQG at time-step: 40
# experiment: 12
# iLQG at time-step: 41
# experiment: 12
# iLQG at time-step: 42
# experiment: 12
# iLQG at time-step: 43
# experiment: 12
# iLQG at time-step: 44
# experiment: 12
# iLQG at time-step: 45
# experiment: 12
# iLQG at time-step: 46
# experiment: 12
# iLQG at time-step: 47
# experiment: 12
# iLQG at time-step: 48
# experiment: 12
# iLQG at time-step: 0
# experiment: 13
# iLQG at time-step: 1
# experiment: 13
# iLQG at time-step: 2
# experiment: 13
# iLQG at time-step: 3
# experiment: 13
# iLQG at time-step: 4
# experiment: 13
# iLQG at time-step: 5
# experiment: 13
# iLQG at time-step: 6
# experiment: 13
# iLQG at time-step: 7
# experiment: 13
# iLQG at time-step: 8
# experiment: 13
# iLQG at time-step: 9
# experiment: 13
# iLQG at time-step: 10
# experiment: 13
# iLQG at time-step: 11
# experiment: 13
# iLQG at time-step: 12
# experiment: 13
# iLQG at time-step: 13
# experiment: 13
# iLQG at time-step: 14
# experiment: 13
# iLQG at time-step: 15
# experiment: 13
# iLQG at time-step: 16
# experiment: 13
# iLQG at time-step: 17
# experiment: 13
# iLQG at time-step: 18
# experiment: 13
# iLQG at time-step: 19
# experiment: 13
# iLQG at time-step: 20
# experiment: 13
# iLQG at time-step: 21
# experiment: 13
# iLQG at time-step: 22
# experiment: 13
# iLQG at time-step: 23
# experiment: 13
# iLQG at time-step: 24
# experiment: 13
# iLQG at time-step: 25
# experiment: 13
# iLQG at time-step: 26
# experiment: 13
# iLQG at time-step: 27
# experiment: 13
# iLQG at time-step: 28
# experiment: 13
# iLQG at time-step: 29
# experiment: 13
# iLQG at time-step: 30
# experiment: 13
# iLQG at time-step: 31
# experiment: 13
# iLQG at time-step: 32
# experiment: 13
# iLQG at time-step: 33
# experiment: 13
# iLQG at time-step: 34
# experiment: 13
# iLQG at time-step: 35
# experiment: 13
# iLQG at time-step: 36
# experiment: 13
# iLQG at time-step: 37
# experiment: 13
# iLQG at time-step: 38
# experiment: 13
# iLQG at time-step: 39
# experiment: 13
# iLQG at time-step: 40
# experiment: 13
# iLQG at time-step: 41
# experiment: 13
# iLQG at time-step: 42
# experiment: 13
# iLQG at time-step: 43
# experiment: 13
# iLQG at time-step: 44
# experiment: 13
# iLQG at time-step: 45
# experiment: 13
# iLQG at time-step: 46
# experiment: 13
# iLQG at time-step: 47
# experiment: 13
# iLQG at time-step: 48
# experiment: 13
# iLQG at time-step: 0
# experiment: 14
# iLQG at time-step: 1
# experiment: 14
# iLQG at time-step: 2
# experiment: 14
# iLQG at time-step: 3
# experiment: 14
# iLQG at time-step: 4
# experiment: 14
# iLQG at time-step: 5
# experiment: 14
# iLQG at time-step: 6
# experiment: 14
# iLQG at time-step: 7
# experiment: 14
# iLQG at time-step: 8
# experiment: 14
# iLQG at time-step: 9
# experiment: 14
# iLQG at time-step: 10
# experiment: 14
# iLQG at time-step: 11
# experiment: 14
# iLQG at time-step: 12
# experiment: 14
# iLQG at time-step: 13
# experiment: 14
# iLQG at time-step: 14
# experiment: 14
# iLQG at time-step: 15
# experiment: 14
# iLQG at time-step: 16
# experiment: 14
# iLQG at time-step: 17
# experiment: 14
# iLQG at time-step: 18
# experiment: 14
# iLQG at time-step: 19
# experiment: 14
# iLQG at time-step: 20
# experiment: 14
# iLQG at time-step: 21
# experiment: 14
# iLQG at time-step: 22
# experiment: 14
# iLQG at time-step: 23
# experiment: 14
# iLQG at time-step: 24
# experiment: 14
# iLQG at time-step: 25
# experiment: 14
# iLQG at time-step: 26
# experiment: 14
# iLQG at time-step: 27
# experiment: 14
# iLQG at time-step: 28
# experiment: 14
# iLQG at time-step: 29
# experiment: 14
# iLQG at time-step: 30
# experiment: 14
# iLQG at time-step: 31
# experiment: 14
# iLQG at time-step: 32
# experiment: 14
# iLQG at time-step: 33
# experiment: 14
# iLQG at time-step: 34
# experiment: 14
# iLQG at time-step: 35
# experiment: 14
# iLQG at time-step: 36
# experiment: 14
# iLQG at time-step: 37
# experiment: 14
# iLQG at time-step: 38
# experiment: 14
# iLQG at time-step: 39
# experiment: 14
# iLQG at time-step: 40
# experiment: 14
# iLQG at time-step: 41
# experiment: 14
# iLQG at time-step: 42
# experiment: 14
# iLQG at time-step: 43
# experiment: 14
# iLQG at time-step: 44
# experiment: 14
# iLQG at time-step: 45
# experiment: 14
# iLQG at time-step: 46
# experiment: 14
# iLQG at time-step: 47
# experiment: 14
# iLQG at time-step: 48
# experiment: 14
# iLQG at time-step: 0
# experiment: 15
# iLQG at time-step: 1
# experiment: 15
# iLQG at time-step: 2
# experiment: 15
# iLQG at time-step: 3
# experiment: 15
# iLQG at time-step: 4
# experiment: 15
# iLQG at time-step: 5
# experiment: 15
# iLQG at time-step: 6
# experiment: 15
# iLQG at time-step: 7
# experiment: 15
# iLQG at time-step: 8
# experiment: 15
# iLQG at time-step: 9
# experiment: 15
# iLQG at time-step: 10
# experiment: 15
# iLQG at time-step: 11
# experiment: 15
# iLQG at time-step: 12
# experiment: 15
# iLQG at time-step: 13
# experiment: 15
# iLQG at time-step: 14
# experiment: 15
# iLQG at time-step: 15
# experiment: 15
# iLQG at time-step: 16
# experiment: 15
# iLQG at time-step: 17
# experiment: 15
# iLQG at time-step: 18
# experiment: 15
# iLQG at time-step: 19
# experiment: 15
# iLQG at time-step: 20
# experiment: 15
# iLQG at time-step: 21
# experiment: 15
# iLQG at time-step: 22
# experiment: 15
# iLQG at time-step: 23
# experiment: 15
# iLQG at time-step: 24
# experiment: 15
# iLQG at time-step: 25
# experiment: 15
# iLQG at time-step: 26
# experiment: 15
# iLQG at time-step: 27
# experiment: 15
# iLQG at time-step: 28
# experiment: 15
# iLQG at time-step: 29
# experiment: 15
# iLQG at time-step: 30
# experiment: 15
# iLQG at time-step: 31
# experiment: 15
# iLQG at time-step: 32
# experiment: 15
# iLQG at time-step: 33
# experiment: 15
# iLQG at time-step: 34
# experiment: 15
# iLQG at time-step: 35
# experiment: 15
# iLQG at time-step: 36
# experiment: 15
# iLQG at time-step: 37
# experiment: 15
# iLQG at time-step: 38
# experiment: 15
# iLQG at time-step: 39
# experiment: 15
# iLQG at time-step: 40
# experiment: 15
# iLQG at time-step: 41
# experiment: 15
# iLQG at time-step: 42
# experiment: 15
# iLQG at time-step: 43
# experiment: 15
# iLQG at time-step: 44
# experiment: 15
# iLQG at time-step: 45
# experiment: 15
# iLQG at time-step: 46
# experiment: 15
# iLQG at time-step: 47
# experiment: 15
# iLQG at time-step: 48
# experiment: 15
# iLQG at time-step: 0
# experiment: 16
# iLQG at time-step: 1
# experiment: 16
# iLQG at time-step: 2
# experiment: 16
# iLQG at time-step: 3
# experiment: 16
# iLQG at time-step: 4
# experiment: 16
# iLQG at time-step: 5
# experiment: 16
# iLQG at time-step: 6
# experiment: 16
# iLQG at time-step: 7
# experiment: 16
# iLQG at time-step: 8
# experiment: 16
# iLQG at time-step: 9
# experiment: 16
# iLQG at time-step: 10
# experiment: 16
# iLQG at time-step: 11
# experiment: 16
# iLQG at time-step: 12
# experiment: 16
# iLQG at time-step: 13
# experiment: 16
# iLQG at time-step: 14
# experiment: 16
# iLQG at time-step: 15
# experiment: 16
# iLQG at time-step: 16
# experiment: 16
# iLQG at time-step: 17
# experiment: 16
# iLQG at time-step: 18
# experiment: 16
# iLQG at time-step: 19
# experiment: 16
# iLQG at time-step: 20
# experiment: 16
# iLQG at time-step: 21
# experiment: 16
# iLQG at time-step: 22
# experiment: 16
# iLQG at time-step: 23
# experiment: 16
# iLQG at time-step: 24
# experiment: 16
# iLQG at time-step: 25
# experiment: 16
# iLQG at time-step: 26
# experiment: 16
# iLQG at time-step: 27
# experiment: 16
# iLQG at time-step: 28
# experiment: 16
# iLQG at time-step: 29
# experiment: 16
# iLQG at time-step: 30
# experiment: 16
# iLQG at time-step: 31
# experiment: 16
# iLQG at time-step: 32
# experiment: 16
# iLQG at time-step: 33
# experiment: 16
# iLQG at time-step: 34
# experiment: 16
# iLQG at time-step: 35
# experiment: 16
# iLQG at time-step: 36
# experiment: 16
# iLQG at time-step: 37
# experiment: 16
# iLQG at time-step: 38
# experiment: 16
# iLQG at time-step: 39
# experiment: 16
# iLQG at time-step: 40
# experiment: 16
# iLQG at time-step: 41
# experiment: 16
# iLQG at time-step: 42
# experiment: 16
# iLQG at time-step: 43
# experiment: 16
# iLQG at time-step: 44
# experiment: 16
# iLQG at time-step: 45
# experiment: 16
# iLQG at time-step: 46
# experiment: 16
# iLQG at time-step: 47
# experiment: 16
# iLQG at time-step: 48
# experiment: 16
# iLQG at time-step: 0
# experiment: 17
# iLQG at time-step: 1
# experiment: 17
# iLQG at time-step: 2
# experiment: 17
# iLQG at time-step: 3
# experiment: 17
# iLQG at time-step: 4
# experiment: 17
# iLQG at time-step: 5
# experiment: 17
# iLQG at time-step: 6
# experiment: 17
# iLQG at time-step: 7
# experiment: 17
# iLQG at time-step: 8
# experiment: 17
# iLQG at time-step: 9
# experiment: 17
# iLQG at time-step: 10
# experiment: 17
# iLQG at time-step: 11
# experiment: 17
# iLQG at time-step: 12
# experiment: 17
# iLQG at time-step: 13
# experiment: 17
# iLQG at time-step: 14
# experiment: 17
# iLQG at time-step: 15
# experiment: 17
# iLQG at time-step: 16
# experiment: 17
# iLQG at time-step: 17
# experiment: 17
# iLQG at time-step: 18
# experiment: 17
# iLQG at time-step: 19
# experiment: 17
# iLQG at time-step: 20
# experiment: 17
# iLQG at time-step: 21
# experiment: 17
# iLQG at time-step: 22
# experiment: 17
# iLQG at time-step: 23
# experiment: 17
# iLQG at time-step: 24
# experiment: 17
# iLQG at time-step: 25
# experiment: 17
# iLQG at time-step: 26
# experiment: 17
# iLQG at time-step: 27
# experiment: 17
# iLQG at time-step: 28
# experiment: 17
# iLQG at time-step: 29
# experiment: 17
# iLQG at time-step: 30
# experiment: 17
# iLQG at time-step: 31
# experiment: 17
# iLQG at time-step: 32
# experiment: 17
# iLQG at time-step: 33
# experiment: 17
# iLQG at time-step: 34
# experiment: 17
# iLQG at time-step: 35
# experiment: 17
# iLQG at time-step: 36
# experiment: 17
# iLQG at time-step: 37
# experiment: 17
# iLQG at time-step: 38
# experiment: 17
# iLQG at time-step: 39
# experiment: 17
# iLQG at time-step: 40
# experiment: 17
# iLQG at time-step: 41
# experiment: 17
# iLQG at time-step: 42
# experiment: 17
# iLQG at time-step: 43
# experiment: 17
# iLQG at time-step: 44
# experiment: 17
# iLQG at time-step: 45
# experiment: 17
# iLQG at time-step: 46
# experiment: 17
# iLQG at time-step: 47
# experiment: 17
# iLQG at time-step: 48
# experiment: 17
# iLQG at time-step: 0
# experiment: 18
# iLQG at time-step: 1
# experiment: 18
# iLQG at time-step: 2
# experiment: 18
# iLQG at time-step: 3
# experiment: 18
# iLQG at time-step: 4
# experiment: 18
# iLQG at time-step: 5
# experiment: 18
# iLQG at time-step: 6
# experiment: 18
# iLQG at time-step: 7
# experiment: 18
# iLQG at time-step: 8
# experiment: 18
# iLQG at time-step: 9
# experiment: 18
# iLQG at time-step: 10
# experiment: 18
# iLQG at time-step: 11
# experiment: 18
# iLQG at time-step: 12
# experiment: 18
# iLQG at time-step: 13
# experiment: 18
# iLQG at time-step: 14
# experiment: 18
# iLQG at time-step: 15
# experiment: 18
# iLQG at time-step: 16
# experiment: 18
# iLQG at time-step: 17
# experiment: 18
# iLQG at time-step: 18
# experiment: 18
# iLQG at time-step: 19
# experiment: 18
# iLQG at time-step: 20
# experiment: 18
# iLQG at time-step: 21
# experiment: 18
# iLQG at time-step: 22
# experiment: 18
# iLQG at time-step: 23
# experiment: 18
# iLQG at time-step: 24
# experiment: 18
# iLQG at time-step: 25
# experiment: 18
# iLQG at time-step: 26
# experiment: 18
# iLQG at time-step: 27
# experiment: 18
# iLQG at time-step: 28
# experiment: 18
# iLQG at time-step: 29
# experiment: 18
# iLQG at time-step: 30
# experiment: 18
# iLQG at time-step: 31
# experiment: 18
# iLQG at time-step: 32
# experiment: 18
# iLQG at time-step: 33
# experiment: 18
# iLQG at time-step: 34
# experiment: 18
# iLQG at time-step: 35
# experiment: 18
# iLQG at time-step: 36
# experiment: 18
# iLQG at time-step: 37
# experiment: 18
# iLQG at time-step: 38
# experiment: 18
# iLQG at time-step: 39
# experiment: 18
# iLQG at time-step: 40
# experiment: 18
# iLQG at time-step: 41
# experiment: 18
# iLQG at time-step: 42
# experiment: 18
# iLQG at time-step: 43
# experiment: 18
# iLQG at time-step: 44
# experiment: 18
# iLQG at time-step: 45
# experiment: 18
# iLQG at time-step: 46
# experiment: 18
# iLQG at time-step: 47
# experiment: 18
# iLQG at time-step: 48
# experiment: 18
# iLQG at time-step: 0
# experiment: 19
# iLQG at time-step: 1
# experiment: 19
# iLQG at time-step: 2
# experiment: 19
# iLQG at time-step: 3
# experiment: 19
# iLQG at time-step: 4
# experiment: 19
# iLQG at time-step: 5
# experiment: 19
# iLQG at time-step: 6
# experiment: 19
# iLQG at time-step: 7
# experiment: 19
# iLQG at time-step: 8
# experiment: 19
# iLQG at time-step: 9
# experiment: 19
# iLQG at time-step: 10
# experiment: 19
# iLQG at time-step: 11
# experiment: 19
# iLQG at time-step: 12
# experiment: 19
# iLQG at time-step: 13
# experiment: 19
# iLQG at time-step: 14
# experiment: 19
# iLQG at time-step: 15
# experiment: 19
# iLQG at time-step: 16
# experiment: 19
# iLQG at time-step: 17
# experiment: 19
# iLQG at time-step: 18
# experiment: 19
# iLQG at time-step: 19
# experiment: 19
# iLQG at time-step: 20
# experiment: 19
# iLQG at time-step: 21
# experiment: 19
# iLQG at time-step: 22
# experiment: 19
# iLQG at time-step: 23
# experiment: 19
# iLQG at time-step: 24
# experiment: 19
# iLQG at time-step: 25
# experiment: 19
# iLQG at time-step: 26
# experiment: 19
# iLQG at time-step: 27
# experiment: 19
# iLQG at time-step: 28
# experiment: 19
# iLQG at time-step: 29
# experiment: 19
# iLQG at time-step: 30
# experiment: 19
# iLQG at time-step: 31
# experiment: 19
# iLQG at time-step: 32
# experiment: 19
# iLQG at time-step: 33
# experiment: 19
# iLQG at time-step: 34
# experiment: 19
# iLQG at time-step: 35
# experiment: 19
# iLQG at time-step: 36
# experiment: 19
# iLQG at time-step: 37
# experiment: 19
# iLQG at time-step: 38
# experiment: 19
# iLQG at time-step: 39
# experiment: 19
# iLQG at time-step: 40
# experiment: 19
# iLQG at time-step: 41
# experiment: 19
# iLQG at time-step: 42
# experiment: 19
# iLQG at time-step: 43
# experiment: 19
# iLQG at time-step: 44
# experiment: 19
# iLQG at time-step: 45
# experiment: 19
# iLQG at time-step: 46
# experiment: 19
# iLQG at time-step: 47
# experiment: 19
# iLQG at time-step: 48
# experiment: 19
# iLQG at time-step: 0
# experiment: 20
# iLQG at time-step: 1
# experiment: 20
# iLQG at time-step: 2
# experiment: 20
# iLQG at time-step: 3
# experiment: 20
# iLQG at time-step: 4
# experiment: 20
# iLQG at time-step: 5
# experiment: 20
# iLQG at time-step: 6
# experiment: 20
# iLQG at time-step: 7
# experiment: 20
# iLQG at time-step: 8
# experiment: 20
# iLQG at time-step: 9
# experiment: 20
# iLQG at time-step: 10
# experiment: 20
# iLQG at time-step: 11
# experiment: 20
# iLQG at time-step: 12
# experiment: 20
# iLQG at time-step: 13
# experiment: 20
# iLQG at time-step: 14
# experiment: 20
# iLQG at time-step: 15
# experiment: 20
# iLQG at time-step: 16
# experiment: 20
# iLQG at time-step: 17
# experiment: 20
# iLQG at time-step: 18
# experiment: 20
# iLQG at time-step: 19
# experiment: 20
# iLQG at time-step: 20
# experiment: 20
# iLQG at time-step: 21
# experiment: 20
# iLQG at time-step: 22
# experiment: 20
# iLQG at time-step: 23
# experiment: 20
# iLQG at time-step: 24
# experiment: 20
# iLQG at time-step: 25
# experiment: 20
# iLQG at time-step: 26
# experiment: 20
# iLQG at time-step: 27
# experiment: 20
# iLQG at time-step: 28
# experiment: 20
# iLQG at time-step: 29
# experiment: 20
# iLQG at time-step: 30
# experiment: 20
# iLQG at time-step: 31
# experiment: 20
# iLQG at time-step: 32
# experiment: 20
# iLQG at time-step: 33
# experiment: 20
# iLQG at time-step: 34
# experiment: 20
# iLQG at time-step: 35
# experiment: 20
# iLQG at time-step: 36
# experiment: 20
# iLQG at time-step: 37
# experiment: 20
# iLQG at time-step: 38
# experiment: 20
# iLQG at time-step: 39
# experiment: 20
# iLQG at time-step: 40
# experiment: 20
# iLQG at time-step: 41
# experiment: 20
# iLQG at time-step: 42
# experiment: 20
# iLQG at time-step: 43
# experiment: 20
# iLQG at time-step: 44
# experiment: 20
# iLQG at time-step: 45
# experiment: 20
# iLQG at time-step: 46
# experiment: 20
# iLQG at time-step: 47
# experiment: 20
# iLQG at time-step: 48
# experiment: 20
# iLQG at time-step: 0
# experiment: 21
# iLQG at time-step: 1
# experiment: 21
# iLQG at time-step: 2
# experiment: 21
# iLQG at time-step: 3
# experiment: 21
# iLQG at time-step: 4
# experiment: 21
# iLQG at time-step: 5
# experiment: 21
# iLQG at time-step: 6
# experiment: 21
# iLQG at time-step: 7
# experiment: 21
# iLQG at time-step: 8
# experiment: 21
# iLQG at time-step: 9
# experiment: 21
# iLQG at time-step: 10
# experiment: 21
# iLQG at time-step: 11
# experiment: 21
# iLQG at time-step: 12
# experiment: 21
# iLQG at time-step: 13
# experiment: 21
# iLQG at time-step: 14
# experiment: 21
# iLQG at time-step: 15
# experiment: 21
# iLQG at time-step: 16
# experiment: 21
# iLQG at time-step: 17
# experiment: 21
# iLQG at time-step: 18
# experiment: 21
# iLQG at time-step: 19
# experiment: 21
# iLQG at time-step: 20
# experiment: 21
# iLQG at time-step: 21
# experiment: 21
# iLQG at time-step: 22
# experiment: 21
# iLQG at time-step: 23
# experiment: 21
# iLQG at time-step: 24
# experiment: 21
# iLQG at time-step: 25
# experiment: 21
# iLQG at time-step: 26
# experiment: 21
# iLQG at time-step: 27
# experiment: 21
# iLQG at time-step: 28
# experiment: 21
# iLQG at time-step: 29
# experiment: 21
# iLQG at time-step: 30
# experiment: 21
# iLQG at time-step: 31
# experiment: 21
# iLQG at time-step: 32
# experiment: 21
# iLQG at time-step: 33
# experiment: 21
# iLQG at time-step: 34
# experiment: 21
# iLQG at time-step: 35
# experiment: 21
# iLQG at time-step: 36
# experiment: 21
# iLQG at time-step: 37
# experiment: 21
# iLQG at time-step: 38
# experiment: 21
# iLQG at time-step: 39
# experiment: 21
# iLQG at time-step: 40
# experiment: 21
# iLQG at time-step: 41
# experiment: 21
# iLQG at time-step: 42
# experiment: 21
# iLQG at time-step: 43
# experiment: 21
# iLQG at time-step: 44
# experiment: 21
# iLQG at time-step: 45
# experiment: 21
# iLQG at time-step: 46
# experiment: 21
# iLQG at time-step: 47
# experiment: 21
# iLQG at time-step: 48
# experiment: 21
# iLQG at time-step: 0
# experiment: 22
# iLQG at time-step: 1
# experiment: 22
# iLQG at time-step: 2
# experiment: 22
# iLQG at time-step: 3
# experiment: 22
# iLQG at time-step: 4
# experiment: 22
# iLQG at time-step: 5
# experiment: 22
# iLQG at time-step: 6
# experiment: 22
# iLQG at time-step: 7
# experiment: 22
# iLQG at time-step: 8
# experiment: 22
# iLQG at time-step: 9
# experiment: 22
# iLQG at time-step: 10
# experiment: 22
# iLQG at time-step: 11
# experiment: 22
# iLQG at time-step: 12
# experiment: 22
# iLQG at time-step: 13
# experiment: 22
# iLQG at time-step: 14
# experiment: 22
# iLQG at time-step: 15
# experiment: 22
# iLQG at time-step: 16
# experiment: 22
# iLQG at time-step: 17
# experiment: 22
# iLQG at time-step: 18
# experiment: 22
# iLQG at time-step: 19
# experiment: 22
# iLQG at time-step: 20
# experiment: 22
# iLQG at time-step: 21
# experiment: 22
# iLQG at time-step: 22
# experiment: 22
# iLQG at time-step: 23
# experiment: 22
# iLQG at time-step: 24
# experiment: 22
# iLQG at time-step: 25
# experiment: 22
# iLQG at time-step: 26
# experiment: 22
# iLQG at time-step: 27
# experiment: 22
# iLQG at time-step: 28
# experiment: 22
# iLQG at time-step: 29
# experiment: 22
# iLQG at time-step: 30
# experiment: 22
# iLQG at time-step: 31
# experiment: 22
# iLQG at time-step: 32
# experiment: 22
# iLQG at time-step: 33
# experiment: 22
# iLQG at time-step: 34
# experiment: 22
# iLQG at time-step: 35
# experiment: 22
# iLQG at time-step: 36
# experiment: 22
# iLQG at time-step: 37
# experiment: 22
# iLQG at time-step: 38
# experiment: 22
# iLQG at time-step: 39
# experiment: 22
# iLQG at time-step: 40
# experiment: 22
# iLQG at time-step: 41
# experiment: 22
# iLQG at time-step: 42
# experiment: 22
# iLQG at time-step: 43
# experiment: 22
# iLQG at time-step: 44
# experiment: 22
# iLQG at time-step: 45
# experiment: 22
# iLQG at time-step: 46
# experiment: 22
# iLQG at time-step: 47
# experiment: 22
# iLQG at time-step: 48
# experiment: 22
# iLQG at time-step: 0
# experiment: 23
# iLQG at time-step: 1
# experiment: 23
# iLQG at time-step: 2
# experiment: 23
# iLQG at time-step: 3
# experiment: 23
# iLQG at time-step: 4
# experiment: 23
# iLQG at time-step: 5
# experiment: 23
# iLQG at time-step: 6
# experiment: 23
# iLQG at time-step: 7
# experiment: 23
# iLQG at time-step: 8
# experiment: 23
# iLQG at time-step: 9
# experiment: 23
# iLQG at time-step: 10
# experiment: 23
# iLQG at time-step: 11
# experiment: 23
# iLQG at time-step: 12
# experiment: 23
# iLQG at time-step: 13
# experiment: 23
# iLQG at time-step: 14
# experiment: 23
# iLQG at time-step: 15
# experiment: 23
# iLQG at time-step: 16
# experiment: 23
# iLQG at time-step: 17
# experiment: 23
# iLQG at time-step: 18
# experiment: 23
# iLQG at time-step: 19
# experiment: 23
# iLQG at time-step: 20
# experiment: 23
# iLQG at time-step: 21
# experiment: 23
# iLQG at time-step: 22
# experiment: 23
# iLQG at time-step: 23
# experiment: 23
# iLQG at time-step: 24
# experiment: 23
# iLQG at time-step: 25
# experiment: 23
# iLQG at time-step: 26
# experiment: 23
# iLQG at time-step: 27
# experiment: 23
# iLQG at time-step: 28
# experiment: 23
# iLQG at time-step: 29
# experiment: 23
# iLQG at time-step: 30
# experiment: 23
# iLQG at time-step: 31
# experiment: 23
# iLQG at time-step: 32
# experiment: 23
# iLQG at time-step: 33
# experiment: 23
# iLQG at time-step: 34
# experiment: 23
# iLQG at time-step: 35
# experiment: 23
# iLQG at time-step: 36
# experiment: 23
# iLQG at time-step: 37
# experiment: 23
# iLQG at time-step: 38
# experiment: 23
# iLQG at time-step: 39
# experiment: 23
# iLQG at time-step: 40
# experiment: 23
# iLQG at time-step: 41
# experiment: 23
# iLQG at time-step: 42
# experiment: 23
# iLQG at time-step: 43
# experiment: 23
# iLQG at time-step: 44
# experiment: 23
# iLQG at time-step: 45
# experiment: 23
# iLQG at time-step: 46
# experiment: 23
# iLQG at time-step: 47
# experiment: 23
# iLQG at time-step: 48
# experiment: 23
# iLQG at time-step: 0
# experiment: 24
# iLQG at time-step: 1
# experiment: 24
# iLQG at time-step: 2
# experiment: 24
# iLQG at time-step: 3
# experiment: 24
# iLQG at time-step: 4
# experiment: 24
# iLQG at time-step: 5
# experiment: 24
# iLQG at time-step: 6
# experiment: 24
# iLQG at time-step: 7
# experiment: 24
# iLQG at time-step: 8
# experiment: 24
# iLQG at time-step: 9
# experiment: 24
# iLQG at time-step: 10
# experiment: 24
# iLQG at time-step: 11
# experiment: 24
# iLQG at time-step: 12
# experiment: 24
# iLQG at time-step: 13
# experiment: 24
# iLQG at time-step: 14
# experiment: 24
# iLQG at time-step: 15
# experiment: 24
# iLQG at time-step: 16
# experiment: 24
# iLQG at time-step: 17
# experiment: 24
# iLQG at time-step: 18
# experiment: 24
# iLQG at time-step: 19
# experiment: 24
# iLQG at time-step: 20
# experiment: 24
# iLQG at time-step: 21
# experiment: 24
# iLQG at time-step: 22
# experiment: 24
# iLQG at time-step: 23
# experiment: 24
# iLQG at time-step: 24
# experiment: 24
# iLQG at time-step: 25
# experiment: 24
# iLQG at time-step: 26
# experiment: 24
# iLQG at time-step: 27
# experiment: 24
# iLQG at time-step: 28
# experiment: 24
# iLQG at time-step: 29
# experiment: 24
# iLQG at time-step: 30
# experiment: 24
# iLQG at time-step: 31
# experiment: 24
# iLQG at time-step: 32
# experiment: 24
# iLQG at time-step: 33
# experiment: 24
# iLQG at time-step: 34
# experiment: 24
# iLQG at time-step: 35
# experiment: 24
# iLQG at time-step: 36
# experiment: 24
# iLQG at time-step: 37
# experiment: 24
# iLQG at time-step: 38
# experiment: 24
# iLQG at time-step: 39
# experiment: 24
# iLQG at time-step: 40
# experiment: 24
# iLQG at time-step: 41
# experiment: 24
# iLQG at time-step: 42
# experiment: 24
# iLQG at time-step: 43
# experiment: 24
# iLQG at time-step: 44
# experiment: 24
# iLQG at time-step: 45
# experiment: 24
# iLQG at time-step: 46
# experiment: 24
# iLQG at time-step: 47
# experiment: 24
# iLQG at time-step: 48
# experiment: 24
# iLQG at time-step: 0
# experiment: 25
# iLQG at time-step: 1
# experiment: 25
# iLQG at time-step: 2
# experiment: 25
# iLQG at time-step: 3
# experiment: 25
# iLQG at time-step: 4
# experiment: 25
# iLQG at time-step: 5
# experiment: 25
# iLQG at time-step: 6
# experiment: 25
# iLQG at time-step: 7
# experiment: 25
# iLQG at time-step: 8
# experiment: 25
# iLQG at time-step: 9
# experiment: 25
# iLQG at time-step: 10
# experiment: 25
# iLQG at time-step: 11
# experiment: 25
# iLQG at time-step: 12
# experiment: 25
# iLQG at time-step: 13
# experiment: 25
# iLQG at time-step: 14
# experiment: 25
# iLQG at time-step: 15
# experiment: 25
# iLQG at time-step: 16
# experiment: 25
# iLQG at time-step: 17
# experiment: 25
# iLQG at time-step: 18
# experiment: 25
# iLQG at time-step: 19
# experiment: 25
# iLQG at time-step: 20
# experiment: 25
# iLQG at time-step: 21
# experiment: 25
# iLQG at time-step: 22
# experiment: 25
# iLQG at time-step: 23
# experiment: 25
# iLQG at time-step: 24
# experiment: 25
# iLQG at time-step: 25
# experiment: 25
# iLQG at time-step: 26
# experiment: 25
# iLQG at time-step: 27
# experiment: 25
# iLQG at time-step: 28
# experiment: 25
# iLQG at time-step: 29
# experiment: 25
# iLQG at time-step: 30
# experiment: 25
# iLQG at time-step: 31
# experiment: 25
# iLQG at time-step: 32
# experiment: 25
# iLQG at time-step: 33
# experiment: 25
# iLQG at time-step: 34
# experiment: 25
# iLQG at time-step: 35
# experiment: 25
# iLQG at time-step: 36
# experiment: 25
# iLQG at time-step: 37
# experiment: 25
# iLQG at time-step: 38
# experiment: 25
# iLQG at time-step: 39
# experiment: 25
# iLQG at time-step: 40
# experiment: 25
# iLQG at time-step: 41
# experiment: 25
# iLQG at time-step: 42
# experiment: 25
# iLQG at time-step: 43
# experiment: 25
# iLQG at time-step: 44
# experiment: 25
# iLQG at time-step: 45
# experiment: 25
# iLQG at time-step: 46
# experiment: 25
# iLQG at time-step: 47
# experiment: 25
# iLQG at time-step: 48
# experiment: 25
# iLQG at time-step: 0
# experiment: 26
# iLQG at time-step: 1
# experiment: 26
# iLQG at time-step: 2
# experiment: 26
# iLQG at time-step: 3
# experiment: 26
# iLQG at time-step: 4
# experiment: 26
# iLQG at time-step: 5
# experiment: 26
# iLQG at time-step: 6
# experiment: 26
# iLQG at time-step: 7
# experiment: 26
# iLQG at time-step: 8
# experiment: 26
# iLQG at time-step: 9
# experiment: 26
# iLQG at time-step: 10
# experiment: 26
# iLQG at time-step: 11
# experiment: 26
# iLQG at time-step: 12
# experiment: 26
# iLQG at time-step: 13
# experiment: 26
# iLQG at time-step: 14
# experiment: 26
# iLQG at time-step: 15
# experiment: 26
# iLQG at time-step: 16
# experiment: 26
# iLQG at time-step: 17
# experiment: 26
# iLQG at time-step: 18
# experiment: 26
# iLQG at time-step: 19
# experiment: 26
# iLQG at time-step: 20
# experiment: 26
# iLQG at time-step: 21
# experiment: 26
# iLQG at time-step: 22
# experiment: 26
# iLQG at time-step: 23
# experiment: 26
# iLQG at time-step: 24
# experiment: 26
# iLQG at time-step: 25
# experiment: 26
# iLQG at time-step: 26
# experiment: 26
# iLQG at time-step: 27
# experiment: 26
# iLQG at time-step: 28
# experiment: 26
# iLQG at time-step: 29
# experiment: 26
# iLQG at time-step: 30
# experiment: 26
# iLQG at time-step: 31
# experiment: 26
# iLQG at time-step: 32
# experiment: 26
# iLQG at time-step: 33
# experiment: 26
# iLQG at time-step: 34
# experiment: 26
# iLQG at time-step: 35
# experiment: 26
# iLQG at time-step: 36
# experiment: 26
# iLQG at time-step: 37
# experiment: 26
# iLQG at time-step: 38
# experiment: 26
# iLQG at time-step: 39
# experiment: 26
# iLQG at time-step: 40
# experiment: 26
# iLQG at time-step: 41
# experiment: 26
# iLQG at time-step: 42
# experiment: 26
# iLQG at time-step: 43
# experiment: 26
# iLQG at time-step: 44
# experiment: 26
# iLQG at time-step: 45
# experiment: 26
# iLQG at time-step: 46
# experiment: 26
# iLQG at time-step: 47
# experiment: 26
# iLQG at time-step: 48
# experiment: 26
# iLQG at time-step: 0
# experiment: 27
# iLQG at time-step: 1
# experiment: 27
# iLQG at time-step: 2
# experiment: 27
# iLQG at time-step: 3
# experiment: 27
# iLQG at time-step: 4
# experiment: 27
# iLQG at time-step: 5
# experiment: 27
# iLQG at time-step: 6
# experiment: 27
# iLQG at time-step: 7
# experiment: 27
# iLQG at time-step: 8
# experiment: 27
# iLQG at time-step: 9
# experiment: 27
# iLQG at time-step: 10
# experiment: 27
# iLQG at time-step: 11
# experiment: 27
# iLQG at time-step: 12
# experiment: 27
# iLQG at time-step: 13
# experiment: 27
# iLQG at time-step: 14
# experiment: 27
# iLQG at time-step: 15
# experiment: 27
# iLQG at time-step: 16
# experiment: 27
# iLQG at time-step: 17
# experiment: 27
# iLQG at time-step: 18
# experiment: 27
# iLQG at time-step: 19
# experiment: 27
# iLQG at time-step: 20
# experiment: 27
# iLQG at time-step: 21
# experiment: 27
# iLQG at time-step: 22
# experiment: 27
# iLQG at time-step: 23
# experiment: 27
# iLQG at time-step: 24
# experiment: 27
# iLQG at time-step: 25
# experiment: 27
# iLQG at time-step: 26
# experiment: 27
# iLQG at time-step: 27
# experiment: 27
# iLQG at time-step: 28
# experiment: 27
# iLQG at time-step: 29
# experiment: 27
# iLQG at time-step: 30
# experiment: 27
# iLQG at time-step: 31
# experiment: 27
# iLQG at time-step: 32
# experiment: 27
# iLQG at time-step: 33
# experiment: 27
# iLQG at time-step: 34
# experiment: 27
# iLQG at time-step: 35
# experiment: 27
# iLQG at time-step: 36
# experiment: 27
# iLQG at time-step: 37
# experiment: 27
# iLQG at time-step: 38
# experiment: 27
# iLQG at time-step: 39
# experiment: 27
# iLQG at time-step: 40
# experiment: 27
# iLQG at time-step: 41
# experiment: 27
# ...
# iLQG at time-step: 9
# experiment: 42
# iLQG at time-step: 10
# experiment: 42
# iLQG at time-step: 11
# experiment: 42
# iLQG at time-step: 12
# experiment: 42
# iLQG at time-step: 13
# experiment: 42
# iLQG at time-step: 14
# experiment: 42
# iLQG at time-step: 15
# experiment: 42
# iLQG at time-step: 16
# experiment: 42
# iLQG at time-step: 17
# experiment: 42
# iLQG at time-step: 18
# experiment: 42
# iLQG at time-step: 19
# experiment: 42
# iLQG at time-step: 20
# experiment: 42
# iLQG at time-step: 21
# experiment: 42
# iLQG at time-step: 22
# experiment: 42
# iLQG at time-step: 23
# experiment: 42
# iLQG at time-step: 24
# experiment: 42
# iLQG at time-step: 25
# experiment: 42
# iLQG at time-step: 26
# experiment: 42
# iLQG at time-step: 27
# experiment: 42
# iLQG at time-step: 28
# experiment: 42
# iLQG at time-step: 29
# experiment: 42
# iLQG at time-step: 30
# experiment: 42
# iLQG at time-step: 31
# experiment: 42
# iLQG at time-step: 32
# experiment: 42
# iLQG at time-step: 33
# experiment: 42
# iLQG at time-step: 34
# experiment: 42
# iLQG at time-step: 35
# experiment: 42
# iLQG at time-step: 36
# experiment: 42
# iLQG at time-step: 37
# experiment: 42
# iLQG at time-step: 38
# experiment: 42
# iLQG at time-step: 39
# experiment: 42
# iLQG at time-step: 40
# experiment: 42
# iLQG at time-step: 41
# experiment: 42
# iLQG at time-step: 42
# experiment: 42
# iLQG at time-step: 43
# experiment: 42
# iLQG at time-step: 44
# experiment: 42
# iLQG at time-step: 45
# experiment: 42
# iLQG at time-step: 46
# experiment: 42
# iLQG at time-step: 47
# experiment: 42
# iLQG at time-step: 48
# experiment: 42
# iLQG at time-step: 0
# experiment: 43
# iLQG at time-step: 1
# experiment: 43
# iLQG at time-step: 2
# experiment: 43
# iLQG at time-step: 3
# experiment: 43
# iLQG at time-step: 4
# experiment: 43
# iLQG at time-step: 5
# experiment: 43
# iLQG at time-step: 6
# experiment: 43
# iLQG at time-step: 7
# experiment: 43
# iLQG at time-step: 8
# experiment: 43
# iLQG at time-step: 9
# experiment: 43
# iLQG at time-step: 10
# experiment: 43
# iLQG at time-step: 11
# experiment: 43
# iLQG at time-step: 12
# experiment: 43
# iLQG at time-step: 13
# experiment: 43
# iLQG at time-step: 14
# experiment: 43
# iLQG at time-step: 15
# experiment: 43
# iLQG at time-step: 16
# experiment: 43
# iLQG at time-step: 17
# experiment: 43
# iLQG at time-step: 18
# experiment: 43
# iLQG at time-step: 19
# experiment: 43
# iLQG at time-step: 20
# experiment: 43
# iLQG at time-step: 21
# experiment: 43
# iLQG at time-step: 22
# experiment: 43
# iLQG at time-step: 23
# experiment: 43
# iLQG at time-step: 24
# experiment: 43
# iLQG at time-step: 25
# experiment: 43
# iLQG at time-step: 26
# experiment: 43
# iLQG at time-step: 27
# experiment: 43
# iLQG at time-step: 28
# experiment: 43
# iLQG at time-step: 29
# experiment: 43
# iLQG at time-step: 30
# experiment: 43
# iLQG at time-step: 31
# experiment: 43
# iLQG at time-step: 32
# experiment: 43
# iLQG at time-step: 33
# experiment: 43
# iLQG at time-step: 34
# experiment: 43
# iLQG at time-step: 35
# experiment: 43
# iLQG at time-step: 36
# experiment: 43
# iLQG at time-step: 37
# experiment: 43
# iLQG at time-step: 38
# experiment: 43
# iLQG at time-step: 39
# experiment: 43
# iLQG at time-step: 40
# experiment: 43
# iLQG at time-step: 41
# experiment: 43
# iLQG at time-step: 42
# experiment: 43
# iLQG at time-step: 43
# experiment: 43
# iLQG at time-step: 44
# experiment: 43
# iLQG at time-step: 45
# experiment: 43
# iLQG at time-step: 46
# experiment: 43
# iLQG at time-step: 47
# experiment: 43
# iLQG at time-step: 48
# experiment: 43
# iLQG at time-step: 0
# experiment: 44
# iLQG at time-step: 1
# experiment: 44
# iLQG at time-step: 2
# experiment: 44
# iLQG at time-step: 3
# experiment: 44
# iLQG at time-step: 4
# experiment: 44
# iLQG at time-step: 5
# experiment: 44
# iLQG at time-step: 6
# experiment: 44
# iLQG at time-step: 7
# experiment: 44
# iLQG at time-step: 8
# experiment: 44
# iLQG at time-step: 9
# experiment: 44
# iLQG at time-step: 10
# experiment: 44
# iLQG at time-step: 11
# experiment: 44
# iLQG at time-step: 12
# experiment: 44
# iLQG at time-step: 13
# experiment: 44
# iLQG at time-step: 14
# experiment: 44
# iLQG at time-step: 15
# experiment: 44
# iLQG at time-step: 16
# experiment: 44
# iLQG at time-step: 17
# experiment: 44
# iLQG at time-step: 18
# experiment: 44
# iLQG at time-step: 19
# experiment: 44
# iLQG at time-step: 20
# experiment: 44
# iLQG at time-step: 21
# experiment: 44
# iLQG at time-step: 22
# experiment: 44
# iLQG at time-step: 23
# experiment: 44
# iLQG at time-step: 24
# experiment: 44
# iLQG at time-step: 25
# experiment: 44
# iLQG at time-step: 26
# experiment: 44
# iLQG at time-step: 27
# experiment: 44
# iLQG at time-step: 28
# experiment: 44
# iLQG at time-step: 29
# experiment: 44
# iLQG at time-step: 30
# experiment: 44
# iLQG at time-step: 31
# experiment: 44
# iLQG at time-step: 32
# experiment: 44
# iLQG at time-step: 33
# experiment: 44
# iLQG at time-step: 34
# experiment: 44
# iLQG at time-step: 35
# experiment: 44
# iLQG at time-step: 36
# experiment: 44
# iLQG at time-step: 37
# experiment: 44
# iLQG at time-step: 38
# experiment: 44
# iLQG at time-step: 39
# experiment: 44
# iLQG at time-step: 40
# experiment: 44
# iLQG at time-step: 41
# experiment: 44
# iLQG at time-step: 42
# experiment: 44
# iLQG at time-step: 43
# experiment: 44
# iLQG at time-step: 44
# experiment: 44
# iLQG at time-step: 45
# experiment: 44
# iLQG at time-step: 46
# experiment: 44
# iLQG at time-step: 47
# experiment: 44
# iLQG at time-step: 48
# experiment: 44
# iLQG at time-step: 0
# experiment: 45
# iLQG at time-step: 1
# experiment: 45
# iLQG at time-step: 2
# experiment: 45
# iLQG at time-step: 3
# experiment: 45
# iLQG at time-step: 4
# experiment: 45
# iLQG at time-step: 5
# experiment: 45
# iLQG at time-step: 6
# experiment: 45
# iLQG at time-step: 7
# experiment: 45
# iLQG at time-step: 8
# experiment: 45
# iLQG at time-step: 9
# experiment: 45
# iLQG at time-step: 10
# experiment: 45
# iLQG at time-step: 11
# experiment: 45
# iLQG at time-step: 12
# experiment: 45
# iLQG at time-step: 13
# experiment: 45
# iLQG at time-step: 14
# experiment: 45
# iLQG at time-step: 15
# experiment: 45
# iLQG at time-step: 16
# experiment: 45
# iLQG at time-step: 17
# experiment: 45
# iLQG at time-step: 18
# experiment: 45
# iLQG at time-step: 19
# experiment: 45
# iLQG at time-step: 20
# experiment: 45
# iLQG at time-step: 21
# experiment: 45
# iLQG at time-step: 22
# experiment: 45
# iLQG at time-step: 23
# experiment: 45
# iLQG at time-step: 24
# experiment: 45
# iLQG at time-step: 25
# experiment: 45
# iLQG at time-step: 26
# experiment: 45
# iLQG at time-step: 27
# experiment: 45
# iLQG at time-step: 28
# experiment: 45
# iLQG at time-step: 29
# experiment: 45
# iLQG at time-step: 30
# experiment: 45
# iLQG at time-step: 31
# experiment: 45
# iLQG at time-step: 32
# experiment: 45
# iLQG at time-step: 33
# experiment: 45
# iLQG at time-step: 34
# experiment: 45
# iLQG at time-step: 35
# experiment: 45
# iLQG at time-step: 36
# experiment: 45
# iLQG at time-step: 37
# experiment: 45
# iLQG at time-step: 38
# experiment: 45
# iLQG at time-step: 39
# experiment: 45
# iLQG at time-step: 40
# experiment: 45
# iLQG at time-step: 41
# experiment: 45
# iLQG at time-step: 42
# experiment: 45
# iLQG at time-step: 43
# experiment: 45
# iLQG at time-step: 44
# experiment: 45
# iLQG at time-step: 45
# experiment: 45
# iLQG at time-step: 46
# experiment: 45
# iLQG at time-step: 47
# experiment: 45
# iLQG at time-step: 48
# experiment: 45
# iLQG at time-step: 0
# experiment: 46
# iLQG at time-step: 1
# experiment: 46
# iLQG at time-step: 2
# experiment: 46
# iLQG at time-step: 3
# experiment: 46
# iLQG at time-step: 4
# experiment: 46
# iLQG at time-step: 5
# experiment: 46
# iLQG at time-step: 6
# experiment: 46
# iLQG at time-step: 7
# experiment: 46
# iLQG at time-step: 8
# experiment: 46
# iLQG at time-step: 9
# experiment: 46
# iLQG at time-step: 10
# experiment: 46
# iLQG at time-step: 11
# experiment: 46
# iLQG at time-step: 12
# experiment: 46
# iLQG at time-step: 13
# experiment: 46
# iLQG at time-step: 14
# experiment: 46
# iLQG at time-step: 15
# experiment: 46
# iLQG at time-step: 16
# experiment: 46
# iLQG at time-step: 17
# experiment: 46
# iLQG at time-step: 18
# experiment: 46
# iLQG at time-step: 19
# experiment: 46
# iLQG at time-step: 20
# experiment: 46
# iLQG at time-step: 21
# experiment: 46
# iLQG at time-step: 22
# experiment: 46
# iLQG at time-step: 23
# experiment: 46
# iLQG at time-step: 24
# experiment: 46
# iLQG at time-step: 25
# experiment: 46
# iLQG at time-step: 26
# experiment: 46
# iLQG at time-step: 27
# experiment: 46
# iLQG at time-step: 28
# experiment: 46
# iLQG at time-step: 29
# experiment: 46
# iLQG at time-step: 30
# experiment: 46
# iLQG at time-step: 31
# experiment: 46
# iLQG at time-step: 32
# experiment: 46
# iLQG at time-step: 33
# experiment: 46
# iLQG at time-step: 34
# experiment: 46
# iLQG at time-step: 35
# experiment: 46
# iLQG at time-step: 36
# experiment: 46
# iLQG at time-step: 37
# experiment: 46
# iLQG at time-step: 38
# experiment: 46
# iLQG at time-step: 39
# experiment: 46
# iLQG at time-step: 40
# experiment: 46
# iLQG at time-step: 41
# experiment: 46
# iLQG at time-step: 42
# experiment: 46
# iLQG at time-step: 43
# experiment: 46
# iLQG at time-step: 44
# experiment: 46
# iLQG at time-step: 45
# experiment: 46
# iLQG at time-step: 46
# experiment: 46
# iLQG at time-step: 47
# experiment: 46
# iLQG at time-step: 48
# experiment: 46
# iLQG at time-step: 0
# experiment: 47
# iLQG at time-step: 1
# experiment: 47
# iLQG at time-step: 2
# experiment: 47
# iLQG at time-step: 3
# experiment: 47
# iLQG at time-step: 4
# experiment: 47
# iLQG at time-step: 5
# experiment: 47
# iLQG at time-step: 6
# experiment: 47
# iLQG at time-step: 7
# experiment: 47
# iLQG at time-step: 8
# experiment: 47
# iLQG at time-step: 9
# experiment: 47
# iLQG at time-step: 10
# experiment: 47
# iLQG at time-step: 11
# experiment: 47
# iLQG at time-step: 12
# experiment: 47
# iLQG at time-step: 13
# experiment: 47
# iLQG at time-step: 14
# experiment: 47
# iLQG at time-step: 15
# experiment: 47
# iLQG at time-step: 16
# experiment: 47
# iLQG at time-step: 17
# experiment: 47
# iLQG at time-step: 18
# experiment: 47
# iLQG at time-step: 19
# experiment: 47
# iLQG at time-step: 20
# experiment: 47
# iLQG at time-step: 21
# experiment: 47
# iLQG at time-step: 22
# experiment: 47
# iLQG at time-step: 23
# experiment: 47
# iLQG at time-step: 24
# experiment: 47
# iLQG at time-step: 25
# experiment: 47
# iLQG at time-step: 26
# experiment: 47
# iLQG at time-step: 27
# experiment: 47
# iLQG at time-step: 28
# experiment: 47
# iLQG at time-step: 29
# experiment: 47
# iLQG at time-step: 30
# experiment: 47
# iLQG at time-step: 31
# experiment: 47
# iLQG at time-step: 32
# experiment: 47
# iLQG at time-step: 33
# experiment: 47
# iLQG at time-step: 34
# experiment: 47
# iLQG at time-step: 35
# experiment: 47
# iLQG at time-step: 36
# experiment: 47
# iLQG at time-step: 37
# experiment: 47
# iLQG at time-step: 38
# experiment: 47
# iLQG at time-step: 39
# experiment: 47
# iLQG at time-step: 40
# experiment: 47
# iLQG at time-step: 41
# experiment: 47
# iLQG at time-step: 42
# experiment: 47
# iLQG at time-step: 43
# experiment: 47
# iLQG at time-step: 44
# experiment: 47
# iLQG at time-step: 45
# experiment: 47
# iLQG at time-step: 46
# experiment: 47
# iLQG at time-step: 47
# experiment: 47
# iLQG at time-step: 48
# experiment: 47
# iLQG at time-step: 0
# experiment: 48
# iLQG at time-step: 1
# experiment: 48
# iLQG at time-step: 2
# experiment: 48
# iLQG at time-step: 3
# experiment: 48
# iLQG at time-step: 4
# experiment: 48
# iLQG at time-step: 5
# experiment: 48
# iLQG at time-step: 6
# experiment: 48
# iLQG at time-step: 7
# experiment: 48
# iLQG at time-step: 8
# experiment: 48
# iLQG at time-step: 9
# experiment: 48
# iLQG at time-step: 10
# experiment: 48
# iLQG at time-step: 11
# experiment: 48
# iLQG at time-step: 12
# experiment: 48
# iLQG at time-step: 13
# experiment: 48
# iLQG at time-step: 14
# experiment: 48
# iLQG at time-step: 15
# experiment: 48
# iLQG at time-step: 16
# experiment: 48
# iLQG at time-step: 17
# experiment: 48
# iLQG at time-step: 18
# experiment: 48
# iLQG at time-step: 19
# experiment: 48
# iLQG at time-step: 20
# experiment: 48
# iLQG at time-step: 21
# experiment: 48
# iLQG at time-step: 22
# experiment: 48
# iLQG at time-step: 23
# experiment: 48
# iLQG at time-step: 24
# experiment: 48
# iLQG at time-step: 25
# experiment: 48
# iLQG at time-step: 26
# experiment: 48
# iLQG at time-step: 27
# experiment: 48
# iLQG at time-step: 28
# experiment: 48
# iLQG at time-step: 29
# experiment: 48
# iLQG at time-step: 30
# experiment: 48
# iLQG at time-step: 31
# experiment: 48
# iLQG at time-step: 32
# experiment: 48
# iLQG at time-step: 33
# experiment: 48
# iLQG at time-step: 34
# experiment: 48
# iLQG at time-step: 35
# experiment: 48
# iLQG at time-step: 36
# experiment: 48
# iLQG at time-step: 37
# experiment: 48
# iLQG at time-step: 38
# experiment: 48
# iLQG at time-step: 39
# experiment: 48
# iLQG at time-step: 40
# experiment: 48
# iLQG at time-step: 41
# experiment: 48
# iLQG at time-step: 42
# experiment: 48
# iLQG at time-step: 43
# experiment: 48
# iLQG at time-step: 44
# experiment: 48
# iLQG at time-step: 45
# experiment: 48
# iLQG at time-step: 46
# experiment: 48
# iLQG at time-step: 47
# experiment: 48
# iLQG at time-step: 48
# experiment: 48
# iLQG at time-step: 0
# experiment: 49
# iLQG at time-step: 1
# experiment: 49
# iLQG at time-step: 2
# experiment: 49
# iLQG at time-step: 3
# experiment: 49
# iLQG at time-step: 4
# experiment: 49
# iLQG at time-step: 5
# experiment: 49
# iLQG at time-step: 6
# experiment: 49
# iLQG at time-step: 7
# experiment: 49
# iLQG at time-step: 8
# experiment: 49
# iLQG at time-step: 9
# experiment: 49
# iLQG at time-step: 10
# experiment: 49
# iLQG at time-step: 11
# experiment: 49
# iLQG at time-step: 12
# experiment: 49
# iLQG at time-step: 13
# experiment: 49
# iLQG at time-step: 14
# experiment: 49
# iLQG at time-step: 15
# experiment: 49
# iLQG at time-step: 16
# experiment: 49
# iLQG at time-step: 17
# experiment: 49
# iLQG at time-step: 18
# experiment: 49
# iLQG at time-step: 19
# experiment: 49
# iLQG at time-step: 20
# experiment: 49
# iLQG at time-step: 21
# experiment: 49
# iLQG at time-step: 22
# experiment: 49
# iLQG at time-step: 23
# experiment: 49
# iLQG at time-step: 24
# experiment: 49
# iLQG at time-step: 25
# experiment: 49
# iLQG at time-step: 26
# experiment: 49
# iLQG at time-step: 27
# experiment: 49
# iLQG at time-step: 28
# experiment: 49
# iLQG at time-step: 29
# experiment: 49
# iLQG at time-step: 30
# experiment: 49
# iLQG at time-step: 31
# experiment: 49
# iLQG at time-step: 32
# experiment: 49
# iLQG at time-step: 33
# experiment: 49
# iLQG at time-step: 34
# experiment: 49
# iLQG at time-step: 35
# experiment: 49
# iLQG at time-step: 36
# experiment: 49
# iLQG at time-step: 37
# experiment: 49
# iLQG at time-step: 38
# experiment: 49
# iLQG at time-step: 39
# experiment: 49
# iLQG at time-step: 40
# experiment: 49
# iLQG at time-step: 41
# experiment: 49
# iLQG at time-step: 42
# experiment: 49
# iLQG at time-step: 43
# experiment: 49
# iLQG at time-step: 44
# experiment: 49
# iLQG at time-step: 45
# experiment: 49
# iLQG at time-step: 46
# experiment: 49
# iLQG at time-step: 47
# experiment: 49
# iLQG at time-step: 48
# experiment: 49
# iLQG at time-step: 0
# experiment: 50
# iLQG at time-step: 1
# experiment: 50
# iLQG at time-step: 2
# experiment: 50
# iLQG at time-step: 3
# experiment: 50
# iLQG at time-step: 4
# experiment: 50
# iLQG at time-step: 5
# experiment: 50
# iLQG at time-step: 6
# experiment: 50
# iLQG at time-step: 7
# experiment: 50
# iLQG at time-step: 8
# experiment: 50
# iLQG at time-step: 9
# experiment: 50
# iLQG at time-step: 10
# experiment: 50
# iLQG at time-step: 11
# experiment: 50
# iLQG at time-step: 12
# experiment: 50
# iLQG at time-step: 13
# experiment: 50
# iLQG at time-step: 14
# experiment: 50
# iLQG at time-step: 15
# experiment: 50
# iLQG at time-step: 16
# experiment: 50
# iLQG at time-step: 17
# experiment: 50
# iLQG at time-step: 18
# experiment: 50
# iLQG at time-step: 19
# experiment: 50
# iLQG at time-step: 20
# experiment: 50
# iLQG at time-step: 21
# experiment: 50
# iLQG at time-step: 22
# experiment: 50
# iLQG at time-step: 23
# experiment: 50
# iLQG at time-step: 24
# experiment: 50
# iLQG at time-step: 25
# experiment: 50
# iLQG at time-step: 26
# experiment: 50
# iLQG at time-step: 27
# experiment: 50
# iLQG at time-step: 28
# experiment: 50
# iLQG at time-step: 29
# experiment: 50
# iLQG at time-step: 30
# experiment: 50
# iLQG at time-step: 31
# experiment: 50
# iLQG at time-step: 32
# experiment: 50
# iLQG at time-step: 33
# experiment: 50
# iLQG at time-step: 34
# experiment: 50
# iLQG at time-step: 35
# experiment: 50
# iLQG at time-step: 36
# experiment: 50
# iLQG at time-step: 37
# experiment: 50
# iLQG at time-step: 38
# experiment: 50
# iLQG at time-step: 39
# experiment: 50
# iLQG at time-step: 40
# experiment: 50
# iLQG at time-step: 41
# experiment: 50
# iLQG at time-step: 42
# experiment: 50
# iLQG at time-step: 43
# experiment: 50
# iLQG at time-step: 44
# experiment: 50
# iLQG at time-step: 45
# experiment: 50
# iLQG at time-step: 46
# experiment: 50
# iLQG at time-step: 47
# experiment: 50
# iLQG at time-step: 48
# experiment: 50
# EKF - MSE LOSS: tensor(-16.6680) [dB]
# LQG cost: 44.71070324513606 [dB]
# Finished LQG simulation

# %% [markdown]
# ### Run iLQG

# %%
# iLQG params
max_iter=50
regu_init=100

# LOSS
loss_fn = nn.MSELoss(reduction='mean')
# MSE [Linear]
MSE_EKF_linear_arr = torch.empty(N_trials)

# # Init state
# m1x_0 = np.array([-2.0, 0.0, 0.6*np.pi, 0.0])
# m2x_0 = np.zeros([n_x,n_x])

# Reset control sequence
u_trj_new = np.empty([N_trials, num_time_pts-1, n_u])
# Reset state
x_trj_new = np.empty([N_trials, num_time_pts, n_x])
x_hat_trj_new = np.empty([N_trials, num_time_pts, n_x])
ilqg_cost_arr = np.empty([N_trials])
# Run Monte-Carlo iLQG 
for i in range(N_trials):
    print("Run experiment: " + str(i+1) )
    
    # Set init state
    x_trj_new[i, 0, :] = m1x_0
    x_hat_trj_new[i, 0, :] = m1x_0

    m1x_posterior = m1x_0
    m2x_posterior = m2x_0
    
    # Init noise for current experiment
    q_noise = Q_noise[i]
    r_noise = R_noise[i]

    # Run iLQG over full trajectory
    for k in range(0, num_time_pts-1):
        # Run iLQG
        tt1 = time.time()
        x_trj_ilqr, u_trj_ilqr, cost_trace, regu_trace, redu_ratio_trace, redu_trace = run_ilqr(x_hat_trj_new[i, k, :], num_time_pts, max_iter, regu_init)
        print("iLQG at time-step: " + str(k) + "\nexperiment: " + str(i+1) + "\nelapsed time: " + str(time.time() - tt1) + "\ncost = " + str(cost_trace[-1]))
        # Update control sequence
        u_trj_new[i, k] = u_trj_ilqr[0]
        # State-Space Evolution
        x_trj_new[i, k+1, :] = rk4singlestep(x_trj_new[i, k, :], u_trj_new[i, k]) + q_noise[:, k]
        # Measurement model
        y = h(x_trj_new[i, k+1, :]) + r_noise[:, k]
        # State Estimation
        m1x_posterior, m2x_posterior = run_EKF(y, u_trj_new[i, k], m1x_posterior, m2x_posterior, W, V)
        x_hat_trj_new[i, k+1, :] = m1x_posterior

    
    MSE_EKF_linear_arr[i] = loss_fn(torch.tensor(x_hat_trj_new[i, :, :]), torch.tensor(x_trj_new[i, :, :])).item()    
    ilqg_cost_arr[i] = cost_trj(x_trj_new[i, :, :], u_trj_new[i, :])/N_trials

MSE_EKF_linear_avg = torch.mean(MSE_EKF_linear_arr)
MSE_EKF_dB_avg = 10 * torch.log10(MSE_EKF_linear_avg)

iLQG_cost_dB = 10 * np.log10(ilqg_cost_arr.mean())

print("EKF - MSE LOSS:", MSE_EKF_dB_avg, "[dB]")
print("iLQG cost:", iLQG_cost_dB, "[dB]")

print("Finished iLQG simulation")
# # Run LQG
# max_iter=1
# tt = time.time()
# x_trj_lqr, u_trj_lqr, cost_trace_lqr, regu_trace_lqr, redu_ratio_trace_lqr, redu_trace_lqr = run_ilqr(y0, num_time_pts, max_iter, regu_init, alg='lqr')
# print("LQR timer: " + str(time.time() - tt) )
# Out:
# Run experiment: 1
# iLQG at time-step: 0
# experiment: 1
# elapsed time: 1.9179394245147705
# cost = 23886.539486246067
# iLQG at time-step: 1
# experiment: 1
# elapsed time: 1.526982069015503
# cost = 15945.783442719827
# iLQG at time-step: 2
# experiment: 1
# elapsed time: 1.4385204315185547
# cost = 10577.547070898256
# iLQG at time-step: 3
# experiment: 1
# elapsed time: 1.4385912418365479
# cost = 7071.203069257866
# iLQG at time-step: 4
# experiment: 1
# elapsed time: 1.4405076503753662
# cost = 3423.9054339245895
# iLQG at time-step: 5
# experiment: 1
# elapsed time: 1.4281413555145264
# cost = 2197.4343955776417
# iLQG at time-step: 6
# experiment: 1
# elapsed time: 1.427105188369751
# cost = 2125.419882051209
# iLQG at time-step: 7
# experiment: 1
# elapsed time: 1.424565076828003
# cost = 2079.656169279836
# iLQG at time-step: 8
# experiment: 1
# elapsed time: 1.3496146202087402
# cost = 1565.7461559596977
# iLQG at time-step: 9
# experiment: 1
# elapsed time: 1.3433380126953125
# cost = 1506.3243612631718
# iLQG at time-step: 10
# experiment: 1
# elapsed time: 1.3391709327697754
# cost = 1359.5543024878668
# iLQG at time-step: 11
# experiment: 1
# elapsed time: 1.3550493717193604
# cost = 1196.9464581328639
# iLQG at time-step: 12
# experiment: 1
# elapsed time: 1.3494563102722168
# cost = 1075.9739084940973
# iLQG at time-step: 13
# experiment: 1
# elapsed time: 1.256516456604004
# cost = 588.0972796423702
# iLQG at time-step: 14
# experiment: 1
# elapsed time: 1.4421277046203613
# cost = 779.2814954275233
# iLQG at time-step: 15
# experiment: 1
# elapsed time: 1.250075101852417
# cost = 720.3573919948108
# iLQG at time-step: 16
# experiment: 1
# elapsed time: 1.422656774520874
# cost = 701.8745338907826
# iLQG at time-step: 17
# experiment: 1
# elapsed time: 1.4167203903198242
# cost = 471.72904701882135
# iLQG at time-step: 18
# experiment: 1
# elapsed time: 1.3499383926391602
# cost = 404.95212368781915
# iLQG at time-step: 19
# experiment: 1
# elapsed time: 1.333174705505371
# cost = 163.83852982320752
# iLQG at time-step: 20
# experiment: 1
# elapsed time: 1.3366003036499023
# cost = 300.08226521128665
# iLQG at time-step: 21
# experiment: 1
# elapsed time: 1.341482400894165
# cost = 304.75589458930534
# iLQG at time-step: 22
# experiment: 1
# elapsed time: 1.3380365371704102
# cost = 443.3565574602717
# iLQG at time-step: 23
# experiment: 1
# elapsed time: 1.3321893215179443
# cost = 339.80204519700976
# iLQG at time-step: 24
# experiment: 1
# elapsed time: 1.3406918048858643
# cost = 499.2305306437838
# iLQG at time-step: 25
# experiment: 1
# elapsed time: 1.3503444194793701
# cost = 240.21740059845604
# iLQG at time-step: 26
# experiment: 1
# elapsed time: 1.3641996383666992
# cost = 162.7330046555422
# iLQG at time-step: 27
# experiment: 1
# elapsed time: 1.249009370803833
# cost = 158.3840838188038
# iLQG at time-step: 28
# experiment: 1
# elapsed time: 1.3348627090454102
# cost = 80.46825363755069
# iLQG at time-step: 29
# experiment: 1
# elapsed time: 1.2494347095489502
# cost = 105.97219220793406
# iLQG at time-step: 30
# experiment: 1
# elapsed time: 1.3427436351776123
# cost = 97.8958344780799
# iLQG at time-step: 31
# experiment: 1
# elapsed time: 1.3486618995666504
# cost = 247.37441051050774
# iLQG at time-step: 32
# experiment: 1
# elapsed time: 1.3333334922790527
# cost = 318.16706009654325
# iLQG at time-step: 33
# experiment: 1
# elapsed time: 1.4175081253051758
# cost = 448.4441560275258
# iLQG at time-step: 34
# experiment: 1
# elapsed time: 1.4311399459838867
# cost = 586.8361961344473
# iLQG at time-step: 35
# experiment: 1
# elapsed time: 1.3368537425994873
# cost = 167.08377294192442
# iLQG at time-step: 36
# experiment: 1
# elapsed time: 1.346961498260498
# cost = 68.72034318661602
# iLQG at time-step: 37
# experiment: 1
# elapsed time: 1.4320459365844727
# cost = 66.90767699607464
# iLQG at time-step: 38
# experiment: 1
# elapsed time: 1.3289074897766113
# cost = 47.87761416908014
# iLQG at time-step: 39
# experiment: 1
# elapsed time: 1.3380253314971924
# cost = 135.7978329319844
# iLQG at time-step: 40
# experiment: 1
# elapsed time: 1.3371422290802002
# cost = 127.20293881561014
# iLQG at time-step: 41
# experiment: 1
# elapsed time: 1.4390177726745605
# cost = 162.8508456199441
# iLQG at time-step: 42
# experiment: 1
# elapsed time: 1.4291141033172607
# cost = 149.15866377896543
# iLQG at time-step: 43
# experiment: 1
# elapsed time: 1.3397126197814941
# cost = 60.821348121218506
# iLQG at time-step: 44
# experiment: 1
# elapsed time: 1.3575129508972168
# cost = 47.408427227109655
# iLQG at time-step: 45
# experiment: 1
# elapsed time: 1.3321819305419922
# cost = 136.10304323503482
# iLQG at time-step: 46
# experiment: 1
# elapsed time: 1.3307077884674072
# cost = 68.33582541583499
# iLQG at time-step: 47
# experiment: 1
# elapsed time: 1.4313998222351074
# cost = 86.07765735131827
# iLQG at time-step: 48
# experiment: 1
# elapsed time: 1.3332343101501465
# cost = 29.43790624264536
# Run experiment: 2
# iLQG at time-step: 0
# experiment: 2
# elapsed time: 1.9161415100097656
# cost = 23886.53948624609
# iLQG at time-step: 1
# experiment: 2
# elapsed time: 1.5810625553131104
# cost = 19136.473151287828
# iLQG at time-step: 2
# experiment: 2
# elapsed time: 1.429931402206421
# cost = 13895.304861239769
# iLQG at time-step: 3
# experiment: 2
# elapsed time: 1.425269603729248
# cost = 10390.014742742424
# iLQG at time-step: 4
# experiment: 2
# elapsed time: 1.4232864379882812
# cost = 6568.210180959573
# iLQG at time-step: 5
# experiment: 2
# elapsed time: 1.4585542678833008
# cost = 3191.861541815454
# iLQG at time-step: 6
# experiment: 2
# elapsed time: 1.4214227199554443
# cost = 1713.5222614063289
# iLQG at time-step: 7
# experiment: 2
# elapsed time: 1.4224464893341064
# cost = 1326.0826292195688
# iLQG at time-step: 8
# experiment: 2
# elapsed time: 1.3411493301391602
# cost = 1119.6989044577274
# iLQG at time-step: 9
# experiment: 2
# elapsed time: 1.342858076095581
# cost = 804.9453445232851
# iLQG at time-step: 10
# experiment: 2
# elapsed time: 1.4246330261230469
# cost = 1097.118515430983
# iLQG at time-step: 11
# experiment: 2
# elapsed time: 1.4276618957519531
# cost = 1049.100375041709
# iLQG at time-step: 12
# experiment: 2
# elapsed time: 1.428560733795166
# cost = 835.5643678224728
# iLQG at time-step: 13
# experiment: 2
# elapsed time: 1.2521235942840576
# cost = 369.0986793806198
# iLQG at time-step: 14
# experiment: 2
# elapsed time: 1.4328787326812744
# cost = 313.82292165739335
# iLQG at time-step: 15
# experiment: 2
# elapsed time: 1.4218378067016602
# cost = 339.3955267319672
# iLQG at time-step: 16
# experiment: 2
# elapsed time: 1.4173619747161865
# cost = 465.61601589451084
# iLQG at time-step: 17
# experiment: 2
# elapsed time: 1.4211947917938232
# cost = 618.9038583170178
# iLQG at time-step: 18
# experiment: 2
# elapsed time: 1.4203901290893555
# cost = 902.0460376189
# iLQG at time-step: 19
# experiment: 2
# elapsed time: 1.3493132591247559
# cost = 702.4812906680437
# iLQG at time-step: 20
# experiment: 2
# elapsed time: 1.3391883373260498
# cost = 742.8865528964448
# iLQG at time-step: 21
# experiment: 2
# elapsed time: 1.4304594993591309
# cost = 490.49974945393785
# iLQG at time-step: 22
# experiment: 2
# elapsed time: 1.4273335933685303
# cost = 474.59475107618135
# iLQG at time-step: 23
# experiment: 2
# elapsed time: 1.3330934047698975
# cost = 272.8821411484452
# iLQG at time-step: 24
# experiment: 2
# elapsed time: 1.3483479022979736
# cost = 281.75801341448806
# iLQG at time-step: 25
# experiment: 2
# elapsed time: 1.3386201858520508
# cost = 180.30231447810158
# iLQG at time-step: 26
# experiment: 2
# elapsed time: 1.4133954048156738
# cost = 336.0137242673358
# iLQG at time-step: 27
# experiment: 2
# elapsed time: 1.340191125869751
# cost = 139.99266151268893
# iLQG at time-step: 28
# experiment: 2
# elapsed time: 1.2540977001190186
# cost = 87.73620500608621
# iLQG at time-step: 29
# experiment: 2
# elapsed time: 1.343458890914917
# cost = 52.58577880219478
# iLQG at time-step: 30
# experiment: 2
# elapsed time: 1.3328602313995361
# cost = 44.9690839619383
# iLQG at time-step: 31
# experiment: 2
# elapsed time: 1.3271358013153076
# cost = 104.01145477410608
# iLQG at time-step: 32
# experiment: 2
# elapsed time: 1.430156946182251
# cost = 141.05451322146087
# iLQG at time-step: 33
# experiment: 2
# elapsed time: 1.2486851215362549
# cost = 118.02169997426346
# iLQG at time-step: 34
# experiment: 2
# elapsed time: 1.3561949729919434
# cost = 160.91534058280453
# iLQG at time-step: 35
# experiment: 2
# elapsed time: 1.3303461074829102
# cost = 178.0810910077025
# iLQG at time-step: 36
# experiment: 2
# elapsed time: 1.3469884395599365
# cost = 317.67090753380165
# iLQG at time-step: 37
# experiment: 2
# elapsed time: 1.3311488628387451
# cost = 279.0859834007886
# iLQG at time-step: 38
# experiment: 2
# elapsed time: 1.3401436805725098
# cost = 254.20267840541172
# iLQG at time-step: 39
# experiment: 2
# elapsed time: 1.4326632022857666
# cost = 185.2832672405066
# iLQG at time-step: 40
# experiment: 2
# elapsed time: 1.4168150424957275
# cost = 483.4174645290997
# iLQG at time-step: 41
# experiment: 2
# elapsed time: 1.2489712238311768
# cost = 394.15077337390846
# iLQG at time-step: 42
# experiment: 2
# elapsed time: 1.4262609481811523
# cost = 661.9688622054707
# iLQG at time-step: 43
# experiment: 2
# elapsed time: 1.3364713191986084
# cost = 468.3614171493488
# iLQG at time-step: 44
# experiment: 2
# elapsed time: 1.3396892547607422
# cost = 440.53712070035544
# iLQG at time-step: 45
# experiment: 2
# elapsed time: 1.246932029724121
# cost = 515.4975906838526
# iLQG at time-step: 46
# experiment: 2
# elapsed time: 1.350311040878296
# cost = 422.6915193671074
# iLQG at time-step: 47
# experiment: 2
# elapsed time: 1.3346045017242432
# cost = 520.3642898586191
# iLQG at time-step: 48
# experiment: 2
# elapsed time: 1.3467285633087158
# cost = 921.605450812603
# Run experiment: 3
# iLQG at time-step: 0
# experiment: 3
# elapsed time: 1.9164540767669678
# cost = 23886.53948624609
# iLQG at time-step: 1
# experiment: 3
# elapsed time: 1.5869059562683105
# cost = 17937.277694853827
# iLQG at time-step: 2
# experiment: 3
# elapsed time: 1.4986965656280518
# cost = 13805.254592118037
# iLQG at time-step: 3
# experiment: 3
# elapsed time: 1.5059149265289307
# cost = 12152.046553350197
# iLQG at time-step: 4
# experiment: 3
# elapsed time: 1.4238829612731934
# cost = 7481.518006138674
# iLQG at time-step: 5
# experiment: 3
# elapsed time: 1.4302265644073486
# cost = 4624.613506484754
# iLQG at time-step: 6
# experiment: 3
# elapsed time: 1.4151241779327393
# cost = 2220.5879891502736
# iLQG at time-step: 7
# experiment: 3
# elapsed time: 1.423302173614502
# cost = 1587.4257050833962
# iLQG at time-step: 8
# experiment: 3
# elapsed time: 1.4235565662384033
# cost = 1093.4515479304075
# iLQG at time-step: 9
# experiment: 3
# elapsed time: 1.4342963695526123
# cost = 943.4962344207639
# iLQG at time-step: 10
# experiment: 3
# elapsed time: 1.3387129306793213
# cost = 866.9987706708957
# iLQG at time-step: 11
# experiment: 3
# elapsed time: 1.342726230621338
# cost = 937.689361941176
# iLQG at time-step: 12
# experiment: 3
# elapsed time: 1.338667631149292
# cost = 401.2193768458336
# iLQG at time-step: 13
# experiment: 3
# elapsed time: 1.3371813297271729
# cost = 1030.4660627825049
# iLQG at time-step: 14
# experiment: 3
# elapsed time: 1.4420843124389648
# cost = 719.9887348775076
# iLQG at time-step: 15
# experiment: 3
# elapsed time: 1.3320095539093018
# cost = 487.093372980253
# iLQG at time-step: 16
# experiment: 3
# elapsed time: 1.3101675510406494
# cost = 505.6757677351804
# iLQG at time-step: 17
# experiment: 3
# elapsed time: 1.3353667259216309
# cost = 564.5597986113214
# iLQG at time-step: 18
# experiment: 3
# elapsed time: 1.3471214771270752
# cost = 581.1285277906222
# iLQG at time-step: 19
# experiment: 3
# elapsed time: 1.346156120300293
# cost = 515.5967618913502
# iLQG at time-step: 20
# experiment: 3
# elapsed time: 1.3379921913146973
# cost = 537.6851278183512
# iLQG at time-step: 21
# experiment: 3
# elapsed time: 1.3564963340759277
# cost = 346.6589034307909
# iLQG at time-step: 22
# experiment: 3
# elapsed time: 1.3332219123840332
# cost = 394.08868433362534
# iLQG at time-step: 23
# experiment: 3
# elapsed time: 1.3481919765472412
# cost = 373.4707403471715
# iLQG at time-step: 24
# experiment: 3
# elapsed time: 1.3356654644012451
# cost = 330.23598828451486
# iLQG at time-step: 25
# experiment: 3
# elapsed time: 1.424750804901123
# cost = 298.9716903178291
# iLQG at time-step: 26
# experiment: 3
# elapsed time: 1.252232551574707
# cost = 144.62508722315638
# iLQG at time-step: 27
# experiment: 3
# elapsed time: 1.3529675006866455
# cost = 249.43194111630854
# iLQG at time-step: 28
# experiment: 3
# elapsed time: 1.2520575523376465
# cost = 243.60118441611633
# iLQG at time-step: 29
# experiment: 3
# elapsed time: 1.3343157768249512
# cost = 401.9968934628543
# iLQG at time-step: 30
# experiment: 3
# elapsed time: 1.3444721698760986
# cost = 292.2696751808109
# iLQG at time-step: 31
# experiment: 3
# elapsed time: 1.4275872707366943
# cost = 380.74681322919236
# iLQG at time-step: 32
# experiment: 3
# elapsed time: 1.3304574489593506
# cost = 317.2391417960679
# iLQG at time-step: 33
# experiment: 3
# elapsed time: 1.3310070037841797
# cost = 187.96689359155997
# iLQG at time-step: 34
# experiment: 3
# elapsed time: 1.336613416671753
# cost = 82.90990806472588
# iLQG at time-step: 35
# experiment: 3
# elapsed time: 1.3388440608978271
# cost = 168.39567529051635
# iLQG at time-step: 36
# experiment: 3
# elapsed time: 1.3560500144958496
# cost = 227.84455426890884
# iLQG at time-step: 37
# experiment: 3
# elapsed time: 1.2506651878356934
# cost = 465.12020542064016
# iLQG at time-step: 38
# experiment: 3
# elapsed time: 1.3560099601745605
# cost = 382.66585800102285
# iLQG at time-step: 39
# experiment: 3
# elapsed time: 1.3364627361297607
# cost = 120.60686105305182
# iLQG at time-step: 40
# experiment: 3
# elapsed time: 1.3444221019744873
# cost = 399.44014357261904
# iLQG at time-step: 41
# experiment: 3
# elapsed time: 1.422025203704834
# cost = 295.20043359386693
# iLQG at time-step: 42
# experiment: 3
# elapsed time: 1.3393409252166748
# cost = 114.02815137915636
# iLQG at time-step: 43
# experiment: 3
# elapsed time: 1.3359582424163818
# cost = 220.45734258765253
# iLQG at time-step: 44
# experiment: 3
# elapsed time: 1.2591578960418701
# cost = 62.26377252537911
# iLQG at time-step: 45
# experiment: 3
# elapsed time: 1.3395683765411377
# cost = 64.42538072315061
# iLQG at time-step: 46
# experiment: 3
# elapsed time: 1.3344106674194336
# cost = 65.41533224715748
# iLQG at time-step: 47
# experiment: 3
# elapsed time: 1.3455066680908203
# cost = 120.98197706604655
# iLQG at time-step: 48
# experiment: 3
# elapsed time: 1.3395037651062012
# cost = 133.95782263412516
# Run experiment: 4
# iLQG at time-step: 0
# experiment: 4
# elapsed time: 1.9190502166748047
# cost = 23886.53948624607
# iLQG at time-step: 1
# experiment: 4
# elapsed time: 1.489799976348877
# cost = 18506.517331940053
# iLQG at time-step: 2
# experiment: 4
# elapsed time: 1.41823148727417
# cost = 12206.646184148516
# iLQG at time-step: 3
# experiment: 4
# elapsed time: 1.4213244915008545
# cost = 7153.906166115011
# iLQG at time-step: 4
# experiment: 4
# elapsed time: 1.4273416996002197
# cost = 4211.939810527034
# iLQG at time-step: 5
# experiment: 4
# elapsed time: 1.416977882385254
# cost = 2776.99261427613
# iLQG at time-step: 6
# experiment: 4
# elapsed time: 1.4211173057556152
# cost = 1521.7211847909286
# iLQG at time-step: 7
# experiment: 4
# elapsed time: 1.4296844005584717
# cost = 1065.7157243468291
# iLQG at time-step: 8
# experiment: 4
# elapsed time: 1.3536601066589355
# cost = 701.4076926097232
# iLQG at time-step: 9
# experiment: 4
# elapsed time: 1.3385446071624756
# cost = 702.1099527975146
# iLQG at time-step: 10
# experiment: 4
# elapsed time: 1.3573689460754395
# cost = 723.8400508322255
# iLQG at time-step: 11
# experiment: 4
# elapsed time: 1.3648767471313477
# cost = 827.6501865454484
# iLQG at time-step: 12
# experiment: 4
# elapsed time: 1.4552972316741943
# cost = 921.4672804359765
# iLQG at time-step: 13
# experiment: 4
# elapsed time: 1.447411298751831
# cost = 666.7197357009486
# iLQG at time-step: 14
# experiment: 4
# elapsed time: 1.3620967864990234
# cost = 429.2007180702955
# iLQG at time-step: 15
# experiment: 4
# elapsed time: 1.3495416641235352
# cost = 274.06727253310584
# iLQG at time-step: 16
# experiment: 4
# elapsed time: 1.434877872467041
# cost = 267.49739566250844
# iLQG at time-step: 17
# experiment: 4
# elapsed time: 1.34675931930542
# cost = 77.90809183439956
# iLQG at time-step: 18
# experiment: 4
# elapsed time: 1.3414630889892578
# cost = 105.9666014795404
# iLQG at time-step: 19
# experiment: 4
# elapsed time: 1.330378770828247
# cost = 33.1724407161787
# iLQG at time-step: 20
# experiment: 4
# elapsed time: 1.3287849426269531
# cost = 71.84042356366183
# iLQG at time-step: 21
# experiment: 4
# elapsed time: 1.3497498035430908
# cost = 102.3231094059906
# iLQG at time-step: 22
# experiment: 4
# elapsed time: 1.4242994785308838
# cost = 341.1798303484417
# iLQG at time-step: 23
# experiment: 4
# elapsed time: 1.336160659790039
# cost = 276.21200987895196
# iLQG at time-step: 24
# experiment: 4
# elapsed time: 1.259735345840454
# cost = 324.4739596130979
# iLQG at time-step: 25
# experiment: 4
# elapsed time: 1.2634036540985107
# cost = 311.3269901500028
# iLQG at time-step: 26
# experiment: 4
# elapsed time: 1.3346500396728516
# cost = 328.06319619464495
# iLQG at time-step: 27
# experiment: 4
# elapsed time: 1.3414971828460693
# cost = 669.8568272278369
# iLQG at time-step: 28
# experiment: 4
# elapsed time: 1.3503124713897705
# cost = 1126.5633665997225
# iLQG at time-step: 29
# experiment: 4
# elapsed time: 1.3390576839447021
# cost = 1162.5056163597621
# iLQG at time-step: 30
# experiment: 4
# elapsed time: 1.3516440391540527
# cost = 1374.6657976039494
# iLQG at time-step: 31
# experiment: 4
# elapsed time: 1.4341208934783936
# cost = 1597.5142391445038
# iLQG at time-step: 32
# experiment: 4
# elapsed time: 1.340975284576416
# cost = 1200.2012197405577
# iLQG at time-step: 33
# experiment: 4
# elapsed time: 1.331862211227417
# cost = 979.5532143517423
# iLQG at time-step: 34
# experiment: 4
# elapsed time: 1.2610445022583008
# cost = 689.7934979883144
# iLQG at time-step: 35
# experiment: 4
# elapsed time: 1.2491495609283447
# cost = 626.7201602799663
# iLQG at time-step: 36
# experiment: 4
# elapsed time: 1.2665314674377441
# cost = 601.5592969681637
# iLQG at time-step: 37
# experiment: 4
# elapsed time: 1.3356986045837402
# cost = 493.37781781123175
# iLQG at time-step: 38
# experiment: 4
# elapsed time: 1.2683384418487549
# cost = 367.8932445331253
# iLQG at time-step: 39
# experiment: 4
# elapsed time: 1.3413567543029785
# cost = 412.183904370708
# iLQG at time-step: 40
# experiment: 4
# elapsed time: 1.3396015167236328
# cost = 501.4561672676339
# iLQG at time-step: 41
# experiment: 4
# elapsed time: 1.2510433197021484
# cost = 470.12408062268287
# iLQG at time-step: 42
# experiment: 4
# elapsed time: 1.3491103649139404
# cost = 644.4593077686047
# iLQG at time-step: 43
# experiment: 4
# elapsed time: 1.3490402698516846
# cost = 959.7682027828214
# iLQG at time-step: 44
# experiment: 4
# elapsed time: 1.3355703353881836
# cost = 1183.5819888536364
# iLQG at time-step: 45
# experiment: 4
# elapsed time: 1.339831829071045
# cost = 922.6742714207343
# iLQG at time-step: 46
# experiment: 4
# elapsed time: 1.3387491703033447
# cost = 530.146716935138
# iLQG at time-step: 47
# experiment: 4
# elapsed time: 1.2451274394989014
# cost = 524.731379620583
# iLQG at time-step: 48
# experiment: 4
# elapsed time: 1.3471705913543701
# cost = 235.27705553534545
# Run experiment: 5
# iLQG at time-step: 0
# experiment: 5
# elapsed time: 1.9169609546661377
# cost = 23886.539486246078
# iLQG at time-step: 1
# experiment: 5
# elapsed time: 1.5799171924591064
# cost = 19891.578756078845
# iLQG at time-step: 2
# experiment: 5
# elapsed time: 1.5001816749572754
# cost = 17118.953871350037
# iLQG at time-step: 3
# experiment: 5
# elapsed time: 1.4177863597869873
# cost = 11143.083693876913
# iLQG at time-step: 4
# experiment: 5
# elapsed time: 1.4169459342956543
# cost = 6691.419574455486
# iLQG at time-step: 5
# experiment: 5
# elapsed time: 1.4179587364196777
# cost = 3765.44009038429
# iLQG at time-step: 6
# experiment: 5
# elapsed time: 1.4309701919555664
# cost = 2134.668242492605
# iLQG at time-step: 7
# experiment: 5
# elapsed time: 1.4163269996643066
# cost = 954.2332066957201
# iLQG at time-step: 8
# experiment: 5
# elapsed time: 1.417250394821167
# cost = 581.5660467859748
# iLQG at time-step: 9
# experiment: 5
# elapsed time: 1.4345123767852783
# cost = 389.52087162888046
# iLQG at time-step: 10
# experiment: 5
# elapsed time: 1.4282560348510742
# cost = 374.9778264977601
# iLQG at time-step: 11
# experiment: 5
# elapsed time: 1.4160869121551514
# cost = 198.5006735894679
# iLQG at time-step: 12
# experiment: 5
# elapsed time: 1.327880859375
# cost = 136.8465553397048
# iLQG at time-step: 13
# experiment: 5
# elapsed time: 1.4262967109680176
# cost = 75.23832979160053
# iLQG at time-step: 14
# experiment: 5
# elapsed time: 1.4366450309753418
# cost = 134.34934930008032
# iLQG at time-step: 15
# experiment: 5
# elapsed time: 1.4187657833099365
# cost = 128.03986339607803
# iLQG at time-step: 16
# experiment: 5
# elapsed time: 1.341461420059204
# cost = 245.03608300740376
# iLQG at time-step: 17
# experiment: 5
# elapsed time: 1.3372714519500732
# cost = 34.87893366081596
# iLQG at time-step: 18
# experiment: 5
# elapsed time: 1.2480120658874512
# cost = 155.29746290558148
# iLQG at time-step: 19
# experiment: 5
# elapsed time: 1.26106595993042
# cost = 2.3931200466516356
# iLQG at time-step: 20
# experiment: 5
# elapsed time: 1.2459397315979004
# cost = 19.506166682337074
# iLQG at time-step: 21
# experiment: 5
# elapsed time: 1.3483915328979492
# cost = 11.28323019095392
# iLQG at time-step: 22
# experiment: 5
# elapsed time: 1.3308587074279785
# cost = 34.6845341587285
# iLQG at time-step: 23
# experiment: 5
# elapsed time: 1.3345568180084229
# cost = 146.56202147453192
# iLQG at time-step: 24
# experiment: 5
# elapsed time: 1.4281504154205322
# cost = 314.83860607664946
# iLQG at time-step: 25
# experiment: 5
# elapsed time: 1.415666103363037
# cost = 379.5761841586076
# iLQG at time-step: 26
# experiment: 5
# elapsed time: 1.3342559337615967
# cost = 434.8047356929353
# iLQG at time-step: 27
# experiment: 5
# elapsed time: 1.3388593196868896
# cost = 286.1473411955784
# iLQG at time-step: 28
# experiment: 5
# elapsed time: 1.335893154144287
# cost = 258.56637475305234
# iLQG at time-step: 29
# experiment: 5
# elapsed time: 1.3407955169677734
# cost = 285.5608326812362
# iLQG at time-step: 30
# experiment: 5
# elapsed time: 1.249645471572876
# cost = 176.49650491126806
# iLQG at time-step: 31
# experiment: 5
# elapsed time: 1.3410851955413818
# cost = 179.3435452492769
# iLQG at time-step: 32
# experiment: 5
# elapsed time: 1.2669391632080078
# cost = 115.97018072885368
# iLQG at time-step: 33
# experiment: 5
# elapsed time: 1.3597135543823242
# cost = 80.58316273511383
# iLQG at time-step: 34
# experiment: 5
# elapsed time: 1.4466898441314697
# cost = 131.68665158081757
# iLQG at time-step: 35
# experiment: 5
# elapsed time: 1.3521592617034912
# cost = 109.95102584932734
# iLQG at time-step: 36
# experiment: 5
# elapsed time: 1.3491666316986084
# cost = 74.8746062324641
# iLQG at time-step: 37
# experiment: 5
# elapsed time: 1.334167242050171
# cost = 40.446535695131246
# iLQG at time-step: 38
# experiment: 5
# elapsed time: 1.1828649044036865
# cost = 55.17625106901222
# iLQG at time-step: 39
# experiment: 5
# elapsed time: 1.3301637172698975
# cost = 57.69336147581337
# iLQG at time-step: 40
# experiment: 5
# elapsed time: 1.3445510864257812
# cost = 124.71940586705611
# iLQG at time-step: 41
# experiment: 5
# elapsed time: 1.3308601379394531
# cost = 83.94952199884284
# iLQG at time-step: 42
# experiment: 5
# elapsed time: 1.4274406433105469
# cost = 113.37081794406647
# iLQG at time-step: 43
# experiment: 5
# elapsed time: 1.422100305557251
# cost = 175.898524947021
# iLQG at time-step: 44
# experiment: 5
# elapsed time: 1.3318092823028564
# cost = 57.08885581978525
# iLQG at time-step: 45
# experiment: 5
# elapsed time: 1.4088175296783447
# cost = 98.91139059016477
# iLQG at time-step: 46
# experiment: 5
# elapsed time: 1.3441338539123535
# cost = 79.59224222061506
# iLQG at time-step: 47
# experiment: 5
# elapsed time: 1.2446658611297607
# cost = 98.99681104539484
# iLQG at time-step: 48
# experiment: 5
# elapsed time: 1.3373053073883057
# cost = 94.27361963010175
# Run experiment: 6
# iLQG at time-step: 0
# experiment: 6
# elapsed time: 1.9199800491333008
# cost = 23886.53948624607
# iLQG at time-step: 1
# experiment: 6
# elapsed time: 1.6578078269958496
# cost = 21536.43032293397
# iLQG at time-step: 2
# experiment: 6
# elapsed time: 1.4974334239959717
# cost = 15930.748005829279
# iLQG at time-step: 3
# experiment: 6
# elapsed time: 1.491265058517456
# cost = 13199.633904784678
# iLQG at time-step: 4
# experiment: 6
# elapsed time: 1.424055814743042
# cost = 9041.71828356537
# iLQG at time-step: 5
# experiment: 6
# elapsed time: 1.4193487167358398
# cost = 4970.866421297651
# iLQG at time-step: 6
# experiment: 6
# elapsed time: 1.4117825031280518
# cost = 3209.361015892936
# iLQG at time-step: 7
# experiment: 6
# elapsed time: 1.4986605644226074
# cost = 2224.324047101928
# iLQG at time-step: 8
# experiment: 6
# elapsed time: 1.4158759117126465
# cost = 1326.2138744436127
# iLQG at time-step: 9
# experiment: 6
# elapsed time: 1.3296499252319336
# cost = 1078.4952071360951
# iLQG at time-step: 10
# experiment: 6
# elapsed time: 1.3540780544281006
# cost = 1337.0669353378396
# iLQG at time-step: 11
# experiment: 6
# elapsed time: 1.3409647941589355
# cost = 971.9140294304259
# iLQG at time-step: 12
# experiment: 6
# elapsed time: 1.3411362171173096
# cost = 1068.968854899984
# iLQG at time-step: 13
# experiment: 6
# elapsed time: 1.331723690032959
# cost = 977.7669266680423
# iLQG at time-step: 14
# experiment: 6
# elapsed time: 1.433351993560791
# cost = 1108.0096395252608
# iLQG at time-step: 15
# experiment: 6
# elapsed time: 1.3293383121490479
# cost = 288.3640342652061
# iLQG at time-step: 16
# experiment: 6
# elapsed time: 1.3347992897033691
# cost = 144.9201453157988
# iLQG at time-step: 17
# experiment: 6
# elapsed time: 1.3321943283081055
# cost = 202.80280576286842
# iLQG at time-step: 18
# experiment: 6
# elapsed time: 1.3338367938995361
# cost = 322.71783426262897
# iLQG at time-step: 19
# experiment: 6
# elapsed time: 1.4127702713012695
# cost = 329.1529153455962
# iLQG at time-step: 20
# experiment: 6
# elapsed time: 1.4252090454101562
# cost = 230.85623365317474
# iLQG at time-step: 21
# experiment: 6
# elapsed time: 1.423130989074707
# cost = 207.5587651275818
# iLQG at time-step: 22
# experiment: 6
# elapsed time: 1.3344388008117676
# cost = 252.84349751948577
# iLQG at time-step: 23
# experiment: 6
# elapsed time: 1.3564393520355225
# cost = 270.9609650079773
# iLQG at time-step: 24
# experiment: 6
# elapsed time: 1.3316762447357178
# cost = 310.82930143417184
# iLQG at time-step: 25
# experiment: 6
# elapsed time: 1.3266942501068115
# cost = 136.19538814763436
# iLQG at time-step: 26
# experiment: 6
# elapsed time: 1.4145703315734863
# cost = 268.3633828140118
# iLQG at time-step: 27
# experiment: 6
# elapsed time: 1.3210787773132324
# cost = 185.8165561980405
# iLQG at time-step: 28
# experiment: 6
# elapsed time: 1.3327569961547852
# cost = 64.07007018207969
# iLQG at time-step: 29
# experiment: 6
# elapsed time: 1.320295810699463
# cost = 172.02109027349601
# iLQG at time-step: 30
# experiment: 6
# elapsed time: 1.3198375701904297
# cost = 106.71257942000372
# iLQG at time-step: 31
# experiment: 6
# elapsed time: 1.4318242073059082
# cost = 518.5808046744669
# iLQG at time-step: 32
# experiment: 6
# elapsed time: 1.3330292701721191
# cost = 300.1265402513148
# iLQG at time-step: 33
# experiment: 6
# elapsed time: 1.3316538333892822
# cost = 222.61257892143024
# iLQG at time-step: 34
# experiment: 6
# elapsed time: 1.3383541107177734
# cost = 459.0420437483962
# iLQG at time-step: 35
# experiment: 6
# elapsed time: 1.3301866054534912
# cost = 579.0448516530205
# iLQG at time-step: 36
# experiment: 6
# elapsed time: 1.34706711769104
# cost = 438.4486204551964
# iLQG at time-step: 37
# experiment: 6
# elapsed time: 1.243034839630127
# cost = 382.1455600329274
# iLQG at time-step: 38
# experiment: 6
# elapsed time: 1.3434762954711914
# cost = 238.67831065541162
# iLQG at time-step: 39
# experiment: 6
# elapsed time: 1.1643965244293213
# cost = 259.0371410900086
# iLQG at time-step: 40
# experiment: 6
# elapsed time: 1.3352255821228027
# cost = 159.0668171766696
# iLQG at time-step: 41
# experiment: 6
# elapsed time: 1.2438976764678955
# cost = 166.66643768667018
# iLQG at time-step: 42
# experiment: 6
# elapsed time: 1.3532233238220215
# cost = 320.6200275901094
# iLQG at time-step: 43
# experiment: 6
# elapsed time: 1.4302027225494385
# cost = 587.7361836288785
# iLQG at time-step: 44
# experiment: 6
# elapsed time: 1.329068899154663
# cost = 433.72028980634934
# iLQG at time-step: 45
# experiment: 6
# elapsed time: 1.2451848983764648
# cost = 345.90314084208234
# iLQG at time-step: 46
# experiment: 6
# elapsed time: 1.3455290794372559
# cost = 713.8455869951919
# iLQG at time-step: 47
# experiment: 6
# elapsed time: 1.3469290733337402
# cost = 1250.9835226958173
# iLQG at time-step: 48
# experiment: 6
# elapsed time: 1.3410401344299316
# cost = 1195.6204470654407
# Run experiment: 7
# iLQG at time-step: 0
# experiment: 7
# elapsed time: 1.9150850772857666
# cost = 23886.539486246074
# iLQG at time-step: 1
# experiment: 7
# elapsed time: 1.6564538478851318
# cost = 19501.69566257504
# iLQG at time-step: 2
# experiment: 7
# elapsed time: 1.4991559982299805
# cost = 14514.214543383561
# iLQG at time-step: 3
# experiment: 7
# elapsed time: 1.4090700149536133
# cost = 10248.16507568328
# iLQG at time-step: 4
# experiment: 7
# elapsed time: 1.4159910678863525
# cost = 6234.846728708488
# iLQG at time-step: 5
# experiment: 7
# elapsed time: 1.416426420211792
# cost = 3770.3480926910606
# iLQG at time-step: 6
# experiment: 7
# elapsed time: 1.431502342224121
# cost = 1895.256578902712
# iLQG at time-step: 7
# experiment: 7
# elapsed time: 1.4139893054962158
# cost = 1148.450759604235
# iLQG at time-step: 8
# experiment: 7
# elapsed time: 1.4208707809448242
# cost = 728.6274487535574
# iLQG at time-step: 9
# experiment: 7
# elapsed time: 1.414961576461792
# cost = 394.5234479208583
# iLQG at time-step: 10
# experiment: 7
# elapsed time: 1.3291881084442139
# cost = 276.4319676072561
# iLQG at time-step: 11
# experiment: 7
# elapsed time: 1.263059377670288
# cost = 222.85188289700912
# iLQG at time-step: 12
# experiment: 7
# elapsed time: 1.4238314628601074
# cost = 133.736928469194
# iLQG at time-step: 13
# experiment: 7
# elapsed time: 1.4124884605407715
# cost = 203.17432689685154
# iLQG at time-step: 14
# experiment: 7
# elapsed time: 1.3436977863311768
# cost = 200.9761588316617
# iLQG at time-step: 15
# experiment: 7
# elapsed time: 1.3296427726745605
# cost = 216.5941843467309
# iLQG at time-step: 16
# experiment: 7
# elapsed time: 1.3415415287017822
# cost = 204.94521557108143
# iLQG at time-step: 17
# experiment: 7
# elapsed time: 1.3323118686676025
# cost = 152.2916339685372
# iLQG at time-step: 18
# experiment: 7
# elapsed time: 1.3437728881835938
# cost = 287.06679787661704
# iLQG at time-step: 19
# experiment: 7
# elapsed time: 1.3339531421661377
# cost = 532.1163108812593
# iLQG at time-step: 20
# experiment: 7
# elapsed time: 1.3319511413574219
# cost = 645.6763280065225
# iLQG at time-step: 21
# experiment: 7
# elapsed time: 1.4279465675354004
# cost = 447.9346906884157
# iLQG at time-step: 22
# experiment: 7
# elapsed time: 1.3405053615570068
# cost = 326.57356843222203
# iLQG at time-step: 23
# experiment: 7
# elapsed time: 1.3464345932006836
# cost = 166.6912354909931
# iLQG at time-step: 24
# experiment: 7
# elapsed time: 1.329707384109497
# cost = 368.9683354412582
# iLQG at time-step: 25
# experiment: 7
# elapsed time: 1.357975959777832
# cost = 756.3911864256847
# iLQG at time-step: 26
# experiment: 7
# elapsed time: 1.33585524559021
# cost = 817.0557100987623
# iLQG at time-step: 27
# experiment: 7
# elapsed time: 1.3294239044189453
# cost = 354.63730668737054
# iLQG at time-step: 28
# experiment: 7
# elapsed time: 1.3366458415985107
# cost = 722.0509736785916
# iLQG at time-step: 29
# experiment: 7
# elapsed time: 1.3480288982391357
# cost = 820.1271483731301
# iLQG at time-step: 30
# experiment: 7
# elapsed time: 1.3254070281982422
# cost = 529.7367965047189
# iLQG at time-step: 31
# experiment: 7
# elapsed time: 1.3294830322265625
# cost = 406.4757764669383
# iLQG at time-step: 32
# experiment: 7
# elapsed time: 1.2343285083770752
# cost = 340.1691530832027
# iLQG at time-step: 33
# experiment: 7
# elapsed time: 1.3354651927947998
# cost = 599.5484129012117
# iLQG at time-step: 34
# experiment: 7
# elapsed time: 1.3201382160186768
# cost = 319.3106870730563
# iLQG at time-step: 35
# experiment: 7
# elapsed time: 1.3403491973876953
# cost = 287.6630530121321
# iLQG at time-step: 36
# experiment: 7
# elapsed time: 1.3191719055175781
# cost = 204.0636462370062
# iLQG at time-step: 37
# experiment: 7
# elapsed time: 1.4064204692840576
# cost = 364.15427762340136
# iLQG at time-step: 38
# experiment: 7
# elapsed time: 1.4104151725769043
# cost = 225.51784029059593
# iLQG at time-step: 39
# experiment: 7
# elapsed time: 1.32187819480896
# cost = 150.88808913823095
# iLQG at time-step: 40
# experiment: 7
# elapsed time: 1.3169353008270264
# cost = 161.13329600535573
# iLQG at time-step: 41
# experiment: 7
# elapsed time: 1.2377173900604248
# cost = 226.4858618415753
# iLQG at time-step: 42
# experiment: 7
# elapsed time: 1.309227705001831
# cost = 165.88301339860297
# iLQG at time-step: 43
# experiment: 7
# elapsed time: 1.3279271125793457
# cost = 306.92566157286285
# iLQG at time-step: 44
# experiment: 7
# elapsed time: 1.3112680912017822
# cost = 305.7406974544915
# iLQG at time-step: 45
# experiment: 7
# elapsed time: 1.3177924156188965
# cost = 405.11625788711007
# iLQG at time-step: 46
# experiment: 7
# elapsed time: 1.327733039855957
# cost = 488.28599429581135
# iLQG at time-step: 47
# experiment: 7
# elapsed time: 1.3157198429107666
# cost = 390.22271447882093
# iLQG at time-step: 48
# experiment: 7
# elapsed time: 1.3107357025146484
# cost = 77.51676874915759
# Run experiment: 8
# iLQG at time-step: 0
# experiment: 8
# elapsed time: 1.8927156925201416
# cost = 23886.539486246067
# iLQG at time-step: 1
# experiment: 8
# elapsed time: 1.7340679168701172
# cost = 22248.532715595964
# iLQG at time-step: 2
# experiment: 8
# elapsed time: 1.4759628772735596
# cost = 16636.270476353722
# iLQG at time-step: 3
# experiment: 8
# elapsed time: 1.40547513961792
# cost = 10772.883702095738
# iLQG at time-step: 4
# experiment: 8
# elapsed time: 1.4313020706176758
# cost = 6389.58110540518
# iLQG at time-step: 5
# experiment: 8
# elapsed time: 1.5124990940093994
# cost = 3598.5546408033283
# iLQG at time-step: 6
# experiment: 8
# elapsed time: 1.4182624816894531
# cost = 1800.809710520138
# iLQG at time-step: 7
# experiment: 8
# elapsed time: 1.4135284423828125
# cost = 945.419950775051
# iLQG at time-step: 8
# experiment: 8
# elapsed time: 1.4242899417877197
# cost = 400.2192837706506
# iLQG at time-step: 9
# experiment: 8
# elapsed time: 1.428710699081421
# cost = 266.25454777072906
# iLQG at time-step: 10
# experiment: 8
# elapsed time: 1.3286256790161133
# cost = 66.4658559531622
# iLQG at time-step: 11
# experiment: 8
# elapsed time: 1.3247356414794922
# cost = 37.82077917863111
# iLQG at time-step: 12
# experiment: 8
# elapsed time: 1.3222432136535645
# cost = 17.40728988106952
# iLQG at time-step: 13
# experiment: 8
# elapsed time: 1.3166418075561523
# cost = 19.215041143299576
# iLQG at time-step: 14
# experiment: 8
# elapsed time: 1.4292938709259033
# cost = 50.02291553727921
# iLQG at time-step: 15
# experiment: 8
# elapsed time: 1.3262016773223877
# cost = 30.55633708975439
# iLQG at time-step: 16
# experiment: 8
# elapsed time: 1.2768006324768066
# cost = 15.951748812761906
# iLQG at time-step: 17
# experiment: 8
# elapsed time: 1.3295629024505615
# cost = 123.26460103465583
# iLQG at time-step: 18
# experiment: 8
# elapsed time: 1.2456319332122803
# cost = 116.37322691764868
# iLQG at time-step: 19
# experiment: 8
# elapsed time: 1.4330873489379883
# cost = 335.6753147859211
# iLQG at time-step: 20
# experiment: 8
# elapsed time: 1.412329912185669
# cost = 355.71935053996856
# iLQG at time-step: 21
# experiment: 8
# elapsed time: 1.3362011909484863
# cost = 253.47595875142002
# iLQG at time-step: 22
# experiment: 8
# elapsed time: 1.3378803730010986
# cost = 359.46263236881424
# iLQG at time-step: 23
# experiment: 8
# elapsed time: 1.333721399307251
# cost = 235.4113438612787
# iLQG at time-step: 24
# experiment: 8
# elapsed time: 1.33848237991333
# cost = 263.0037093184217
# iLQG at time-step: 25
# experiment: 8
# elapsed time: 1.3400850296020508
# cost = 268.94901511249583
# iLQG at time-step: 26
# experiment: 8
# elapsed time: 1.4128437042236328
# cost = 293.28551755664785
# iLQG at time-step: 27
# experiment: 8
# elapsed time: 1.3303828239440918
# cost = 151.78435662689213
# iLQG at time-step: 28
# experiment: 8
# elapsed time: 1.3331451416015625
# cost = 379.79552858539046
# iLQG at time-step: 29
# experiment: 8
# elapsed time: 1.3314290046691895
# cost = 344.86702695792553
# iLQG at time-step: 30
# experiment: 8
# elapsed time: 1.3413398265838623
# cost = 217.24055881571945
# iLQG at time-step: 31
# experiment: 8
# elapsed time: 1.3454480171203613
# cost = 155.83883196537423
# iLQG at time-step: 32
# experiment: 8
# elapsed time: 1.3278582096099854
# cost = 255.3372607659722
# iLQG at time-step: 33
# experiment: 8
# elapsed time: 1.329416275024414
# cost = 264.0439530869631
# iLQG at time-step: 34
# experiment: 8
# elapsed time: 1.3276829719543457
# cost = 239.71649962197313
# iLQG at time-step: 35
# experiment: 8
# elapsed time: 1.328080415725708
# cost = 278.0469191500561
# iLQG at time-step: 36
# experiment: 8
# elapsed time: 1.3420732021331787
# cost = 223.6858139715107
# iLQG at time-step: 37
# experiment: 8
# elapsed time: 1.2442290782928467
# cost = 282.4855478855603
# iLQG at time-step: 38
# experiment: 8
# elapsed time: 1.420682668685913
# cost = 312.3180091540815
# iLQG at time-step: 39
# experiment: 8
# elapsed time: 1.3366377353668213
# cost = 290.8723290357905
# iLQG at time-step: 40
# experiment: 8
# elapsed time: 1.331674575805664
# cost = 244.83905213605405
# iLQG at time-step: 41
# experiment: 8
# elapsed time: 1.3321113586425781
# cost = 279.90437498518395
# iLQG at time-step: 42
# experiment: 8
# elapsed time: 1.3396005630493164
# cost = 397.81477227752504
# iLQG at time-step: 43
# experiment: 8
# elapsed time: 1.3286583423614502
# cost = 329.6722888425946
# iLQG at time-step: 44
# experiment: 8
# elapsed time: 1.2548532485961914
# cost = 308.15687334787737
# iLQG at time-step: 45
# experiment: 8
# elapsed time: 1.3371570110321045
# cost = 235.45572142062582
# iLQG at time-step: 46
# experiment: 8
# elapsed time: 1.321610450744629
# cost = 457.1139785799684
# iLQG at time-step: 47
# experiment: 8
# elapsed time: 1.3435397148132324
# cost = 739.0031981543978
# iLQG at time-step: 48
# experiment: 8
# elapsed time: 1.3332931995391846
# cost = 408.08811574401153
# Run experiment: 9
# iLQG at time-step: 0
# experiment: 9
# elapsed time: 1.8916680812835693
# cost = 23886.53948624608
# iLQG at time-step: 1
# experiment: 9
# elapsed time: 1.7336702346801758
# cost = 22398.391006229704
# iLQG at time-step: 2
# experiment: 9
# elapsed time: 1.6503918170928955
# cost = 20848.68932874966
# iLQG at time-step: 3
# experiment: 9
# elapsed time: 1.5680277347564697
# cost = 17076.802090110363
# iLQG at time-step: 4
# experiment: 9
# elapsed time: 1.3984429836273193
# cost = 10763.839047088502
# iLQG at time-step: 5
# experiment: 9
# elapsed time: 1.3998081684112549
# cost = 7567.091643253377
# iLQG at time-step: 6
# experiment: 9
# elapsed time: 1.4096791744232178
# cost = 3795.4147210400697
# iLQG at time-step: 7
# experiment: 9
# elapsed time: 1.404999017715454
# cost = 1873.7184307905056
# iLQG at time-step: 8
# experiment: 9
# elapsed time: 1.4150145053863525
# cost = 1240.276755605605
# iLQG at time-step: 9
# experiment: 9
# elapsed time: 1.4023737907409668
# cost = 770.6321295391173
# iLQG at time-step: 10
# experiment: 9
# elapsed time: 1.4024245738983154
# cost = 772.7389273141174
# iLQG at time-step: 11
# experiment: 9
# elapsed time: 1.3225955963134766
# cost = 217.41110749816679
# iLQG at time-step: 12
# experiment: 9
# elapsed time: 1.2453877925872803
# cost = 135.13688739194635
# iLQG at time-step: 13
# experiment: 9
# elapsed time: 1.3931052684783936
# cost = 220.71544378958765
# iLQG at time-step: 14
# experiment: 9
# elapsed time: 1.323150396347046
# cost = 83.20805044868476
# iLQG at time-step: 15
# experiment: 9
# elapsed time: 1.316279411315918
# cost = 311.81802881839246
# iLQG at time-step: 16
# experiment: 9
# elapsed time: 1.3149144649505615
# cost = 283.6406747347415
# iLQG at time-step: 17
# experiment: 9
# elapsed time: 1.3307337760925293
# cost = 374.29094970882255
# iLQG at time-step: 18
# experiment: 9
# elapsed time: 1.317192554473877
# cost = 309.7751078020684
# iLQG at time-step: 19
# experiment: 9
# elapsed time: 1.3292500972747803
# cost = 233.65608343177158
# iLQG at time-step: 20
# experiment: 9
# elapsed time: 1.313046932220459
# cost = 183.28425968857496
# iLQG at time-step: 21
# experiment: 9
# elapsed time: 1.23038911819458
# cost = 129.19171058828792
# iLQG at time-step: 22
# experiment: 9
# elapsed time: 1.3239960670471191
# cost = 200.69809420819374
# iLQG at time-step: 23
# experiment: 9
# elapsed time: 1.310633659362793
# cost = 208.8466021456488
# iLQG at time-step: 24
# experiment: 9
# elapsed time: 1.3952531814575195
# cost = 232.8025666420624
# iLQG at time-step: 25
# experiment: 9
# elapsed time: 1.4051902294158936
# cost = 256.66183781307194
# iLQG at time-step: 26
# experiment: 9
# elapsed time: 1.4081790447235107
# cost = 191.74412908170515
# iLQG at time-step: 27
# experiment: 9
# elapsed time: 1.317199468612671
# cost = 99.61098742280775
# iLQG at time-step: 28
# experiment: 9
# elapsed time: 1.3289029598236084
# cost = 139.38858259887235
# iLQG at time-step: 29
# experiment: 9
# elapsed time: 1.4026641845703125
# cost = 99.00036367610144
# iLQG at time-step: 30
# experiment: 9
# elapsed time: 1.3970756530761719
# cost = 105.21215969466101
# iLQG at time-step: 31
# experiment: 9
# elapsed time: 1.1449177265167236
# cost = 163.13496335743952
# iLQG at time-step: 32
# experiment: 9
# elapsed time: 1.2390999794006348
# cost = 59.44978285302541
# iLQG at time-step: 33
# experiment: 9
# elapsed time: 1.3348596096038818
# cost = 106.38659212292842
# iLQG at time-step: 34
# experiment: 9
# elapsed time: 1.3141486644744873
# cost = 121.47402061456876
# iLQG at time-step: 35
# experiment: 9
# elapsed time: 1.327033519744873
# cost = 204.38339168317813
# iLQG at time-step: 36
# experiment: 9
# elapsed time: 1.3140950202941895
# cost = 146.78456340444305
# iLQG at time-step: 37
# experiment: 9
# elapsed time: 1.3151705265045166
# cost = 160.83974852554184
# iLQG at time-step: 38
# experiment: 9
# elapsed time: 1.3198215961456299
# cost = 108.3990096605802
# iLQG at time-step: 39
# experiment: 9
# elapsed time: 1.346703290939331
# cost = 104.08500445891246
# iLQG at time-step: 40
# experiment: 9
# elapsed time: 1.3305931091308594
# cost = 140.74843408129644
# iLQG at time-step: 41
# experiment: 9
# elapsed time: 1.3274805545806885
# cost = 201.13491270460665
# iLQG at time-step: 42
# experiment: 9
# elapsed time: 1.3333325386047363
# cost = 245.1149171833255
# iLQG at time-step: 43
# experiment: 9
# elapsed time: 1.3297178745269775
# cost = 128.16002778383915
# iLQG at time-step: 44
# experiment: 9
# elapsed time: 1.3367810249328613
# cost = 103.07004903279706
# iLQG at time-step: 45
# experiment: 9
# elapsed time: 1.2417702674865723
# cost = 119.44149006255277
# iLQG at time-step: 46
# experiment: 9
# elapsed time: 1.2593863010406494
# cost = 85.87330977274209
# iLQG at time-step: 47
# experiment: 9
# elapsed time: 1.2587971687316895
# cost = 71.92837325448332
# iLQG at time-step: 48
# experiment: 9
# elapsed time: 1.3516333103179932
# cost = 324.1537276704772
# Run experiment: 10
# iLQG at time-step: 0
# experiment: 10
# elapsed time: 1.9168329238891602
# cost = 23886.539486246078
# iLQG at time-step: 1
# experiment: 10
# elapsed time: 1.5826616287231445
# cost = 18329.808078220012
# iLQG at time-step: 2
# experiment: 10
# elapsed time: 1.5030531883239746
# cost = 14866.884591107342
# iLQG at time-step: 3
# experiment: 10
# elapsed time: 1.41786789894104
# cost = 10947.094107124552
# iLQG at time-step: 4
# experiment: 10
# elapsed time: 1.4179847240447998
# cost = 7695.127300132677
# iLQG at time-step: 5
# experiment: 10
# elapsed time: 1.416877031326294
# cost = 4235.105687668423
# iLQG at time-step: 6
# experiment: 10
# elapsed time: 1.5164921283721924
# cost = 2574.2764207115565
# iLQG at time-step: 7
# experiment: 10
# elapsed time: 1.4163053035736084
# cost = 1502.5862745489655
# iLQG at time-step: 8
# experiment: 10
# elapsed time: 1.416957139968872
# cost = 925.1669072607112
# iLQG at time-step: 9
# experiment: 10
# elapsed time: 1.4452104568481445
# cost = 614.2847955369219
# iLQG at time-step: 10
# experiment: 10
# elapsed time: 1.3301334381103516
# cost = 425.6388087190118
# iLQG at time-step: 11
# experiment: 10
# elapsed time: 1.421147108078003
# cost = 477.47413033338404
# iLQG at time-step: 12
# experiment: 10
# elapsed time: 1.4241111278533936
# cost = 987.3397171654649
# iLQG at time-step: 13
# experiment: 10
# elapsed time: 1.4171974658966064
# cost = 888.9795036196763
# iLQG at time-step: 14
# experiment: 10
# elapsed time: 1.3335576057434082
# cost = 652.9062324839613
# iLQG at time-step: 15
# experiment: 10
# elapsed time: 1.256242036819458
# cost = 686.105320969356
# iLQG at time-step: 16
# experiment: 10
# elapsed time: 1.3362047672271729
# cost = 692.2348737227583
# iLQG at time-step: 17
# experiment: 10
# elapsed time: 1.3335163593292236
# cost = 429.1035966532941
# iLQG at time-step: 18
# experiment: 10
# elapsed time: 1.2416374683380127
# cost = 445.14971691673907
# iLQG at time-step: 19
# experiment: 10
# elapsed time: 1.2594845294952393
# cost = 426.23254245676105
# iLQG at time-step: 20
# experiment: 10
# elapsed time: 1.3173236846923828
# cost = 620.1370611633155
# iLQG at time-step: 21
# experiment: 10
# elapsed time: 1.3239705562591553
# cost = 904.569765916014
# iLQG at time-step: 22
# experiment: 10
# elapsed time: 1.236480712890625
# cost = 619.8631545401493
# iLQG at time-step: 23
# experiment: 10
# elapsed time: 1.3384804725646973
# cost = 737.3612046667636
# iLQG at time-step: 24
# experiment: 10
# elapsed time: 1.3307361602783203
# cost = 618.8870942906563
# iLQG at time-step: 25
# experiment: 10
# elapsed time: 1.2351455688476562
# cost = 517.9026405759996
# iLQG at time-step: 26
# experiment: 10
# elapsed time: 1.239166021347046
# cost = 545.6631226485913
# iLQG at time-step: 27
# experiment: 10
# elapsed time: 1.3314998149871826
# cost = 565.4291434139184
# iLQG at time-step: 28
# experiment: 10
# elapsed time: 1.3341951370239258
# cost = 525.723125760691
# iLQG at time-step: 29
# experiment: 10
# elapsed time: 1.3142585754394531
# cost = 446.02959386132176
# iLQG at time-step: 30
# experiment: 10
# elapsed time: 1.2349591255187988
# cost = 250.4104132484405
# iLQG at time-step: 31
# experiment: 10
# elapsed time: 1.3295750617980957
# cost = 346.1992702577206
# iLQG at time-step: 32
# experiment: 10
# elapsed time: 1.2350401878356934
# cost = 612.6416471739668
# iLQG at time-step: 33
# experiment: 10
# elapsed time: 1.3204154968261719
# cost = 644.2150729412748
# iLQG at time-step: 34
# experiment: 10
# elapsed time: 1.3195395469665527
# cost = 618.1791521361442
# iLQG at time-step: 35
# experiment: 10
# elapsed time: 1.3549816608428955
# cost = 305.00895352326546
# iLQG at time-step: 36
# experiment: 10
# elapsed time: 1.333216667175293
# cost = 296.02977875562874
# iLQG at time-step: 37
# experiment: 10
# elapsed time: 1.2702624797821045
# cost = 233.90137672244333
# iLQG at time-step: 38
# experiment: 10
# elapsed time: 1.2552564144134521
# cost = 362.56346996033375
# iLQG at time-step: 39
# experiment: 10
# elapsed time: 1.3407783508300781
# cost = 389.756058046197
# iLQG at time-step: 40
# experiment: 10
# elapsed time: 1.348653793334961
# cost = 519.27977983755
# iLQG at time-step: 41
# experiment: 10
# elapsed time: 1.2473340034484863
# cost = 288.1849277767817
# iLQG at time-step: 42
# experiment: 10
# elapsed time: 1.2481391429901123
# cost = 287.28550342554405
# iLQG at time-step: 43
# experiment: 10
# elapsed time: 1.348459243774414
# cost = 169.56720117753142
# iLQG at time-step: 44
# experiment: 10
# elapsed time: 1.3347809314727783
# cost = 238.11174081763176
# iLQG at time-step: 45
# experiment: 10
# elapsed time: 1.332458257675171
# cost = 170.33364653736723
# iLQG at time-step: 46
# experiment: 10
# elapsed time: 1.4206609725952148
# cost = 208.63905238077285
# iLQG at time-step: 47
# experiment: 10
# elapsed time: 1.3277549743652344
# cost = 115.67057662247217
# iLQG at time-step: 48
# experiment: 10
# elapsed time: 1.3243861198425293
# cost = 55.03726566196535
# Run experiment: 11
# iLQG at time-step: 0
# experiment: 11
# elapsed time: 1.9193596839904785
# cost = 23886.539486246085
# iLQG at time-step: 1
# experiment: 11
# elapsed time: 1.5841295719146729
# cost = 19150.084456868553
# iLQG at time-step: 2
# experiment: 11
# elapsed time: 1.4966909885406494
# cost = 14684.693168151502
# iLQG at time-step: 3
# experiment: 11
# elapsed time: 1.429241418838501
# cost = 10652.296559320714
# iLQG at time-step: 4
# experiment: 11
# elapsed time: 1.4141459465026855
# cost = 5609.314159105496
# iLQG at time-step: 5
# experiment: 11
# elapsed time: 1.4290742874145508
# cost = 3519.9349410190125
# iLQG at time-step: 6
# experiment: 11
# elapsed time: 1.4137282371520996
# cost = 2081.30085749349
# iLQG at time-step: 7
# experiment: 11
# elapsed time: 1.4209330081939697
# cost = 1707.9675929723567
# iLQG at time-step: 8
# experiment: 11
# elapsed time: 1.418410301208496
# cost = 1452.5888774843036
# iLQG at time-step: 9
# experiment: 11
# elapsed time: 1.4349195957183838
# cost = 930.4858840811378
# iLQG at time-step: 10
# experiment: 11
# elapsed time: 1.2481191158294678
# cost = 621.9712017361293
# iLQG at time-step: 11
# experiment: 11
# elapsed time: 1.3340773582458496
# cost = 494.5854042092864
# iLQG at time-step: 12
# experiment: 11
# elapsed time: 1.2613716125488281
# cost = 542.1545313258173
# iLQG at time-step: 13
# experiment: 11
# elapsed time: 1.3454585075378418
# cost = 414.46913594782774
# iLQG at time-step: 14
# experiment: 11
# elapsed time: 1.3293709754943848
# cost = 492.06661989737177
# iLQG at time-step: 15
# experiment: 11
# elapsed time: 1.3297927379608154
# cost = 591.7526150128119
# iLQG at time-step: 16
# experiment: 11
# elapsed time: 1.2443747520446777
# cost = 498.6324571732109
# iLQG at time-step: 17
# experiment: 11
# elapsed time: 1.340721845626831
# ...
# experiment: 47
# elapsed time: 1.3197321891784668
# cost = 837.360100042245
# iLQG at time-step: 30
# experiment: 47
# elapsed time: 1.3373100757598877
# cost = 919.3439604341448
# iLQG at time-step: 31
# experiment: 47
# elapsed time: 1.351844072341919
# cost = 723.2896451190908
# iLQG at time-step: 32
# experiment: 47
# elapsed time: 1.3264617919921875
# cost = 586.1707112426648
# iLQG at time-step: 33
# experiment: 47
# elapsed time: 1.321056842803955
# cost = 696.1608609473726
# iLQG at time-step: 34
# experiment: 47
# elapsed time: 1.3336009979248047
# cost = 740.027441235522
# iLQG at time-step: 35
# experiment: 47
# elapsed time: 1.3240065574645996
# cost = 394.5462894869111
# iLQG at time-step: 36
# experiment: 47
# elapsed time: 1.4138495922088623
# cost = 411.35261775122524
# iLQG at time-step: 37
# experiment: 47
# elapsed time: 1.3127999305725098
# cost = 234.41220131319676
# iLQG at time-step: 38
# experiment: 47
# elapsed time: 1.3305041790008545
# cost = 361.83545807036046
# iLQG at time-step: 39
# experiment: 47
# elapsed time: 1.316767930984497
# cost = 78.72266333563809
# iLQG at time-step: 40
# experiment: 47
# elapsed time: 1.4104478359222412
# cost = 179.68595965509215
# iLQG at time-step: 41
# experiment: 47
# elapsed time: 1.3932640552520752
# cost = 206.58020869794316
# iLQG at time-step: 42
# experiment: 47
# elapsed time: 1.2373197078704834
# cost = 139.5726750835399
# iLQG at time-step: 43
# experiment: 47
# elapsed time: 1.312305212020874
# cost = 152.22748828723223
# iLQG at time-step: 44
# experiment: 47
# elapsed time: 1.3226358890533447
# cost = 197.5242981134074
# iLQG at time-step: 45
# experiment: 47
# elapsed time: 1.310434103012085
# cost = 144.76006592405312
# iLQG at time-step: 46
# experiment: 47
# elapsed time: 1.3082995414733887
# cost = 81.41286090422717
# iLQG at time-step: 47
# experiment: 47
# elapsed time: 1.3102314472198486
# cost = 72.31803454857796
# iLQG at time-step: 48
# experiment: 47
# elapsed time: 1.3117902278900146
# cost = 130.3576945525243
# Run experiment: 48
# iLQG at time-step: 0
# experiment: 48
# elapsed time: 1.8855903148651123
# cost = 23886.539486246074
# iLQG at time-step: 1
# experiment: 48
# elapsed time: 1.5690081119537354
# cost = 19242.358621786585
# iLQG at time-step: 2
# experiment: 48
# elapsed time: 1.389549970626831
# cost = 11904.723238088918
# iLQG at time-step: 3
# experiment: 48
# elapsed time: 1.405177354812622
# cost = 10385.602597923977
# iLQG at time-step: 4
# experiment: 48
# elapsed time: 1.393233299255371
# cost = 6395.598818534855
# iLQG at time-step: 5
# experiment: 48
# elapsed time: 1.401057243347168
# cost = 3975.2207255738967
# iLQG at time-step: 6
# experiment: 48
# elapsed time: 1.400099754333496
# cost = 1992.5073552106112
# iLQG at time-step: 7
# experiment: 48
# elapsed time: 1.392024278640747
# cost = 1105.72039583023
# iLQG at time-step: 8
# experiment: 48
# elapsed time: 1.4158198833465576
# cost = 1009.0560054276704
# iLQG at time-step: 9
# experiment: 48
# elapsed time: 1.3953185081481934
# cost = 833.7156400026103
# iLQG at time-step: 10
# experiment: 48
# elapsed time: 1.406036138534546
# cost = 599.2346665541809
# iLQG at time-step: 11
# experiment: 48
# elapsed time: 1.398383378982544
# cost = 540.1398017491531
# iLQG at time-step: 12
# experiment: 48
# elapsed time: 1.3346178531646729
# cost = 203.25934062383834
# iLQG at time-step: 13
# experiment: 48
# elapsed time: 1.3175625801086426
# cost = 116.14403164182878
# iLQG at time-step: 14
# experiment: 48
# elapsed time: 1.4122614860534668
# cost = 150.49507347850502
# iLQG at time-step: 15
# experiment: 48
# elapsed time: 1.3950071334838867
# cost = 126.05695450935208
# iLQG at time-step: 16
# experiment: 48
# elapsed time: 1.247112512588501
# cost = 179.78743529009685
# iLQG at time-step: 17
# experiment: 48
# elapsed time: 1.3196253776550293
# cost = 459.4574733926703
# iLQG at time-step: 18
# experiment: 48
# elapsed time: 1.3145039081573486
# cost = 187.4451715814981
# iLQG at time-step: 19
# experiment: 48
# elapsed time: 1.404895305633545
# cost = 311.53504137146905
# iLQG at time-step: 20
# experiment: 48
# elapsed time: 1.3100783824920654
# cost = 278.96818143612575
# iLQG at time-step: 21
# experiment: 48
# elapsed time: 1.3879022598266602
# cost = 415.836280013847
# iLQG at time-step: 22
# experiment: 48
# elapsed time: 1.3347055912017822
# cost = 519.9832475646544
# iLQG at time-step: 23
# experiment: 48
# elapsed time: 1.400629997253418
# cost = 362.02213606614976
# iLQG at time-step: 24
# experiment: 48
# elapsed time: 1.3122453689575195
# cost = 277.28983372440405
# iLQG at time-step: 25
# experiment: 48
# elapsed time: 1.2273204326629639
# cost = 183.16481573216902
# iLQG at time-step: 26
# experiment: 48
# elapsed time: 1.4080731868743896
# cost = 153.9685633075663
# iLQG at time-step: 27
# experiment: 48
# elapsed time: 1.3217873573303223
# cost = 397.7230130970815
# iLQG at time-step: 28
# experiment: 48
# elapsed time: 1.312276840209961
# cost = 300.9662252333397
# iLQG at time-step: 29
# experiment: 48
# elapsed time: 1.3144350051879883
# cost = 255.09612218305946
# iLQG at time-step: 30
# experiment: 48
# elapsed time: 1.4037630558013916
# cost = 358.5997969559647
# iLQG at time-step: 31
# experiment: 48
# elapsed time: 1.3085784912109375
# cost = 119.91897403753387
# iLQG at time-step: 32
# experiment: 48
# elapsed time: 1.3272290229797363
# cost = 71.03840118152866
# iLQG at time-step: 33
# experiment: 48
# elapsed time: 1.3109321594238281
# cost = 120.70237731605134
# iLQG at time-step: 34
# experiment: 48
# elapsed time: 1.3334565162658691
# cost = 204.60165796253574
# iLQG at time-step: 35
# experiment: 48
# elapsed time: 1.2316348552703857
# cost = 151.2821718769181
# iLQG at time-step: 36
# experiment: 48
# elapsed time: 1.3239529132843018
# cost = 131.04015980099044
# iLQG at time-step: 37
# experiment: 48
# elapsed time: 1.3256638050079346
# cost = 245.9015251298287
# iLQG at time-step: 38
# experiment: 48
# elapsed time: 1.3116376399993896
# cost = 515.9191288456309
# iLQG at time-step: 39
# experiment: 48
# elapsed time: 1.3987703323364258
# cost = 984.6347635752903
# iLQG at time-step: 40
# experiment: 48
# elapsed time: 1.318741798400879
# cost = 411.9350932153013
# iLQG at time-step: 41
# experiment: 48
# elapsed time: 1.3104650974273682
# cost = 166.36229840426662
# iLQG at time-step: 42
# experiment: 48
# elapsed time: 1.3280365467071533
# cost = 198.11513844113253
# iLQG at time-step: 43
# experiment: 48
# elapsed time: 1.2269716262817383
# cost = 255.35089094919348
# iLQG at time-step: 44
# experiment: 48
# elapsed time: 1.3272700309753418
# cost = 260.9414026201637
# iLQG at time-step: 45
# experiment: 48
# elapsed time: 1.3174281120300293
# cost = 214.82907165559092
# iLQG at time-step: 46
# experiment: 48
# elapsed time: 1.4028704166412354
# cost = 322.2444524925737
# iLQG at time-step: 47
# experiment: 48
# elapsed time: 1.2280354499816895
# cost = 151.01083071335523
# iLQG at time-step: 48
# experiment: 48
# elapsed time: 1.3206415176391602
# cost = 165.39882025322606
# Run experiment: 49
# iLQG at time-step: 0
# experiment: 49
# elapsed time: 1.8915112018585205
# cost = 23886.53948624608
# iLQG at time-step: 1
# experiment: 49
# elapsed time: 1.563143253326416
# cost = 19422.297436360215
# iLQG at time-step: 2
# experiment: 49
# elapsed time: 1.4113514423370361
# cost = 15114.839669771478
# iLQG at time-step: 3
# experiment: 49
# elapsed time: 1.3944776058197021
# cost = 8617.804984387303
# iLQG at time-step: 4
# experiment: 49
# elapsed time: 1.4028515815734863
# cost = 5432.759553911611
# iLQG at time-step: 5
# experiment: 49
# elapsed time: 1.3953263759613037
# cost = 2294.574361461852
# iLQG at time-step: 6
# experiment: 49
# elapsed time: 1.4117729663848877
# cost = 1140.7288397474726
# iLQG at time-step: 7
# experiment: 49
# elapsed time: 1.3933145999908447
# cost = 669.7211184796414
# iLQG at time-step: 8
# experiment: 49
# elapsed time: 1.399306058883667
# cost = 352.0911756919293
# iLQG at time-step: 9
# experiment: 49
# elapsed time: 1.4022860527038574
# cost = 417.99400379337123
# iLQG at time-step: 10
# experiment: 49
# elapsed time: 1.4066071510314941
# cost = 417.9758423849627
# iLQG at time-step: 11
# experiment: 49
# elapsed time: 1.406834363937378
# cost = 823.9007223509353
# iLQG at time-step: 12
# experiment: 49
# elapsed time: 1.4137341976165771
# cost = 658.2916243090343
# iLQG at time-step: 13
# experiment: 49
# elapsed time: 1.3229789733886719
# cost = 615.0257763557127
# iLQG at time-step: 14
# experiment: 49
# elapsed time: 1.3230624198913574
# cost = 559.2737765246902
# iLQG at time-step: 15
# experiment: 49
# elapsed time: 1.317000389099121
# cost = 445.57766876221524
# iLQG at time-step: 16
# experiment: 49
# elapsed time: 1.3158669471740723
# cost = 440.1561486973031
# iLQG at time-step: 17
# experiment: 49
# elapsed time: 1.3304240703582764
# cost = 551.1893403394786
# iLQG at time-step: 18
# experiment: 49
# elapsed time: 1.3169755935668945
# cost = 1051.1957091394459
# iLQG at time-step: 19
# experiment: 49
# elapsed time: 1.3385438919067383
# cost = 902.5675480974415
# iLQG at time-step: 20
# experiment: 49
# elapsed time: 1.3151333332061768
# cost = 811.9293431243801
# iLQG at time-step: 21
# experiment: 49
# elapsed time: 1.3985888957977295
# cost = 606.1866286007048
# iLQG at time-step: 22
# experiment: 49
# elapsed time: 1.3349714279174805
# cost = 474.7691704161758
# iLQG at time-step: 23
# experiment: 49
# elapsed time: 1.3131697177886963
# cost = 445.5557576787083
# iLQG at time-step: 24
# experiment: 49
# elapsed time: 1.3201022148132324
# cost = 544.7137498669077
# iLQG at time-step: 25
# experiment: 49
# elapsed time: 1.2416002750396729
# cost = 507.7078262972869
# iLQG at time-step: 26
# experiment: 49
# elapsed time: 1.3209998607635498
# cost = 282.4148126909751
# iLQG at time-step: 27
# experiment: 49
# elapsed time: 1.3133630752563477
# cost = 165.50090230104064
# iLQG at time-step: 28
# experiment: 49
# elapsed time: 1.3235290050506592
# cost = 70.06256782045877
# iLQG at time-step: 29
# experiment: 49
# elapsed time: 1.2292921543121338
# cost = 9.375690231545919
# iLQG at time-step: 30
# experiment: 49
# elapsed time: 1.3299145698547363
# cost = 114.12510839579855
# iLQG at time-step: 31
# experiment: 49
# elapsed time: 1.229391098022461
# cost = 46.20755845662849
# iLQG at time-step: 32
# experiment: 49
# elapsed time: 1.319993019104004
# cost = 38.4186777615926
# iLQG at time-step: 33
# experiment: 49
# elapsed time: 1.313631296157837
# cost = 21.298506941092313
# iLQG at time-step: 34
# experiment: 49
# elapsed time: 1.3252370357513428
# cost = 49.97389848003434
# iLQG at time-step: 35
# experiment: 49
# elapsed time: 1.2350893020629883
# cost = 37.34159953048202
# iLQG at time-step: 36
# experiment: 49
# elapsed time: 1.3213438987731934
# cost = 41.677219899937676
# iLQG at time-step: 37
# experiment: 49
# elapsed time: 1.41593599319458
# cost = 54.0108646046404
# iLQG at time-step: 38
# experiment: 49
# elapsed time: 1.3151414394378662
# cost = 40.9472140341679
# iLQG at time-step: 39
# experiment: 49
# elapsed time: 1.3145174980163574
# cost = 53.5674868617574
# iLQG at time-step: 40
# experiment: 49
# elapsed time: 1.3321053981781006
# cost = 420.4302881923971
# iLQG at time-step: 41
# experiment: 49
# elapsed time: 1.3138165473937988
# cost = 283.6337690315822
# iLQG at time-step: 42
# experiment: 49
# elapsed time: 1.3228354454040527
# cost = 781.5798772215171
# iLQG at time-step: 43
# experiment: 49
# elapsed time: 1.3255672454833984
# cost = 582.7871896018415
# iLQG at time-step: 44
# experiment: 49
# elapsed time: 1.4190120697021484
# cost = 619.9075903657631
# iLQG at time-step: 45
# experiment: 49
# elapsed time: 1.4151132106781006
# cost = 393.70918889641433
# iLQG at time-step: 46
# experiment: 49
# elapsed time: 1.3163330554962158
# cost = 571.8320625873856
# iLQG at time-step: 47
# experiment: 49
# elapsed time: 1.3200602531433105
# cost = 453.96713413719755
# iLQG at time-step: 48
# experiment: 49
# elapsed time: 1.317657232284546
# cost = 446.7168468663656
# Run experiment: 50
# iLQG at time-step: 0
# experiment: 50
# elapsed time: 1.8922772407531738
# cost = 23886.539486246056
# iLQG at time-step: 1
# experiment: 50
# elapsed time: 1.6489486694335938
# cost = 21802.485531354585
# iLQG at time-step: 2
# experiment: 50
# elapsed time: 1.4819185733795166
# cost = 16920.68942552625
# iLQG at time-step: 3
# experiment: 50
# elapsed time: 1.4089434146881104
# cost = 11152.569759771144
# iLQG at time-step: 4
# experiment: 50
# elapsed time: 1.4037811756134033
# cost = 7277.05119038916
# iLQG at time-step: 5
# experiment: 50
# elapsed time: 1.4162070751190186
# cost = 4657.9005320232645
# iLQG at time-step: 6
# experiment: 50
# elapsed time: 1.4082725048065186
# cost = 2890.7857539642255
# iLQG at time-step: 7
# experiment: 50
# elapsed time: 1.4091849327087402
# cost = 1475.6966897674095
# iLQG at time-step: 8
# experiment: 50
# elapsed time: 1.4463157653808594
# cost = 789.5359518978825
# iLQG at time-step: 9
# experiment: 50
# elapsed time: 1.4050941467285156
# cost = 723.0610934017107
# iLQG at time-step: 10
# experiment: 50
# elapsed time: 1.4047183990478516
# cost = 292.7456222019249
# iLQG at time-step: 11
# experiment: 50
# elapsed time: 1.4113869667053223
# cost = 275.1530186771323
# iLQG at time-step: 12
# experiment: 50
# elapsed time: 1.2456624507904053
# cost = 245.60818576413436
# iLQG at time-step: 13
# experiment: 50
# elapsed time: 1.3180391788482666
# cost = 304.9356626049582
# iLQG at time-step: 14
# experiment: 50
# elapsed time: 1.324172019958496
# cost = 259.3250364254634
# iLQG at time-step: 15
# experiment: 50
# elapsed time: 1.3181562423706055
# cost = 109.26148748126745
# iLQG at time-step: 16
# experiment: 50
# elapsed time: 1.2395412921905518
# cost = 89.07245848443418
# iLQG at time-step: 17
# experiment: 50
# elapsed time: 1.3149652481079102
# cost = 58.216948581887365
# iLQG at time-step: 18
# experiment: 50
# elapsed time: 1.2408726215362549
# cost = 48.38506769487897
# iLQG at time-step: 19
# experiment: 50
# elapsed time: 1.311626672744751
# cost = 33.8666296921937
# iLQG at time-step: 20
# experiment: 50
# elapsed time: 1.2825870513916016
# cost = 35.32913059128096
# iLQG at time-step: 21
# experiment: 50
# elapsed time: 1.3118183612823486
# cost = 70.86508710231905
# iLQG at time-step: 22
# experiment: 50
# elapsed time: 1.3198206424713135
# cost = 63.75490442775971
# iLQG at time-step: 23
# experiment: 50
# elapsed time: 1.3912053108215332
# cost = 345.1670851297439
# iLQG at time-step: 24
# experiment: 50
# elapsed time: 1.3213880062103271
# cost = 95.13150418182248
# iLQG at time-step: 25
# experiment: 50
# elapsed time: 1.3123164176940918
# cost = 58.308386633714356
# iLQG at time-step: 26
# experiment: 50
# elapsed time: 1.409099817276001
# cost = 96.35445848052213
# iLQG at time-step: 27
# experiment: 50
# elapsed time: 1.31089448928833
# cost = 212.2406978395222
# iLQG at time-step: 28
# experiment: 50
# elapsed time: 1.315061330795288
# cost = 250.54074239049757
# iLQG at time-step: 29
# experiment: 50
# elapsed time: 1.3398337364196777
# cost = 439.5376259998997
# iLQG at time-step: 30
# experiment: 50
# elapsed time: 1.3139057159423828
# cost = 804.9034944003552
# iLQG at time-step: 31
# experiment: 50
# elapsed time: 1.3320343494415283
# cost = 455.1254194360698
# iLQG at time-step: 32
# experiment: 50
# elapsed time: 1.3971960544586182
# cost = 568.2719903756204
# iLQG at time-step: 33
# experiment: 50
# elapsed time: 1.4046576023101807
# cost = 456.42097513858056
# iLQG at time-step: 34
# experiment: 50
# elapsed time: 1.316593885421753
# cost = 570.6393537186751
# iLQG at time-step: 35
# experiment: 50
# elapsed time: 1.3217108249664307
# cost = 572.6748645014394
# iLQG at time-step: 36
# experiment: 50
# elapsed time: 1.3171963691711426
# cost = 329.480770557485
# iLQG at time-step: 37
# experiment: 50
# elapsed time: 1.3267741203308105
# cost = 327.42579326549003
# iLQG at time-step: 38
# experiment: 50
# elapsed time: 1.3232510089874268
# cost = 240.70519879039048
# iLQG at time-step: 39
# experiment: 50
# elapsed time: 1.3195292949676514
# cost = 165.51536105638243
# iLQG at time-step: 40
# experiment: 50
# elapsed time: 1.3988375663757324
# cost = 91.95581210053342
# iLQG at time-step: 41
# experiment: 50
# elapsed time: 1.3137590885162354
# cost = 97.25780067890722
# iLQG at time-step: 42
# experiment: 50
# elapsed time: 1.308905839920044
# cost = 205.18190215223692
# iLQG at time-step: 43
# experiment: 50
# elapsed time: 1.4003527164459229
# cost = 493.74304583510985
# iLQG at time-step: 44
# experiment: 50
# elapsed time: 1.2388386726379395
# cost = 527.5822273007332
# iLQG at time-step: 45
# experiment: 50
# elapsed time: 1.311361312866211
# cost = 363.63350903042317
# iLQG at time-step: 46
# experiment: 50
# elapsed time: 1.3134195804595947
# cost = 328.41498702970057
# iLQG at time-step: 47
# experiment: 50
# elapsed time: 1.324235200881958
# cost = 354.0420235490047
# iLQG at time-step: 48
# experiment: 50
# elapsed time: 1.3933110237121582
# cost = 475.8790909781212
# EKF - MSE LOSS: tensor(-21.9858) [dB]
# iLQG cost: 27.263572720964117 [dB]
# Finished iLQG simulation

# %% [markdown]
# ## Plot performance

# %%
# Plot parameters
lw_=2
fontSize = 10
plt_ex = 3

# %% [markdown]
# ### Plot estimated vs true trajectory

# %%
plt.figure(figsize=(7,6))
x_mean_iLQG = x_trj_new.mean(axis=0)
x_mean_LQG = x_trj_lqr_new.mean(axis=0)

ax1 = plt.subplot(311)
lines = plt.plot(t, x_mean_iLQG, lw=3, label=['x','v', r'$\theta$', r'$\omega$'])
# ax1.set_xlabel('Time')
ax1.set_ylabel('State (iLQG)')
ax1.legend(ncols=4, loc='upper right', fontsize=fontSize)
ax1.grid(True)
ax1.tick_params('x', labelbottom=False)

ax00 = lines[0].axes
ax00.set_yticks(list(ax00.get_yticks())+[np.pi])
labels = [item.get_text() for item in ax00.get_yticklabels()]
labels[-1] = r'$\pi$'
ax00.set_yticklabels(labels)

ax2 = plt.subplot(312, sharex=ax1)
lines = plt.plot(t, x_mean_LQG, lw=3, label=['x','v', r'$\theta$', r'$\omega$'])
# ax2.set_xlabel('Time')
ax2.set_ylabel('State (LQG)')
ax2.legend(ncols=4, loc='upper right', fontsize=fontSize)
ax2.grid(True)
ax2.tick_params('x', labelbottom=False)

ax00 = lines[0].axes
ax00.set_yticks(list(ax00.get_yticks())+[np.pi])
labels = [item.get_text() for item in ax00.get_yticklabels()]
labels[-1] = r'$\pi$'
ax00.set_yticklabels(labels)

ax3 = plt.subplot(313, sharex=ax1)
ax3.plot(t[:-1], u_trj_new.mean(axis=0), lw=3, label=r'$u_{iLQG}$')
ax3.plot(t[:-1], u_trj_lqr_new.mean(axis=0), lw=3, label=r'$u_{LQG}$')
ax3.set_xlabel('Time')
ax3.set_ylabel('Control input')
ax3.legend(ncols=2, loc='upper right', fontsize=fontSize)
ax3.grid(True)

# plt.tight_layout() 
plt.tight_layout(pad=0.0, w_pad=0.0, h_pad=0.0)

# %%
plt.figure(figsize=(10,6))

ax1 = plt.subplot(321)
ax1.plot(t, x_hat_trj_new[plt_ex, :,0],lw=lw_,label = r'$\hat{x}$', color = 'r')
ax1.plot(t, x_trj_new[plt_ex, :,0],lw=lw_,label = 'x', color = 'k', linestyle='--')
ax1.set_xlabel('Time')
ax1.legend(ncols=2, loc='lower right', fontsize=fontSize)
ax1.grid(True)

ax2 = plt.subplot(322)
ax2.plot(t, x_hat_trj_new[plt_ex, :,1],lw=lw_,label = r'$\hat{v}$', color = 'r')
ax2.plot(t, x_trj_new[plt_ex, :,1], lw=lw_,linestyle = '--', color = 'k', label='v')
ax2.legend(ncols=2, loc='lower right', fontsize=fontSize)
ax2.set_xlabel('Time')
ax2.grid(True)


ax3 = plt.subplot(323)
# ax3.plot(t, x_trj_new[-1, :,2], lw=lw_,linestyle = '-', color = 'k', label=r'$\theta$')
lines = plt.plot(t, x_hat_trj_new[plt_ex, :,2],lw=lw_,label = r'$\hat{\theta}$', color = 'r')
ax3.plot(t, x_trj_new[plt_ex, :,2], lw=lw_,linestyle = '--', color = 'k', label=r'$\theta$')
ax3.set_xlabel('Time')
ax3.legend(ncols=2, loc='lower right', fontsize=fontSize)
ax3.grid(True)

# lines = plt.plot(t, x_trj_new[-1, :,0])
ax00 = lines[0].axes
ax00.set_yticks(list(ax00.get_yticks())+[np.pi])
labels = [item.get_text() for item in ax00.get_yticklabels()]
labels[-1] = r'$\pi$'
ax00.set_yticklabels(labels)

ax4 = plt.subplot(324)
ax4.plot(t, x_hat_trj_new[plt_ex, :,3],lw=lw_,label = r'$\hat{\omega}$', color = 'r')
ax4.plot(t, x_trj_new[plt_ex, :,3], lw=lw_,linestyle = '--', color = 'k', label=r'$\omega$')
ax4.set_xlabel('Time')
ax4.legend(ncols=2, loc='lower right', fontsize=fontSize)
ax4.grid(True)

ax5 = plt.subplot(313)
ax5.plot(t[:-1], u_trj_new[plt_ex, :],lw=lw_, color='k')
ax5.set_xlabel('Time')
ax5.set_ylabel('Control input')
ax5.grid(True)


plt.tight_layout()

# %%
plt.plot(x_mean_iLQG[:,2], x_mean_iLQG[:,3])
plt.axvline(x = np.pi, color = 'r', lw=3, linestyle=':')
plt.axhline(y = 0, color = 'r', lw=3, linestyle=':')
plt.xlabel(r"$\theta$ (rad)", fontsize=15)
plt.ylabel(r'$\dot{\theta}$ (rad/s)', fontsize=15)
plt.title("Phase Portrait")
# Out:
# Text(0.5, 1.0, 'Phase Portrait')

# %%
plt.subplots(figsize=(10,6))
# Plot results
plt.subplot(2, 2, 1)
plt.plot(cost_trace)
plt.xlabel('# Iteration')
plt.ylabel('Total cost')
plt.title('Cost trace')

plt.subplot(2, 2, 2)
delta_opt = (np.array(cost_trace) - cost_trace[-1])
plt.plot(delta_opt)
plt.yscale('log')
plt.xlabel('# Iteration')
plt.ylabel('Optimality gap')
plt.title('Convergence plot')

plt.subplot(2, 2, 3)
plt.plot(redu_ratio_trace)
plt.title('Ratio of actual reduction and expected reduction')
plt.ylabel('Reduction ratio')
plt.xlabel('# Iteration')

plt.subplot(2, 2, 4)
plt.plot(regu_trace)
plt.title('Regularization trace')
plt.ylabel('Regularization')
plt.xlabel('# Iteration')
plt.tight_layout()
# Out:
# /tmp/ipykernel_528070/2695651614.py:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 2, 1)

# %% [markdown]
# ### Convergence Analysis
# You can find some plots of the convergence traces captured throughout the iLQR solve process above. The convergence plot indicates that we have achieved superlinear convergence. In fact, iLQR achieves nearly second order convergence. In the case of linear convergence (e.g. gradient descent), the [graph would show a line](https://en.wikipedia.org/wiki/Rate_of_convergence). While the integrated regularization improves robustness it damps convergence in the early iteration steps.
#
# In the ideal case, the expected reduction and the actual reduction should be the same, i.e. the reduction ratio remains around 1. If that is the case, the quadratic approximation of costs and linear approximation of the dynamics are very accurate. If the ratio becomes significantly lower than 1, the regularization needs to be increased and thus the stepsize reduced.
